# %%
import time
tStart = time.time()
tEnd = time.time()
print( (tEnd - tStart))
# Out:
# 0.0

# %%
from fugle_marketdata import RestClient
client = RestClient(api_key='MmRkMTA5OWUtNjM3OS00YmQ5LTk4ZWMtNTYzOGQyMjY5MWY2IGIyYTNhYWY5LTcxY2ItNGUyMy04NTVhLTU0ZDhkNzE2ZjM1Mw==')
stock = client.stock

# %%
#取得股票行情快照
stock.snapshot.quotes(market='TSE')
# Out:
# {'date': '2024-03-01',
#  'time': '140000',
#  'market': 'TSE',
#  'data': [{'type': 'EQUITY',
#    'symbol': '0050',
#    'name': '元大台灣50',
#    'openPrice': 143.55,
#    'highPrice': 143.95,
#    'lowPrice': 142.8,
#    'closePrice': 142.8,
#    'change': -0.5,
#    'changePercent': -0.35,
#    'tradeVolume': 8640,
#    'tradeValue': 1237684800,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '0051',
#    'name': '元大中型100',
#    'openPrice': 77.4,
#    'highPrice': 77.85,
#    'lowPrice': 77.25,
#    'closePrice': 77.7,
#    'change': 0.35,
#    'changePercent': 0.45,
#    'tradeVolume': 111,
#    'tradeValue': 8610350,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '0052',
#    'name': '富邦科技',
#    'openPrice': 144.65,
#    'highPrice': 144.8,
#    'lowPrice': 143.95,
#    'closePrice': 144,
#    'change': -0.05,
#    'changePercent': -0.03,
#    'tradeVolume': 95,
#    'tradeValue': 13710700,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '0053',
#    'name': '元大電子',
#    'openPrice': 78.55,
#    'highPrice': 78.85,
#    'lowPrice': 78.2,
#    'closePrice': 78.35,
#    'change': 0.15,
#    'changePercent': 0.19,
#    'tradeVolume': 6,
#    'tradeValue': 471350,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '0055',
#    'name': '元大MSCI金融',
#    'openPrice': 23.98,
#    'highPrice': 23.98,
#    'lowPrice': 23.88,
#    'closePrice': 23.92,
#    'change': -0.06,
#    'changePercent': -0.25,
#    'tradeVolume': 158,
#    'tradeValue': 3780690,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '0056',
#    'name': '元大高股息',
#    'openPrice': 37.7,
#    'highPrice': 37.82,
#    'lowPrice': 37.66,
#    'closePrice': 37.74,
#    'change': 0.04,
#    'changePercent': 0.11,
#    'tradeVolume': 16467,
#    'tradeValue': 621794280,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '0057',
#    'name': '富邦摩台',
#    'openPrice': 107.7,
#    'highPrice': 107.7,
#    'lowPrice': 107.2,
#    'closePrice': 107.2,
#    'change': 0.1,
#    'changePercent': 0.09,
#    'tradeVolume': 2,
#    'tradeValue': 214900,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '0061',
#    'name': '元大寶滬深',
#    'openPrice': 16.79,
#    'highPrice': 16.79,
#    'lowPrice': 16.63,
#    'closePrice': 16.73,
#    'change': 0.04,
#    'changePercent': 0.24,
#    'tradeVolume': 530,
#    'tradeValue': 8863010,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '006203',
#    'name': '元大MSCI台灣',
#    'openPrice': 69.5,
#    'highPrice': 69.5,
#    'lowPrice': 68.85,
#    'closePrice': 68.9,
#    'change': 0.1,
#    'changePercent': 0.15,
#    'tradeVolume': 5,
#    'tradeValue': 345300,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '006204',
#    'name': '永豐臺灣加權',
#    'openPrice': 94.1,
#    'highPrice': 94.15,
#    'lowPrice': 94.05,
#    'closePrice': 94.15,
#    'change': 0.1,
#    'changePercent': 0.11,
#    'tradeVolume': 4,
#    'tradeValue': 376400,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '006205',
#    'name': '富邦上証',
#    'openPrice': 28.67,
#    'highPrice': 28.87,
#    'lowPrice': 28.61,
#    'closePrice': 28.77,
#    'change': 0.16,
#    'changePercent': 0.56,
#    'tradeVolume': 1166,
#    'tradeValue': 33514680,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '006206',
#    'name': '元大上證50',
#    'openPrice': 27.72,
#    'highPrice': 27.84,
#    'lowPrice': 27.7,
#    'closePrice': 27.79,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 94,
#    'tradeValue': 2610760,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '006207',
#    'name': '復華滬深',
#    'openPrice': 21.85,
#    'highPrice': 22,
#    'lowPrice': 21.85,
#    'closePrice': 21.94,
#    'change': 0.14,
#    'changePercent': 0.64,
#    'tradeVolume': 123,
#    'tradeValue': 2697970,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '006208',
#    'name': '富邦台50',
#    'openPrice': 84,
#    'highPrice': 84.2,
#    'lowPrice': 83.65,
#    'closePrice': 83.7,
#    'change': -0.25,
#    'changePercent': -0.3,
#    'tradeVolume': 3880,
#    'tradeValue': 325254150,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00625K',
#    'name': '富邦上証+R',
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 0,
#    'tradeValue': 0,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00631L',
#    'name': '元大台灣50正2',
#    'openPrice': 170.9,
#    'highPrice': 171.05,
#    'lowPrice': 169.6,
#    'closePrice': 169.85,
#    'change': -0.3,
#    'changePercent': -0.18,
#    'tradeVolume': 817,
#    'tradeValue': 139077550,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00632R',
#    'name': '元大台灣50反1',
#    'openPrice': 4.21,
#    'highPrice': 4.22,
#    'lowPrice': 4.2,
#    'closePrice': 4.22,
#    'change': 0.01,
#    'changePercent': 0.24,
#    'tradeVolume': 36408,
#    'tradeValue': 153303710,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00633L',
#    'name': '富邦上証正2',
#    'openPrice': 31.59,
#    'highPrice': 31.85,
#    'lowPrice': 31.22,
#    'closePrice': 31.61,
#    'change': 0.14,
#    'changePercent': 0.44,
#    'tradeVolume': 6543,
#    'tradeValue': 206483530,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00634R',
#    'name': '富邦上証反1',
#    'openPrice': 4.8,
#    'highPrice': 4.8,
#    'lowPrice': 4.76,
#    'closePrice': 4.78,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 388,
#    'tradeValue': 1850870,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00635U',
#    'name': '期元大S&P黃金',
#    'openPrice': 24.46,
#    'highPrice': 24.5,
#    'lowPrice': 24.46,
#    'closePrice': 24.46,
#    'change': 0.1,
#    'changePercent': 0.41,
#    'tradeVolume': 271,
#    'tradeValue': 6633280,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00636',
#    'name': '國泰中國A50',
#    'openPrice': 19.6,
#    'highPrice': 19.68,
#    'lowPrice': 19.54,
#    'closePrice': 19.63,
#    'change': 0.05,
#    'changePercent': 0.26,
#    'tradeVolume': 1245,
#    'tradeValue': 24421680,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00636K',
#    'name': '國泰中國A50+U',
#    'openPrice': 6.23,
#    'highPrice': 6.23,
#    'lowPrice': 6.23,
#    'closePrice': 6.23,
#    'change': 0.02,
#    'changePercent': 0.32,
#    'tradeVolume': 2,
#    'tradeValue': 1246,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00637L',
#    'name': '元大滬深300正2',
#    'openPrice': 12.58,
#    'highPrice': 12.65,
#    'lowPrice': 12.42,
#    'closePrice': 12.56,
#    'change': 0.02,
#    'changePercent': 0.16,
#    'tradeVolume': 65893,
#    'tradeValue': 826914240,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00638R',
#    'name': '元大滬深300反1',
#    'openPrice': 10.04,
#    'highPrice': 10.06,
#    'lowPrice': 9.96,
#    'closePrice': 10,
#    'change': -0.02,
#    'changePercent': -0.2,
#    'tradeVolume': 352,
#    'tradeValue': 3514910,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00639',
#    'name': '富邦深100',
#    'openPrice': 10.16,
#    'highPrice': 10.32,
#    'lowPrice': 10.16,
#    'closePrice': 10.27,
#    'change': 0.11,
#    'changePercent': 1.08,
#    'tradeVolume': 1103,
#    'tradeValue': 11318820,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00640L',
#    'name': '富邦日本正2',
#    'openPrice': 55.05,
#    'highPrice': 55.65,
#    'lowPrice': 55.05,
#    'closePrice': 55.55,
#    'change': 1.35,
#    'changePercent': 2.49,
#    'tradeVolume': 641,
#    'tradeValue': 35498500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00641R',
#    'name': '富邦日本反1',
#    'openPrice': 6.68,
#    'highPrice': 6.68,
#    'lowPrice': 6.65,
#    'closePrice': 6.67,
#    'change': -0.05,
#    'changePercent': -0.74,
#    'tradeVolume': 1922,
#    'tradeValue': 12801200,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00642U',
#    'name': '期元大S&P石油',
#    'openPrice': 17.11,
#    'highPrice': 17.14,
#    'lowPrice': 17.11,
#    'closePrice': 17.13,
#    'change': -0.01,
#    'changePercent': -0.06,
#    'tradeVolume': 1606,
#    'tradeValue': 27505020,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00643',
#    'name': '群益深証中小',
#    'openPrice': 11.22,
#    'highPrice': 11.37,
#    'lowPrice': 11.21,
#    'closePrice': 11.32,
#    'change': 0.14,
#    'changePercent': 1.25,
#    'tradeVolume': 1259,
#    'tradeValue': 14227470,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00643K',
#    'name': '群益深証中小+R',
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 0,
#    'tradeValue': 0,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00645',
#    'name': '富邦日本',
#    'openPrice': 36.96,
#    'highPrice': 37.15,
#    'lowPrice': 36.96,
#    'closePrice': 37.12,
#    'change': 0.42,
#    'changePercent': 1.14,
#    'tradeVolume': 1254,
#    'tradeValue': 46469600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00646',
#    'name': '元大S&P500',
#    'openPrice': 50.15,
#    'highPrice': 50.35,
#    'lowPrice': 50.15,
#    'closePrice': 50.3,
#    'change': 0.25,
#    'changePercent': 0.5,
#    'tradeVolume': 5073,
#    'tradeValue': 255279900,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00647L',
#    'name': '元大S&P500正2',
#    'openPrice': 78.85,
#    'highPrice': 79.2,
#    'lowPrice': 78.85,
#    'closePrice': 79.1,
#    'change': 0.65,
#    'changePercent': 0.83,
#    'tradeVolume': 39,
#    'tradeValue': 3085100,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00648R',
#    'name': '元大S&P500反1',
#    'openPrice': 5.85,
#    'highPrice': 5.87,
#    'lowPrice': 5.85,
#    'closePrice': 5.85,
#    'change': -0.03,
#    'changePercent': -0.51,
#    'tradeVolume': 479,
#    'tradeValue': 2802890,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00650L',
#    'name': '復華香港正2',
#    'openPrice': 8.54,
#    'highPrice': 8.7,
#    'lowPrice': 8.21,
#    'closePrice': 8.59,
#    'change': -0.01,
#    'changePercent': -0.12,
#    'tradeVolume': 31946,
#    'tradeValue': 271631150,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00651R',
#    'name': '復華香港反1',
#    'openPrice': 9.68,
#    'highPrice': 9.9,
#    'lowPrice': 9.62,
#    'closePrice': 9.67,
#    'change': -0.01,
#    'changePercent': -0.1,
#    'tradeVolume': 828,
#    'tradeValue': 8086880,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00652',
#    'name': '富邦印度',
#    'openPrice': 35.9,
#    'highPrice': 36.14,
#    'lowPrice': 35.9,
#    'closePrice': 36.13,
#    'change': 0.27,
#    'changePercent': 0.75,
#    'tradeVolume': 626,
#    'tradeValue': 22537450,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00653L',
#    'name': '富邦印度正2',
#    'openPrice': 56.95,
#    'highPrice': 57.6,
#    'lowPrice': 56.9,
#    'closePrice': 57.6,
#    'change': 1.1,
#    'changePercent': 1.95,
#    'tradeVolume': 182,
#    'tradeValue': 10420450,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00654R',
#    'name': '富邦印度反1',
#    'openPrice': 6.85,
#    'highPrice': 6.85,
#    'lowPrice': 6.82,
#    'closePrice': 6.82,
#    'change': -0.08,
#    'changePercent': -1.16,
#    'tradeVolume': 154,
#    'tradeValue': 1050980,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00655L',
#    'name': '國泰中國A50正2',
#    'openPrice': 21.79,
#    'highPrice': 22.05,
#    'lowPrice': 21.59,
#    'closePrice': 21.9,
#    'change': 0.12,
#    'changePercent': 0.55,
#    'tradeVolume': 4078,
#    'tradeValue': 89000640,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00656R',
#    'name': '國泰中國A50反1',
#    'openPrice': 9.02,
#    'highPrice': 9.04,
#    'lowPrice': 8.96,
#    'closePrice': 8.98,
#    'change': -0.02,
#    'changePercent': -0.22,
#    'tradeVolume': 429,
#    'tradeValue': 3864780,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00657',
#    'name': '國泰日經225',
#    'openPrice': 46.46,
#    'highPrice': 46.85,
#    'lowPrice': 46.46,
#    'closePrice': 46.85,
#    'change': 0.91,
#    'changePercent': 1.98,
#    'tradeVolume': 124,
#    'tradeValue': 5789230,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00657K',
#    'name': '國泰日經225+U',
#    'openPrice': 14.78,
#    'highPrice': 14.78,
#    'lowPrice': 14.78,
#    'closePrice': 14.78,
#    'change': 0.33,
#    'changePercent': 2.28,
#    'tradeVolume': 2,
#    'tradeValue': 2956,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00660',
#    'name': '元大歐洲50',
#    'openPrice': 35.02,
#    'highPrice': 35.2,
#    'lowPrice': 35.02,
#    'closePrice': 35.2,
#    'change': 0.08,
#    'changePercent': 0.23,
#    'tradeVolume': 3,
#    'tradeValue': 105240,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00661',
#    'name': '元大日經225',
#    'openPrice': 50.35,
#    'highPrice': 50.9,
#    'lowPrice': 50.35,
#    'closePrice': 50.9,
#    'change': 1.07,
#    'changePercent': 2.15,
#    'tradeVolume': 527,
#    'tradeValue': 26738250,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00662',
#    'name': '富邦NASDAQ',
#    'openPrice': 73.05,
#    'highPrice': 73.65,
#    'lowPrice': 73.05,
#    'closePrice': 73.55,
#    'change': 0.8,
#    'changePercent': 1.1,
#    'tradeVolume': 4090,
#    'tradeValue': 301033900,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00663L',
#    'name': '國泰臺灣加權正2',
#    'openPrice': 157.85,
#    'highPrice': 157.85,
#    'lowPrice': 157,
#    'closePrice': 157.1,
#    'change': -0.2,
#    'changePercent': -0.13,
#    'tradeVolume': 143,
#    'tradeValue': 22475450,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00664R',
#    'name': '國泰臺灣加權反1',
#    'openPrice': 4.74,
#    'highPrice': 4.76,
#    'lowPrice': 4.74,
#    'closePrice': 4.76,
#    'change': 0.02,
#    'changePercent': 0.42,
#    'tradeVolume': 2568,
#    'tradeValue': 12188350,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00665L',
#    'name': '富邦恒生國企正2',
#    'openPrice': 5.34,
#    'highPrice': 5.49,
#    'lowPrice': 5.15,
#    'closePrice': 5.44,
#    'change': 0.04,
#    'changePercent': 0.74,
#    'tradeVolume': 94431,
#    'tradeValue': 503914780,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00666R',
#    'name': '富邦恒生國企反1',
#    'openPrice': 16.78,
#    'highPrice': 16.92,
#    'lowPrice': 16.47,
#    'closePrice': 16.54,
#    'change': -0.11,
#    'changePercent': -0.66,
#    'tradeVolume': 721,
#    'tradeValue': 12004480,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00668',
#    'name': '國泰美國道瓊',
#    'openPrice': 44.7,
#    'highPrice': 44.77,
#    'lowPrice': 44.7,
#    'closePrice': 44.72,
#    'change': -0.06,
#    'changePercent': -0.13,
#    'tradeVolume': 66,
#    'tradeValue': 2951270,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00668K',
#    'name': '國泰美國道瓊+U',
#    'openPrice': 14.14,
#    'highPrice': 14.14,
#    'lowPrice': 14.14,
#    'closePrice': 14.14,
#    'change': 0.01,
#    'changePercent': 0.07,
#    'tradeVolume': 2,
#    'tradeValue': 2828,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00669R',
#    'name': '國泰美國道瓊反1',
#    'openPrice': 7.08,
#    'highPrice': 7.08,
#    'lowPrice': 7.06,
#    'closePrice': 7.07,
#    'change': -0.01,
#    'changePercent': -0.14,
#    'tradeVolume': 1107,
#    'tradeValue': 7824380,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00670L',
#    'name': '富邦NASDAQ正2',
#    'openPrice': 111.6,
#    'highPrice': 112.15,
#    'lowPrice': 111.35,
#    'closePrice': 112,
#    'change': 2.45,
#    'changePercent': 2.24,
#    'tradeVolume': 1578,
#    'tradeValue': 176326700,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00671R',
#    'name': '富邦NASDAQ反1',
#    'openPrice': 4.08,
#    'highPrice': 4.09,
#    'lowPrice': 4.07,
#    'closePrice': 4.08,
#    'change': -0.03,
#    'changePercent': -0.73,
#    'tradeVolume': 8536,
#    'tradeValue': 34797560,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00673R',
#    'name': '期元大S&P原油反1',
#    'openPrice': 7.67,
#    'highPrice': 7.67,
#    'lowPrice': 7.65,
#    'closePrice': 7.67,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 14283,
#    'tradeValue': 109478890,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00674R',
#    'name': '期元大S&P黃金反1',
#    'openPrice': 12.04,
#    'highPrice': 12.04,
#    'lowPrice': 12.01,
#    'closePrice': 12.03,
#    'change': -0.07,
#    'changePercent': -0.58,
#    'tradeVolume': 189,
#    'tradeValue': 2273390,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00675L',
#    'name': '富邦臺灣加權正2',
#    'openPrice': 68.95,
#    'highPrice': 69.05,
#    'lowPrice': 68.4,
#    'closePrice': 68.65,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 715,
#    'tradeValue': 49146700,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00676R',
#    'name': '富邦臺灣加權反1',
#    'openPrice': 2.63,
#    'highPrice': 2.64,
#    'lowPrice': 2.62,
#    'closePrice': 2.64,
#    'change': 0.01,
#    'changePercent': 0.38,
#    'tradeVolume': 7573,
#    'tradeValue': 19928440,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00678',
#    'name': '群益那斯達克生技',
#    'openPrice': 27.8,
#    'highPrice': 27.82,
#    'lowPrice': 27.71,
#    'closePrice': 27.75,
#    'change': -0.81,
#    'changePercent': -2.84,
#    'tradeVolume': 362,
#    'tradeValue': 10056770,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00680L',
#    'name': '元大美債20正2',
#    'openPrice': 8.92,
#    'highPrice': 8.98,
#    'lowPrice': 8.89,
#    'closePrice': 8.93,
#    'change': 0.1,
#    'changePercent': 1.13,
#    'tradeVolume': 38121,
#    'tradeValue': 340514070,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00681R',
#    'name': '元大美債20反1',
#    'openPrice': 20.05,
#    'highPrice': 20.08,
#    'lowPrice': 19.99,
#    'closePrice': 20.05,
#    'change': -0.13,
#    'changePercent': -0.64,
#    'tradeVolume': 369,
#    'tradeValue': 7389510,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00682U',
#    'name': '期元大美元指數',
#    'openPrice': 21.02,
#    'highPrice': 21.02,
#    'lowPrice': 20.97,
#    'closePrice': 20.97,
#    'change': 0.01,
#    'changePercent': 0.05,
#    'tradeVolume': 6,
#    'tradeValue': 125970,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00683L',
#    'name': '期元大美元指正2',
#    'openPrice': 22.4,
#    'highPrice': 22.43,
#    'lowPrice': 22.39,
#    'closePrice': 22.42,
#    'change': 0.09,
#    'changePercent': 0.4,
#    'tradeVolume': 221,
#    'tradeValue': 4951660,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00684R',
#    'name': '期元大美元指反1',
#    'openPrice': 15.58,
#    'highPrice': 15.59,
#    'lowPrice': 15.58,
#    'closePrice': 15.59,
#    'change': 0.01,
#    'changePercent': 0.06,
#    'tradeVolume': 2,
#    'tradeValue': 31170,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00685L',
#    'name': '群益臺灣加權正2',
#    'openPrice': 61.45,
#    'highPrice': 61.45,
#    'lowPrice': 60.95,
#    'closePrice': 61.05,
#    'change': -0.05,
#    'changePercent': -0.08,
#    'tradeVolume': 147,
#    'tradeValue': 9003650,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00686R',
#    'name': '群益臺灣加權反1',
#    'openPrice': 2.83,
#    'highPrice': 2.84,
#    'lowPrice': 2.82,
#    'closePrice': 2.84,
#    'change': 0.01,
#    'changePercent': 0.35,
#    'tradeVolume': 344,
#    'tradeValue': 973610,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00688L',
#    'name': '國泰20年美債正2',
#    'openPrice': 8.85,
#    'highPrice': 8.91,
#    'lowPrice': 8.84,
#    'closePrice': 8.88,
#    'change': 0.11,
#    'changePercent': 1.25,
#    'tradeVolume': 27423,
#    'tradeValue': 243436830,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00689R',
#    'name': '國泰20年美債反1',
#    'openPrice': 20.75,
#    'highPrice': 20.75,
#    'lowPrice': 20.75,
#    'closePrice': 20.75,
#    'change': -0.19,
#    'changePercent': -0.91,
#    'tradeVolume': 106,
#    'tradeValue': 2199500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00690',
#    'name': '兆豐藍籌30',
#    'openPrice': 31.58,
#    'highPrice': 31.64,
#    'lowPrice': 31.33,
#    'closePrice': 31.35,
#    'change': -0.13,
#    'changePercent': -0.41,
#    'tradeVolume': 5280,
#    'tradeValue': 166038470,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00692',
#    'name': '富邦公司治理',
#    'openPrice': 34.77,
#    'highPrice': 34.83,
#    'lowPrice': 34.64,
#    'closePrice': 34.67,
#    'change': -0.07,
#    'changePercent': -0.2,
#    'tradeVolume': 2228,
#    'tradeValue': 77363960,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00693U',
#    'name': '期街口S&P黃豆',
#    'openPrice': 23.04,
#    'highPrice': 23.21,
#    'lowPrice': 23.03,
#    'closePrice': 23.21,
#    'change': 0.09,
#    'changePercent': 0.39,
#    'tradeVolume': 324,
#    'tradeValue': 7486250,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00700',
#    'name': '富邦恒生國企',
#    'openPrice': 11.12,
#    'highPrice': 11.2,
#    'lowPrice': 10.93,
#    'closePrice': 11.17,
#    'change': 0.04,
#    'changePercent': 0.36,
#    'tradeVolume': 425,
#    'tradeValue': 4705760,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00701',
#    'name': '國泰股利精選30',
#    'openPrice': 25.36,
#    'highPrice': 25.43,
#    'lowPrice': 25.31,
#    'closePrice': 25.4,
#    'change': -0.06,
#    'changePercent': -0.24,
#    'tradeVolume': 842,
#    'tradeValue': 21367060,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00702',
#    'name': '國泰標普低波高息',
#    'openPrice': 21.57,
#    'highPrice': 21.65,
#    'lowPrice': 21.57,
#    'closePrice': 21.65,
#    'change': 0.09,
#    'changePercent': 0.42,
#    'tradeVolume': 154,
#    'tradeValue': 3327860,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00703',
#    'name': '台新MSCI中國',
#    'openPrice': 13.63,
#    'highPrice': 13.77,
#    'lowPrice': 13.37,
#    'closePrice': 13.77,
#    'change': 0.04,
#    'changePercent': 0.29,
#    'tradeVolume': 172,
#    'tradeValue': 2326100,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00706L',
#    'name': '期元大S&P日圓正2',
#    'openPrice': 6.9,
#    'highPrice': 6.9,
#    'lowPrice': 6.87,
#    'closePrice': 6.88,
#    'change': -0.06,
#    'changePercent': -0.86,
#    'tradeVolume': 9203,
#    'tradeValue': 63403850,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00707R',
#    'name': '期元大S&P日圓反1',
#    'openPrice': 28.23,
#    'highPrice': 28.35,
#    'lowPrice': 28.23,
#    'closePrice': 28.35,
#    'change': 0.07,
#    'changePercent': 0.25,
#    'tradeVolume': 3,
#    'tradeValue': 84810,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00708L',
#    'name': '期元大S&P黃金正2',
#    'openPrice': 26.68,
#    'highPrice': 26.79,
#    'lowPrice': 26.66,
#    'closePrice': 26.69,
#    'change': 0.22,
#    'changePercent': 0.83,
#    'tradeVolume': 846,
#    'tradeValue': 22601690,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00709',
#    'name': '富邦歐洲',
#    'openPrice': 27.74,
#    'highPrice': 27.8,
#    'lowPrice': 27.74,
#    'closePrice': 27.8,
#    'change': 0.05,
#    'changePercent': 0.18,
#    'tradeVolume': 29,
#    'tradeValue': 804760,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00710B',
#    'name': '復華彭博非投等債',
#    'openPrice': 18.95,
#    'highPrice': 18.97,
#    'lowPrice': 18.94,
#    'closePrice': 18.96,
#    'change': -0.02,
#    'changePercent': -0.11,
#    'tradeVolume': 280,
#    'tradeValue': 5307190,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00711B',
#    'name': '復華彭博新興債',
#    'openPrice': 16.1,
#    'highPrice': 16.12,
#    'lowPrice': 16.09,
#    'closePrice': 16.09,
#    'change': -0.03,
#    'changePercent': -0.19,
#    'tradeVolume': 153,
#    'tradeValue': 2464270,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00712',
#    'name': '復華富時不動產',
#    'openPrice': 9.55,
#    'highPrice': 9.58,
#    'lowPrice': 9.51,
#    'closePrice': 9.57,
#    'change': 0.17,
#    'changePercent': 1.81,
#    'tradeVolume': 29775,
#    'tradeValue': 284465250,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00713',
#    'name': '元大台灣高息低波',
#    'openPrice': 51.5,
#    'highPrice': 51.5,
#    'lowPrice': 51.35,
#    'closePrice': 51.4,
#    'change': 0.05,
#    'changePercent': 0.1,
#    'tradeVolume': 4512,
#    'tradeValue': 232169250,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00714',
#    'name': '群益道瓊美國地產',
#    'openPrice': 19.39,
#    'highPrice': 19.4,
#    'lowPrice': 19.37,
#    'closePrice': 19.37,
#    'change': 0.16,
#    'changePercent': 0.83,
#    'tradeVolume': 341,
#    'tradeValue': 6612750,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00715L',
#    'name': '期街口布蘭特正2',
#    'openPrice': 14.98,
#    'highPrice': 15.02,
#    'lowPrice': 14.97,
#    'closePrice': 14.97,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 7928,
#    'tradeValue': 118849030,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00717',
#    'name': '富邦美國特別股',
#    'openPrice': 15.71,
#    'highPrice': 15.79,
#    'lowPrice': 15.71,
#    'closePrice': 15.75,
#    'change': 0.06,
#    'changePercent': 0.38,
#    'tradeVolume': 673,
#    'tradeValue': 10604970,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00728',
#    'name': '第一金工業30',
#    'openPrice': 29.05,
#    'highPrice': 29.16,
#    'lowPrice': 28.83,
#    'closePrice': 28.86,
#    'change': -0.13,
#    'changePercent': -0.45,
#    'tradeVolume': 800,
#    'tradeValue': 23224040,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00730',
#    'name': '富邦臺灣優質高息',
#    'openPrice': 21.48,
#    'highPrice': 21.63,
#    'lowPrice': 21.48,
#    'closePrice': 21.56,
#    'change': 0.11,
#    'changePercent': 0.51,
#    'tradeVolume': 456,
#    'tradeValue': 9820990,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00731',
#    'name': '復華富時高息低波',
#    'openPrice': 68.8,
#    'highPrice': 68.8,
#    'lowPrice': 68.55,
#    'closePrice': 68.6,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 857,
#    'tradeValue': 58830100,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00733',
#    'name': '富邦臺灣中小',
#    'openPrice': 61.65,
#    'highPrice': 62.7,
#    'lowPrice': 61.65,
#    'closePrice': 62.5,
#    'change': 1,
#    'changePercent': 1.63,
#    'tradeVolume': 1677,
#    'tradeValue': 104613600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00735',
#    'name': '國泰臺韓科技',
#    'openPrice': 31.2,
#    'highPrice': 31.24,
#    'lowPrice': 31.06,
#    'closePrice': 31.06,
#    'change': -0.1,
#    'changePercent': -0.32,
#    'tradeVolume': 165,
#    'tradeValue': 5133530,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00736',
#    'name': '國泰新興市場',
#    'openPrice': 20.84,
#    'highPrice': 20.84,
#    'lowPrice': 20.81,
#    'closePrice': 20.81,
#    'change': 0.02,
#    'changePercent': 0.1,
#    'tradeVolume': 101,
#    'tradeValue': 2101840,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00737',
#    'name': '國泰AI+Robo',
#    'openPrice': 31.47,
#    'highPrice': 31.61,
#    'lowPrice': 31.47,
#    'closePrice': 31.61,
#    'change': 0.21,
#    'changePercent': 0.67,
#    'tradeVolume': 461,
#    'tradeValue': 14547340,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00738U',
#    'name': '期元大道瓊白銀',
#    'openPrice': 21.17,
#    'highPrice': 21.25,
#    'lowPrice': 21.12,
#    'closePrice': 21.19,
#    'change': 0.17,
#    'changePercent': 0.81,
#    'tradeVolume': 477,
#    'tradeValue': 10091440,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00739',
#    'name': '元大MSCI A股',
#    'openPrice': 20.33,
#    'highPrice': 20.46,
#    'lowPrice': 20.33,
#    'closePrice': 20.41,
#    'change': 0.13,
#    'changePercent': 0.64,
#    'tradeVolume': 72,
#    'tradeValue': 1470370,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00752',
#    'name': '中信中國50',
#    'openPrice': 16.1,
#    'highPrice': 16.14,
#    'lowPrice': 15.9,
#    'closePrice': 16.08,
#    'change': -0.02,
#    'changePercent': -0.12,
#    'tradeVolume': 2964,
#    'tradeValue': 47531400,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00753L',
#    'name': '中信中國50正2',
#    'openPrice': 6.7,
#    'highPrice': 6.75,
#    'lowPrice': 6.49,
#    'closePrice': 6.69,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 40375,
#    'tradeValue': 267554900,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00757',
#    'name': '統一FANG+',
#    'openPrice': 75.2,
#    'highPrice': 75.5,
#    'lowPrice': 75,
#    'closePrice': 75.4,
#    'change': 1,
#    'changePercent': 1.34,
#    'tradeVolume': 2758,
#    'tradeValue': 207765200,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00762',
#    'name': '元大全球AI',
#    'openPrice': 57.55,
#    'highPrice': 58,
#    'lowPrice': 57.5,
#    'closePrice': 58,
#    'change': 1.45,
#    'changePercent': 2.56,
#    'tradeVolume': 684,
#    'tradeValue': 39514950,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00763U',
#    'name': '期街口道瓊銅',
#    'openPrice': 23.61,
#    'highPrice': 23.61,
#    'lowPrice': 23.58,
#    'closePrice': 23.58,
#    'change': -0.07,
#    'changePercent': -0.3,
#    'tradeVolume': 9,
#    'tradeValue': 212370,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00770',
#    'name': '國泰北美科技',
#    'openPrice': 40.8,
#    'highPrice': 41.09,
#    'lowPrice': 40.77,
#    'closePrice': 41.08,
#    'change': 0.79,
#    'changePercent': 1.96,
#    'tradeVolume': 3431,
#    'tradeValue': 140510830,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00771',
#    'name': '元大US高息特別股',
#    'openPrice': 17.32,
#    'highPrice': 17.35,
#    'lowPrice': 17.28,
#    'closePrice': 17.29,
#    'change': 0.04,
#    'changePercent': 0.23,
#    'tradeVolume': 88,
#    'tradeValue': 1523000,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00775B',
#    'name': '新光投等債15+',
#    'openPrice': 33.65,
#    'highPrice': 33.72,
#    'lowPrice': 33.56,
#    'closePrice': 33.72,
#    'change': -0.08,
#    'changePercent': -0.24,
#    'tradeVolume': 9,
#    'tradeValue': 302530,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00783',
#    'name': '富邦中証500',
#    'openPrice': 18.1,
#    'highPrice': 18.1,
#    'lowPrice': 18.09,
#    'closePrice': 18.09,
#    'change': 0.26,
#    'changePercent': 1.46,
#    'tradeVolume': 34,
#    'tradeValue': 615370,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00830',
#    'name': '國泰費城半導體',
#    'openPrice': 41.8,
#    'highPrice': 42.26,
#    'lowPrice': 41.8,
#    'closePrice': 42.24,
#    'change': 1.48,
#    'changePercent': 3.63,
#    'tradeVolume': 8920,
#    'tradeValue': 375409370,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00850',
#    'name': '元大臺灣ESG永續',
#    'openPrice': 36.76,
#    'highPrice': 36.82,
#    'lowPrice': 36.68,
#    'closePrice': 36.7,
#    'change': -0.08,
#    'changePercent': -0.22,
#    'tradeVolume': 1009,
#    'tradeValue': 37076090,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00851',
#    'name': '台新全球AI',
#    'openPrice': 41.34,
#    'highPrice': 41.68,
#    'lowPrice': 41.34,
#    'closePrice': 41.63,
#    'change': 0.55,
#    'changePercent': 1.34,
#    'tradeVolume': 31,
#    'tradeValue': 1289570,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00852L',
#    'name': '國泰美國道瓊正2',
#    'openPrice': 24.13,
#    'highPrice': 24.19,
#    'lowPrice': 24.13,
#    'closePrice': 24.17,
#    'change': 0.07,
#    'changePercent': 0.29,
#    'tradeVolume': 224,
#    'tradeValue': 5415120,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00861',
#    'name': '元大全球未來通訊',
#    'openPrice': 37.71,
#    'highPrice': 37.94,
#    'lowPrice': 37.71,
#    'closePrice': 37.93,
#    'change': 0.4,
#    'changePercent': 1.07,
#    'tradeVolume': 1183,
#    'tradeValue': 44843500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00865B',
#    'name': '國泰US短期公債',
#    'openPrice': 43.83,
#    'highPrice': 43.85,
#    'lowPrice': 43.78,
#    'closePrice': 43.78,
#    'change': -0.08,
#    'changePercent': -0.18,
#    'tradeVolume': 151,
#    'tradeValue': 6614760,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00875',
#    'name': '國泰網路資安',
#    'openPrice': 32.42,
#    'highPrice': 32.61,
#    'lowPrice': 32.42,
#    'closePrice': 32.6,
#    'change': 0.18,
#    'changePercent': 0.56,
#    'tradeVolume': 352,
#    'tradeValue': 11464420,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00876',
#    'name': '元大全球5G',
#    'openPrice': 36.93,
#    'highPrice': 37.19,
#    'lowPrice': 36.93,
#    'closePrice': 37.08,
#    'change': 0.46,
#    'changePercent': 1.26,
#    'tradeVolume': 1897,
#    'tradeValue': 70377020,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00878',
#    'name': '國泰永續高股息',
#    'openPrice': 22,
#    'highPrice': 22.1,
#    'lowPrice': 22,
#    'closePrice': 22.03,
#    'change': 0.04,
#    'changePercent': 0.18,
#    'tradeVolume': 51708,
#    'tradeValue': 1140116450,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00881',
#    'name': '國泰台灣5G+',
#    'openPrice': 19.2,
#    'highPrice': 19.27,
#    'lowPrice': 19.09,
#    'closePrice': 19.09,
#    'change': -0.08,
#    'changePercent': -0.42,
#    'tradeVolume': 13029,
#    'tradeValue': 249757600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00882',
#    'name': '中信中國高股息',
#    'openPrice': 10.24,
#    'highPrice': 10.26,
#    'lowPrice': 10.12,
#    'closePrice': 10.23,
#    'change': -0.02,
#    'changePercent': -0.2,
#    'tradeVolume': 23709,
#    'tradeValue': 241591330,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00885',
#    'name': '富邦越南',
#    'openPrice': 12.52,
#    'highPrice': 12.55,
#    'lowPrice': 12.49,
#    'closePrice': 12.54,
#    'change': 0.06,
#    'changePercent': 0.48,
#    'tradeVolume': 8913,
#    'tradeValue': 111623440,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00891',
#    'name': '中信關鍵半導體',
#    'openPrice': 17.59,
#    'highPrice': 17.65,
#    'lowPrice': 17.44,
#    'closePrice': 17.47,
#    'change': -0.05,
#    'changePercent': -0.29,
#    'tradeVolume': 10263,
#    'tradeValue': 180227290,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00892',
#    'name': '富邦台灣半導體',
#    'openPrice': 15.05,
#    'highPrice': 15.14,
#    'lowPrice': 15.03,
#    'closePrice': 15.05,
#    'change': 0.07,
#    'changePercent': 0.47,
#    'tradeVolume': 6574,
#    'tradeValue': 99166720,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00893',
#    'name': '國泰智能電動車',
#    'openPrice': 20.2,
#    'highPrice': 20.36,
#    'lowPrice': 20.19,
#    'closePrice': 20.34,
#    'change': 0.69,
#    'changePercent': 3.51,
#    'tradeVolume': 20933,
#    'tradeValue': 425251620,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00894',
#    'name': '中信小資高價30',
#    'openPrice': 17.92,
#    'highPrice': 18.06,
#    'lowPrice': 17.9,
#    'closePrice': 17.98,
#    'change': 0.16,
#    'changePercent': 0.9,
#    'tradeVolume': 2489,
#    'tradeValue': 44737160,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00895',
#    'name': '富邦未來車',
#    'openPrice': 23.54,
#    'highPrice': 23.72,
#    'lowPrice': 23.54,
#    'closePrice': 23.7,
#    'change': 0.46,
#    'changePercent': 1.98,
#    'tradeVolume': 2391,
#    'tradeValue': 56594670,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00896',
#    'name': '中信綠能及電動車',
#    'openPrice': 16.51,
#    'highPrice': 16.58,
#    'lowPrice': 16.5,
#    'closePrice': 16.54,
#    'change': 0.03,
#    'changePercent': 0.18,
#    'tradeVolume': 1822,
#    'tradeValue': 30142600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00897',
#    'name': '富邦基因免疫生技',
#    'openPrice': 8.13,
#    'highPrice': 8.13,
#    'lowPrice': 8.06,
#    'closePrice': 8.08,
#    'change': -0.24,
#    'changePercent': -2.88,
#    'tradeVolume': 1323,
#    'tradeValue': 10702300,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00898',
#    'name': '國泰基因免疫革命',
#    'openPrice': 7.55,
#    'highPrice': 7.55,
#    'lowPrice': 7.45,
#    'closePrice': 7.46,
#    'change': -0.23,
#    'changePercent': -2.99,
#    'tradeVolume': 689,
#    'tradeValue': 5150650,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00899',
#    'name': 'FT潔淨能源',
#    'openPrice': 16.54,
#    'highPrice': 16.62,
#    'lowPrice': 16.54,
#    'closePrice': 16.62,
#    'change': 0.08,
#    'changePercent': 0.48,
#    'tradeVolume': 130,
#    'tradeValue': 2158920,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00900',
#    'name': '富邦特選高股息30',
#    'openPrice': 14.37,
#    'highPrice': 14.45,
#    'lowPrice': 14.34,
#    'closePrice': 14.4,
#    'change': 0.03,
#    'changePercent': 0.21,
#    'tradeVolume': 20438,
#    'tradeValue': 294546430,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00901',
#    'name': '永豐智能車供應鏈',
#    'openPrice': 16.42,
#    'highPrice': 16.46,
#    'lowPrice': 16.35,
#    'closePrice': 16.36,
#    'change': 0.02,
#    'changePercent': 0.12,
#    'tradeVolume': 870,
#    'tradeValue': 14288500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00902',
#    'name': '中信電池及儲能',
#    'openPrice': 9.59,
#    'highPrice': 9.63,
#    'lowPrice': 9.56,
#    'closePrice': 9.61,
#    'change': 0.17,
#    'changePercent': 1.8,
#    'tradeVolume': 4058,
#    'tradeValue': 38943800,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00903',
#    'name': '富邦元宇宙',
#    'openPrice': 13.08,
#    'highPrice': 13.21,
#    'lowPrice': 13.08,
#    'closePrice': 13.19,
#    'change': 0.28,
#    'changePercent': 2.17,
#    'tradeVolume': 5456,
#    'tradeValue': 71865060,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00904',
#    'name': '新光臺灣半導體30',
#    'openPrice': 16.33,
#    'highPrice': 16.35,
#    'lowPrice': 16.19,
#    'closePrice': 16.21,
#    'change': -0.02,
#    'changePercent': -0.12,
#    'tradeVolume': 1851,
#    'tradeValue': 30114340,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00905',
#    'name': 'FT臺灣Smart',
#    'openPrice': 11.36,
#    'highPrice': 11.37,
#    'lowPrice': 11.32,
#    'closePrice': 11.33,
#    'change': -0.03,
#    'changePercent': -0.26,
#    'tradeVolume': 1286,
#    'tradeValue': 14595960,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00907',
#    'name': '永豐優息存股',
#    'openPrice': 14.66,
#    'highPrice': 14.66,
#    'lowPrice': 14.6,
#    'closePrice': 14.64,
#    'change': -0.02,
#    'changePercent': -0.14,
#    'tradeVolume': 2907,
#    'tradeValue': 42557080,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00908',
#    'name': '富邦入息REITs+',
#    'openPrice': 11.9,
#    'highPrice': 11.91,
#    'lowPrice': 11.86,
#    'closePrice': 11.87,
#    'change': -0.05,
#    'changePercent': -0.42,
#    'tradeVolume': 824,
#    'tradeValue': 9787120,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00909',
#    'name': '國泰數位支付服務',
#    'openPrice': 26.56,
#    'highPrice': 26.65,
#    'lowPrice': 26.56,
#    'closePrice': 26.62,
#    'change': -0.31,
#    'changePercent': -1.15,
#    'tradeVolume': 506,
#    'tradeValue': 13457060,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00910',
#    'name': '第一金太空衛星',
#    'openPrice': 16.86,
#    'highPrice': 16.86,
#    'lowPrice': 16.79,
#    'closePrice': 16.82,
#    'change': 0.07,
#    'changePercent': 0.42,
#    'tradeVolume': 175,
#    'tradeValue': 2942650,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00911',
#    'name': '兆豐洲際半導體',
#    'openPrice': 25.79,
#    'highPrice': 26.12,
#    'lowPrice': 25.62,
#    'closePrice': 26.12,
#    'change': 0.79,
#    'changePercent': 3.12,
#    'tradeVolume': 891,
#    'tradeValue': 23181250,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00912',
#    'name': '中信臺灣智慧50',
#    'openPrice': 16.49,
#    'highPrice': 16.54,
#    'lowPrice': 16.46,
#    'closePrice': 16.48,
#    'change': -0.05,
#    'changePercent': -0.3,
#    'tradeVolume': 708,
#    'tradeValue': 11666540,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00913',
#    'name': '兆豐台灣晶圓製造',
#    'openPrice': 19.5,
#    'highPrice': 19.56,
#    'lowPrice': 19.39,
#    'closePrice': 19.42,
#    'change': -0.06,
#    'changePercent': -0.31,
#    'tradeVolume': 3540,
#    'tradeValue': 68908890,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00915',
#    'name': '凱基優選高股息30',
#    'openPrice': 22.85,
#    'highPrice': 22.94,
#    'lowPrice': 22.75,
#    'closePrice': 22.89,
#    'change': 0.07,
#    'changePercent': 0.31,
#    'tradeVolume': 9677,
#    'tradeValue': 221523660,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00916',
#    'name': '國泰全球品牌50',
#    'openPrice': 20.86,
#    'highPrice': 20.91,
#    'lowPrice': 20.85,
#    'closePrice': 20.9,
#    'change': 0.13,
#    'changePercent': 0.63,
#    'tradeVolume': 273,
#    'tradeValue': 5701600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00917',
#    'name': '中信特選金融',
#    'openPrice': 17.89,
#    'highPrice': 17.9,
#    'lowPrice': 17.87,
#    'closePrice': 17.87,
#    'change': 0.06,
#    'changePercent': 0.34,
#    'tradeVolume': 584,
#    'tradeValue': 10443620,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00918',
#    'name': '大華優利高填息30',
#    'openPrice': 22.3,
#    'highPrice': 22.33,
#    'lowPrice': 22.11,
#    'closePrice': 22.24,
#    'change': 0.27,
#    'changePercent': 1.23,
#    'tradeVolume': 75874,
#    'tradeValue': 1688997670,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00919',
#    'name': '群益台灣精選高息',
#    'openPrice': 24.42,
#    'highPrice': 24.44,
#    'lowPrice': 24.2,
#    'closePrice': 24.25,
#    'change': 0.22,
#    'changePercent': 0.92,
#    'tradeVolume': 298696,
#    'tradeValue': 7266177800,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00920',
#    'name': '富邦ESG綠色電力',
#    'openPrice': 13.62,
#    'highPrice': 13.67,
#    'lowPrice': 13.6,
#    'closePrice': 13.66,
#    'change': 0.2,
#    'changePercent': 1.49,
#    'tradeVolume': 161,
#    'tradeValue': 2197820,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00921',
#    'name': '兆豐龍頭等權重',
#    'openPrice': 18.2,
#    'highPrice': 18.24,
#    'lowPrice': 18.17,
#    'closePrice': 18.19,
#    'change': -0.01,
#    'changePercent': -0.05,
#    'tradeVolume': 2867,
#    'tradeValue': 52191770,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00922',
#    'name': '國泰台灣領袖50',
#    'openPrice': 17.95,
#    'highPrice': 17.97,
#    'lowPrice': 17.85,
#    'closePrice': 17.86,
#    'change': -0.04,
#    'changePercent': -0.22,
#    'tradeVolume': 7557,
#    'tradeValue': 135204480,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00923',
#    'name': '群益台ESG低碳50',
#    'openPrice': 18.39,
#    'highPrice': 18.44,
#    'lowPrice': 18.32,
#    'closePrice': 18.32,
#    'change': -0.07,
#    'changePercent': -0.38,
#    'tradeVolume': 5502,
#    'tradeValue': 101121990,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00924',
#    'name': '復華S&P500成長',
#    'openPrice': 19.77,
#    'highPrice': 19.92,
#    'lowPrice': 19.77,
#    'closePrice': 19.92,
#    'change': 0.2,
#    'changePercent': 1.01,
#    'tradeVolume': 394,
#    'tradeValue': 7835420,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00925',
#    'name': '新光標普電動車',
#    'openPrice': 16.5,
#    'highPrice': 16.61,
#    'lowPrice': 16.5,
#    'closePrice': 16.6,
#    'change': 0.17,
#    'changePercent': 1.03,
#    'tradeVolume': 233,
#    'tradeValue': 3867330,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00926',
#    'name': '凱基全球菁英55',
#    'openPrice': 19.25,
#    'highPrice': 19.44,
#    'lowPrice': 19.25,
#    'closePrice': 19.3,
#    'change': 0.08,
#    'changePercent': 0.42,
#    'tradeVolume': 307,
#    'tradeValue': 5926760,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00927',
#    'name': '群益半導體收益',
#    'openPrice': 18.2,
#    'highPrice': 18.28,
#    'lowPrice': 18.12,
#    'closePrice': 18.13,
#    'change': -0.06,
#    'changePercent': -0.33,
#    'tradeVolume': 7496,
#    'tradeValue': 136407130,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00929',
#    'name': '復華台灣科技優息',
#    'openPrice': 19.61,
#    'highPrice': 19.67,
#    'lowPrice': 19.55,
#    'closePrice': 19.56,
#    'change': -0.02,
#    'changePercent': -0.1,
#    'tradeVolume': 99782,
#    'tradeValue': 1955942890,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00930',
#    'name': '永豐ESG低碳高息',
#    'openPrice': 18.96,
#    'highPrice': 19.03,
#    'lowPrice': 18.92,
#    'closePrice': 18.94,
#    'change': -0.01,
#    'changePercent': -0.05,
#    'tradeVolume': 1775,
#    'tradeValue': 33694160,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00932',
#    'name': '兆豐永續高息等權',
#    'openPrice': 16.78,
#    'highPrice': 16.89,
#    'lowPrice': 16.78,
#    'closePrice': 16.85,
#    'change': 0.07,
#    'changePercent': 0.42,
#    'tradeVolume': 2522,
#    'tradeValue': 42472050,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00934',
#    'name': '中信成長高股息',
#    'openPrice': 17.97,
#    'highPrice': 18.03,
#    'lowPrice': 17.91,
#    'closePrice': 17.92,
#    'change': -0.04,
#    'changePercent': -0.22,
#    'tradeVolume': 7461,
#    'tradeValue': 134157170,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00935',
#    'name': '野村臺灣新科技50',
#    'openPrice': 18.64,
#    'highPrice': 18.7,
#    'lowPrice': 18.53,
#    'closePrice': 18.56,
#    'change': -0.03,
#    'changePercent': -0.16,
#    'tradeVolume': 5254,
#    'tradeValue': 97802940,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '00936',
#    'name': '台新永續高息中小',
#    'openPrice': 16.43,
#    'highPrice': 16.58,
#    'lowPrice': 16.39,
#    'closePrice': 16.52,
#    'change': 0.11,
#    'changePercent': 0.67,
#    'tradeVolume': 5214,
#    'tradeValue': 86101030,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '01001T',
#    'name': '土銀富邦R1',
#    'openPrice': 14.78,
#    'highPrice': 14.78,
#    'lowPrice': 14.6,
#    'closePrice': 14.78,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 8,
#    'tradeValue': 117600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '01002T',
#    'name': '土銀國泰R1',
#    'openPrice': 17.35,
#    'highPrice': 17.35,
#    'lowPrice': 17.21,
#    'closePrice': 17.25,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 437,
#    'tradeValue': 7538490,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '01004T',
#    'name': '土銀富邦R2',
#    'openPrice': 13.25,
#    'highPrice': 13.25,
#    'lowPrice': 13.22,
#    'closePrice': 13.25,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 77,
#    'tradeValue': 1019350,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '01007T',
#    'name': '兆豐國泰R2',
#    'openPrice': 16.85,
#    'highPrice': 16.9,
#    'lowPrice': 16.8,
#    'closePrice': 16.81,
#    'change': 0.01,
#    'changePercent': 0.06,
#    'tradeVolume': 269,
#    'tradeValue': 4533840,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '01009T',
#    'name': '王道圓滿R1',
#    'openPrice': 8.1,
#    'highPrice': 8.12,
#    'lowPrice': 8.07,
#    'closePrice': 8.12,
#    'change': -0.06,
#    'changePercent': -0.73,
#    'tradeVolume': 36,
#    'tradeValue': 291630,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '01010T',
#    'name': '京城樂富R1',
#    'openPrice': 10.04,
#    'highPrice': 10.1,
#    'lowPrice': 10.04,
#    'closePrice': 10.08,
#    'change': 0.03,
#    'changePercent': 0.3,
#    'tradeVolume': 203,
#    'tradeValue': 2041210,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '020000',
#    'name': '富邦特選蘋果N',
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 0,
#    'tradeValue': 0,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '020002',
#    'name': '元富新中國N',
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 0,
#    'tradeValue': 0,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '020007',
#    'name': '凱基臺灣500N',
#    'openPrice': 40.05,
#    'highPrice': 40.05,
#    'lowPrice': 40.05,
#    'closePrice': 40.05,
#    'change': 0.4,
#    'changePercent': 1.01,
#    'tradeVolume': 1,
#    'tradeValue': 40050,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '020011',
#    'name': '統一微波高息20N',
#    'openPrice': 8.45,
#    'highPrice': 8.45,
#    'lowPrice': 8.45,
#    'closePrice': 8.45,
#    'change': 0,
# ...
#   {'type': 'EQUITY',
#    'symbol': '5434',
#    'name': '崇越',
#    'openPrice': 197,
#    'highPrice': 200,
#    'lowPrice': 197,
#    'closePrice': 197.5,
#    'change': 3,
#    'changePercent': 1.54,
#    'tradeVolume': 1311,
#    'tradeValue': 260478000,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5469',
#    'name': '瀚宇博',
#    'openPrice': 56.7,
#    'highPrice': 58.3,
#    'lowPrice': 56.7,
#    'closePrice': 57.5,
#    'change': 0.9,
#    'changePercent': 1.59,
#    'tradeVolume': 2632,
#    'tradeValue': 151648000,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5471',
#    'name': '松翰',
#    'openPrice': 53.6,
#    'highPrice': 53.9,
#    'lowPrice': 52.2,
#    'closePrice': 52.5,
#    'change': -1.2,
#    'changePercent': -2.23,
#    'tradeVolume': 601,
#    'tradeValue': 31654000,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5484',
#    'name': '慧友',
#    'openPrice': 27.5,
#    'highPrice': 27.75,
#    'lowPrice': 27,
#    'closePrice': 27.75,
#    'change': 0.25,
#    'changePercent': 0.91,
#    'tradeVolume': 55,
#    'tradeValue': 1503350,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5515',
#    'name': '建國',
#    'openPrice': 17.75,
#    'highPrice': 17.75,
#    'lowPrice': 17.5,
#    'closePrice': 17.6,
#    'change': -0.1,
#    'changePercent': -0.56,
#    'tradeVolume': 649,
#    'tradeValue': 11423250,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5519',
#    'name': '隆大',
#    'openPrice': 35,
#    'highPrice': 35.05,
#    'lowPrice': 34.35,
#    'closePrice': 34.7,
#    'change': -0.3,
#    'changePercent': -0.86,
#    'tradeVolume': 564,
#    'tradeValue': 19574650,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5521',
#    'name': '工信',
#    'openPrice': 12.95,
#    'highPrice': 13.1,
#    'lowPrice': 12.6,
#    'closePrice': 12.6,
#    'change': -0.5,
#    'changePercent': -3.82,
#    'tradeVolume': 6698,
#    'tradeValue': 85566650,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5522',
#    'name': '遠雄',
#    'openPrice': 56.2,
#    'highPrice': 56.2,
#    'lowPrice': 56,
#    'closePrice': 56.1,
#    'change': -0.1,
#    'changePercent': -0.18,
#    'tradeVolume': 344,
#    'tradeValue': 19301300,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5525',
#    'name': '順天',
#    'openPrice': 27.65,
#    'highPrice': 28.15,
#    'lowPrice': 27.65,
#    'closePrice': 27.95,
#    'change': 0.3,
#    'changePercent': 1.08,
#    'tradeVolume': 232,
#    'tradeValue': 6494900,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5531',
#    'name': '鄉林',
#    'openPrice': 9.9,
#    'highPrice': 9.9,
#    'lowPrice': 9.75,
#    'closePrice': 9.8,
#    'change': -0.09,
#    'changePercent': -0.91,
#    'tradeVolume': 767,
#    'tradeValue': 7513650,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5533',
#    'name': '皇鼎',
#    'openPrice': 23.3,
#    'highPrice': 23.75,
#    'lowPrice': 23.3,
#    'closePrice': 23.75,
#    'change': 0.3,
#    'changePercent': 1.28,
#    'tradeVolume': 891,
#    'tradeValue': 21095600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5534',
#    'name': '長虹',
#    'openPrice': 78.1,
#    'highPrice': 78.7,
#    'lowPrice': 78.1,
#    'closePrice': 78.7,
#    'change': 0.6,
#    'changePercent': 0.77,
#    'tradeVolume': 447,
#    'tradeValue': 35112600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5538',
#    'name': '東明-KY',
#    'openPrice': 32.9,
#    'highPrice': 32.9,
#    'lowPrice': 32.65,
#    'closePrice': 32.65,
#    'change': -0.3,
#    'changePercent': -0.91,
#    'tradeVolume': 14,
#    'tradeValue': 458750,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5546',
#    'name': '永固-KY',
#    'openPrice': 31,
#    'highPrice': 32,
#    'lowPrice': 31,
#    'closePrice': 31.1,
#    'change': 0.1,
#    'changePercent': 0.32,
#    'tradeVolume': 13,
#    'tradeValue': 406700,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5607',
#    'name': '遠雄港',
#    'openPrice': 62,
#    'highPrice': 62.2,
#    'lowPrice': 61.2,
#    'closePrice': 61.5,
#    'change': -0.5,
#    'changePercent': -0.81,
#    'tradeVolume': 892,
#    'tradeValue': 54980700,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5608',
#    'name': '四維航',
#    'openPrice': 20.1,
#    'highPrice': 20.15,
#    'lowPrice': 19.65,
#    'closePrice': 20,
#    'change': -0.1,
#    'changePercent': -0.5,
#    'tradeVolume': 2234,
#    'tradeValue': 44333650,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5706',
#    'name': '鳳凰',
#    'openPrice': 61.7,
#    'highPrice': 62.2,
#    'lowPrice': 61.5,
#    'closePrice': 61.9,
#    'change': 0.2,
#    'changePercent': 0.32,
#    'tradeVolume': 281,
#    'tradeValue': 17386700,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5871',
#    'name': '中租-KY',
#    'openPrice': 174.5,
#    'highPrice': 175,
#    'lowPrice': 172.5,
#    'closePrice': 174,
#    'change': -0.5,
#    'changePercent': -0.29,
#    'tradeVolume': 3455,
#    'tradeValue': 599738500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5871A',
#    'name': '中租-KY甲特',
#    'openPrice': 96.8,
#    'highPrice': 96.8,
#    'lowPrice': 96.7,
#    'closePrice': 96.7,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 41,
#    'tradeValue': 3966200,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5876',
#    'name': '上海商銀',
#    'openPrice': 44.65,
#    'highPrice': 45.2,
#    'lowPrice': 44.55,
#    'closePrice': 44.55,
#    'change': -0.45,
#    'changePercent': -1,
#    'tradeVolume': 2293,
#    'tradeValue': 102574900,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5880',
#    'name': '合庫金',
#    'openPrice': 25.85,
#    'highPrice': 25.9,
#    'lowPrice': 25.7,
#    'closePrice': 25.8,
#    'change': -0.15,
#    'changePercent': -0.58,
#    'tradeVolume': 5548,
#    'tradeValue': 143237300,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5906',
#    'name': '台南-KY',
#    'openPrice': 60.3,
#    'highPrice': 60.4,
#    'lowPrice': 60.3,
#    'closePrice': 60.3,
#    'change': -0.1,
#    'changePercent': -0.17,
#    'tradeVolume': 12,
#    'tradeValue': 724600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '5907',
#    'name': '大洋-KY',
#    'openPrice': 11.05,
#    'highPrice': 11.05,
#    'lowPrice': 10.9,
#    'closePrice': 10.95,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 103,
#    'tradeValue': 1127350,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6005',
#    'name': '群益證',
#    'openPrice': 16.9,
#    'highPrice': 17.15,
#    'lowPrice': 16.85,
#    'closePrice': 17.05,
#    'change': 0.3,
#    'changePercent': 1.79,
#    'tradeVolume': 8539,
#    'tradeValue': 145516550,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6024',
#    'name': '群益期',
#    'openPrice': 54.9,
#    'highPrice': 55,
#    'lowPrice': 54.4,
#    'closePrice': 54.8,
#    'change': 0.3,
#    'changePercent': 0.55,
#    'tradeVolume': 564,
#    'tradeValue': 30821200,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6108',
#    'name': '競國',
#    'openPrice': 22.5,
#    'highPrice': 22.5,
#    'lowPrice': 22,
#    'closePrice': 22.05,
#    'change': -0.3,
#    'changePercent': -1.34,
#    'tradeVolume': 761,
#    'tradeValue': 16870050,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6112',
#    'name': '邁達特',
#    'openPrice': 70,
#    'highPrice': 70,
#    'lowPrice': 66.7,
#    'closePrice': 67.3,
#    'change': -4.6,
#    'changePercent': -6.4,
#    'tradeVolume': 8239,
#    'tradeValue': 558045000,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6115',
#    'name': '鎰勝',
#    'openPrice': 49.6,
#    'highPrice': 50,
#    'lowPrice': 49.5,
#    'closePrice': 49.95,
#    'change': 0.35,
#    'changePercent': 0.71,
#    'tradeVolume': 219,
#    'tradeValue': 10887250,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6116',
#    'name': '彩晶',
#    'openPrice': 11.35,
#    'highPrice': 11.45,
#    'lowPrice': 11.2,
#    'closePrice': 11.2,
#    'change': -0.15,
#    'changePercent': -1.32,
#    'tradeVolume': 8892,
#    'tradeValue': 100379300,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6117',
#    'name': '迎廣',
#    'openPrice': 74,
#    'highPrice': 76.3,
#    'lowPrice': 73.3,
#    'closePrice': 74.6,
#    'change': 1.3,
#    'changePercent': 1.77,
#    'tradeVolume': 2157,
#    'tradeValue': 161088800,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6120',
#    'name': '達運',
#    'openPrice': 15.75,
#    'highPrice': 15.75,
#    'lowPrice': 15.4,
#    'closePrice': 15.4,
#    'change': -0.25,
#    'changePercent': -1.6,
#    'tradeVolume': 3502,
#    'tradeValue': 54379750,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6128',
#    'name': '上福',
#    'openPrice': 34.35,
#    'highPrice': 34.65,
#    'lowPrice': 34.35,
#    'closePrice': 34.55,
#    'change': 0.2,
#    'changePercent': 0.58,
#    'tradeVolume': 290,
#    'tradeValue': 10003500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6133',
#    'name': '金橋',
#    'openPrice': 15.4,
#    'highPrice': 15.65,
#    'lowPrice': 15.25,
#    'closePrice': 15.25,
#    'change': -0.15,
#    'changePercent': -0.97,
#    'tradeVolume': 504,
#    'tradeValue': 7775100,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6136',
#    'name': '富爾特',
#    'openPrice': 24.7,
#    'highPrice': 25.25,
#    'lowPrice': 24.35,
#    'closePrice': 24.4,
#    'change': -0.3,
#    'changePercent': -1.21,
#    'tradeVolume': 924,
#    'tradeValue': 22889050,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6139',
#    'name': '亞翔',
#    'openPrice': 169.5,
#    'highPrice': 176,
#    'lowPrice': 169.5,
#    'closePrice': 175.5,
#    'change': 7,
#    'changePercent': 4.15,
#    'tradeVolume': 13382,
#    'tradeValue': 2329697500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6141',
#    'name': '柏承',
#    'openPrice': 22,
#    'highPrice': 22.1,
#    'lowPrice': 21.05,
#    'closePrice': 21.25,
#    'change': -0.75,
#    'changePercent': -3.41,
#    'tradeVolume': 5866,
#    'tradeValue': 126144150,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6142',
#    'name': '友勁',
#    'openPrice': 10.5,
#    'highPrice': 10.7,
#    'lowPrice': 10.5,
#    'closePrice': 10.6,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 273,
#    'tradeValue': 2888750,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6152',
#    'name': '百一',
#    'openPrice': 11.1,
#    'highPrice': 11.2,
#    'lowPrice': 10.9,
#    'closePrice': 11,
#    'change': -0.1,
#    'changePercent': -0.9,
#    'tradeVolume': 1133,
#    'tradeValue': 12529400,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6153',
#    'name': '嘉聯益',
#    'openPrice': 20.9,
#    'highPrice': 20.9,
#    'lowPrice': 20.65,
#    'closePrice': 20.7,
#    'change': -0.15,
#    'changePercent': -0.72,
#    'tradeVolume': 996,
#    'tradeValue': 20611850,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6155',
#    'name': '鈞寶',
#    'openPrice': 27.45,
#    'highPrice': 27.45,
#    'lowPrice': 26.85,
#    'closePrice': 26.85,
#    'change': -0.35,
#    'changePercent': -1.29,
#    'tradeVolume': 154,
#    'tradeValue': 4162700,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6164',
#    'name': '華興',
#    'openPrice': 16.25,
#    'highPrice': 16.3,
#    'lowPrice': 15.85,
#    'closePrice': 15.95,
#    'change': -0.35,
#    'changePercent': -2.15,
#    'tradeVolume': 2144,
#    'tradeValue': 34217050,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6165',
#    'name': '浪凡',
#    'openPrice': 50,
#    'highPrice': 51.2,
#    'lowPrice': 48.8,
#    'closePrice': 49.55,
#    'change': -0.75,
#    'changePercent': -1.49,
#    'tradeVolume': 2395,
#    'tradeValue': 119259600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6166',
#    'name': '凌華',
#    'openPrice': 63.9,
#    'highPrice': 65.7,
#    'lowPrice': 63.3,
#    'closePrice': 64.5,
#    'change': 0.7,
#    'changePercent': 1.1,
#    'tradeVolume': 782,
#    'tradeValue': 50706000,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6168',
#    'name': '宏齊',
#    'openPrice': 26.8,
#    'highPrice': 26.8,
#    'lowPrice': 26.25,
#    'closePrice': 26.35,
#    'change': -0.45,
#    'changePercent': -1.68,
#    'tradeVolume': 1188,
#    'tradeValue': 31441350,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6176',
#    'name': '瑞儀',
#    'openPrice': 146.5,
#    'highPrice': 147,
#    'lowPrice': 142.5,
#    'closePrice': 144,
#    'change': -3.5,
#    'changePercent': -2.37,
#    'tradeVolume': 5207,
#    'tradeValue': 753437500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6177',
#    'name': '達麗',
#    'openPrice': 35.2,
#    'highPrice': 35.3,
#    'lowPrice': 34.95,
#    'closePrice': 35.05,
#    'change': 0.15,
#    'changePercent': 0.43,
#    'tradeVolume': 628,
#    'tradeValue': 22018150,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6183',
#    'name': '關貿',
#    'openPrice': 69.8,
#    'highPrice': 70,
#    'lowPrice': 69.5,
#    'closePrice': 69.9,
#    'change': 0.1,
#    'changePercent': 0.14,
#    'tradeVolume': 37,
#    'tradeValue': 2583900,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6184',
#    'name': '大豐電',
#    'openPrice': 52,
#    'highPrice': 52,
#    'lowPrice': 51.7,
#    'closePrice': 51.9,
#    'change': -0.4,
#    'changePercent': -0.76,
#    'tradeVolume': 63,
#    'tradeValue': 3264600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6189',
#    'name': '豐藝',
#    'openPrice': 79.8,
#    'highPrice': 81.9,
#    'lowPrice': 78.5,
#    'closePrice': 78.5,
#    'change': -0.5,
#    'changePercent': -0.63,
#    'tradeVolume': 6811,
#    'tradeValue': 546663100,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6191',
#    'name': '精成科',
#    'openPrice': 65.7,
#    'highPrice': 67,
#    'lowPrice': 65.6,
#    'closePrice': 66,
#    'change': 0.7,
#    'changePercent': 1.07,
#    'tradeVolume': 2625,
#    'tradeValue': 174084000,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6192',
#    'name': '巨路',
#    'openPrice': 98.8,
#    'highPrice': 101,
#    'lowPrice': 98.6,
#    'closePrice': 101,
#    'change': 2.9,
#    'changePercent': 2.96,
#    'tradeVolume': 489,
#    'tradeValue': 48899600,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6196',
#    'name': '帆宣',
#    'openPrice': 159,
#    'highPrice': 160.5,
#    'lowPrice': 158.5,
#    'closePrice': 158.5,
#    'change': -0.5,
#    'changePercent': -0.31,
#    'tradeVolume': 1623,
#    'tradeValue': 258362500,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6197',
#    'name': '佳必琪',
#    'openPrice': 96,
#    'highPrice': 96.4,
#    'lowPrice': 93.4,
#    'closePrice': 93.6,
#    'change': -1.7,
#    'changePercent': -1.78,
#    'tradeVolume': 2321,
#    'tradeValue': 219375900,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6201',
#    'name': '亞弘電',
#    'openPrice': 68.8,
#    'highPrice': 69.9,
#    'lowPrice': 65.9,
#    'closePrice': 66.1,
#    'change': 0.6,
#    'changePercent': 0.92,
#    'tradeVolume': 270,
#    'tradeValue': 18155100,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6202',
#    'name': '盛群',
#    'openPrice': 60,
#    'highPrice': 60,
#    'lowPrice': 59.7,
#    'closePrice': 59.8,
#    'change': -0.2,
#    'changePercent': -0.33,
#    'tradeVolume': 1214,
#    'tradeValue': 72621100,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6205',
#    'name': '詮欣',
#    'openPrice': 81.2,
#    'highPrice': 82.8,
#    'lowPrice': 81,
#    'closePrice': 81.5,
#    'change': -0.6,
#    'changePercent': -0.73,
#    'tradeVolume': 1083,
#    'tradeValue': 88291700,
#    'lastUpdated': 1709271000000000},
#   {'type': 'EQUITY',
#    'symbol': '6206',
#    'name': '飛捷',
#    'openPrice': 71.3,
#    'highPrice': 71.3,
#    'lowPrice': 70,
#    'closePrice': 70.3,
#    'change': -1,
#    'changePercent': -1.4,
#    'tradeVolume': 268,
#    'tradeValue': 18920100,
#    'lastUpdated': 1709271000000000},
#   ...]}

# %%
#取得股票漲跌幅排行
stock.snapshot.movers(market='TSE', direction='up', change='percent')
# Out:
# {'date': '2024-02-23',
#  'time': '140000',
#  'market': 'TSE',
#  'change': 'percent',
#  'data': [{'type': 'EQUITY',
#    'symbol': '3312',
#    'name': '弘憶股',
#    'openPrice': 36,
#    'highPrice': 38.65,
#    'lowPrice': 35.9,
#    'closePrice': 38.65,
#    'change': 3.5,
#    'changePercent': 9.96,
#    'tradeVolume': 12552,
#    'tradeValue': 476702750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1809',
#    'name': '中釉',
#    'openPrice': 26.4,
#    'highPrice': 28.25,
#    'lowPrice': 26.25,
#    'closePrice': 28.25,
#    'change': 2.55,
#    'changePercent': 9.92,
#    'tradeVolume': 13829,
#    'tradeValue': 386896600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4526',
#    'name': '東台',
#    'openPrice': 22.8,
#    'highPrice': 22.8,
#    'lowPrice': 22.5,
#    'closePrice': 22.8,
#    'change': 2.05,
#    'changePercent': 9.88,
#    'tradeVolume': 5956,
#    'tradeValue': 135777750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6937',
#    'name': '天虹',
#    'openPrice': 198.5,
#    'highPrice': 217,
#    'lowPrice': 198.5,
#    'closePrice': 217,
#    'change': 19.5,
#    'changePercent': 9.87,
#    'tradeVolume': 1026,
#    'tradeValue': 218529000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3583',
#    'name': '辛耘',
#    'openPrice': 258,
#    'highPrice': 278.5,
#    'lowPrice': 256.5,
#    'closePrice': 278.5,
#    'change': 25,
#    'changePercent': 9.86,
#    'tradeVolume': 9985,
#    'tradeValue': 2714591500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2467',
#    'name': '志聖',
#    'openPrice': 135.5,
#    'highPrice': 136,
#    'lowPrice': 135.5,
#    'closePrice': 136,
#    'change': 12,
#    'changePercent': 9.68,
#    'tradeVolume': 1534,
#    'tradeValue': 208339500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4588',
#    'name': '玖鼎電力',
#    'openPrice': 98,
#    'highPrice': 101.5,
#    'lowPrice': 91.5,
#    'closePrice': 101.5,
#    'change': 8.9,
#    'changePercent': 9.61,
#    'tradeVolume': 4469,
#    'tradeValue': 437420200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2454',
#    'name': '聯發科',
#    'openPrice': 1035,
#    'highPrice': 1100,
#    'lowPrice': 1010,
#    'closePrice': 1100,
#    'change': 85,
#    'changePercent': 8.37,
#    'tradeVolume': 23373,
#    'tradeValue': 24862155000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1519',
#    'name': '華城',
#    'openPrice': 528,
#    'highPrice': 568,
#    'lowPrice': 515,
#    'closePrice': 560,
#    'change': 43,
#    'changePercent': 8.32,
#    'tradeVolume': 15651,
#    'tradeValue': 8479882000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4770',
#    'name': '上品',
#    'openPrice': 351.5,
#    'highPrice': 385,
#    'lowPrice': 346,
#    'closePrice': 378,
#    'change': 28,
#    'changePercent': 8,
#    'tradeVolume': 3705,
#    'tradeValue': 1378658500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1342',
#    'name': '八貫',
#    'openPrice': 120.5,
#    'highPrice': 125,
#    'lowPrice': 120.5,
#    'closePrice': 123,
#    'change': 9,
#    'changePercent': 7.89,
#    'tradeVolume': 3478,
#    'tradeValue': 427371000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1513',
#    'name': '中興電',
#    'openPrice': 135,
#    'highPrice': 146,
#    'lowPrice': 131.5,
#    'closePrice': 143,
#    'change': 9.5,
#    'changePercent': 7.12,
#    'tradeVolume': 78206,
#    'tradeValue': 11032031000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6789',
#    'name': '采鈺',
#    'openPrice': 311,
#    'highPrice': 333,
#    'lowPrice': 310.5,
#    'closePrice': 327.5,
#    'change': 20,
#    'changePercent': 6.5,
#    'tradeVolume': 10306,
#    'tradeValue': 3359278000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2405',
#    'name': '輔信',
#    'openPrice': 19.8,
#    'highPrice': 21,
#    'lowPrice': 19.65,
#    'closePrice': 20.55,
#    'change': 1.25,
#    'changePercent': 6.48,
#    'tradeVolume': 41176,
#    'tradeValue': 844020050,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6141',
#    'name': '柏承',
#    'openPrice': 18.3,
#    'highPrice': 19.45,
#    'lowPrice': 18.1,
#    'closePrice': 19.35,
#    'change': 1.15,
#    'changePercent': 6.32,
#    'tradeVolume': 8898,
#    'tradeValue': 167818950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6526',
#    'name': '達發',
#    'openPrice': 658,
#    'highPrice': 693,
#    'lowPrice': 656,
#    'closePrice': 688,
#    'change': 38,
#    'changePercent': 5.85,
#    'tradeVolume': 4856,
#    'tradeValue': 3287859000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6776',
#    'name': '展碁國際',
#    'openPrice': 62.6,
#    'highPrice': 66.4,
#    'lowPrice': 62.1,
#    'closePrice': 64.5,
#    'change': 3.5,
#    'changePercent': 5.74,
#    'tradeVolume': 2673,
#    'tradeValue': 171861200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6288',
#    'name': '聯嘉',
#    'openPrice': 33.9,
#    'highPrice': 36,
#    'lowPrice': 33.4,
#    'closePrice': 35.4,
#    'change': 1.8,
#    'changePercent': 5.36,
#    'tradeVolume': 18640,
#    'tradeValue': 650065600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5269',
#    'name': '祥碩',
#    'openPrice': 2190,
#    'highPrice': 2285,
#    'lowPrice': 2185,
#    'closePrice': 2280,
#    'change': 115,
#    'changePercent': 5.31,
#    'tradeVolume': 1844,
#    'tradeValue': 4141410000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2331',
#    'name': '精英',
#    'openPrice': 29.85,
#    'highPrice': 32.15,
#    'lowPrice': 29.8,
#    'closePrice': 31,
#    'change': 1.5,
#    'changePercent': 5.08,
#    'tradeVolume': 20961,
#    'tradeValue': 654416300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6168',
#    'name': '宏齊',
#    'openPrice': 28.15,
#    'highPrice': 30.2,
#    'lowPrice': 28.15,
#    'closePrice': 29.3,
#    'change': 1.35,
#    'changePercent': 4.83,
#    'tradeVolume': 22584,
#    'tradeValue': 661180300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1717',
#    'name': '長興',
#    'openPrice': 30.8,
#    'highPrice': 32.45,
#    'lowPrice': 30.5,
#    'closePrice': 31.75,
#    'change': 1.45,
#    'changePercent': 4.79,
#    'tradeVolume': 16839,
#    'tradeValue': 535795600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8114',
#    'name': '振樺電',
#    'openPrice': 127.5,
#    'highPrice': 129.5,
#    'lowPrice': 123.5,
#    'closePrice': 123.5,
#    'change': 5.5,
#    'changePercent': 4.66,
#    'tradeVolume': 2654,
#    'tradeValue': 339432500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6165',
#    'name': '浪凡',
#    'openPrice': 46,
#    'highPrice': 49.3,
#    'lowPrice': 45.6,
#    'closePrice': 47.5,
#    'change': 2.1,
#    'changePercent': 4.63,
#    'tradeVolume': 7172,
#    'tradeValue': 344278950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1536',
#    'name': '和大',
#    'openPrice': 53,
#    'highPrice': 54.9,
#    'lowPrice': 52.9,
#    'closePrice': 54.6,
#    'change': 2.4,
#    'changePercent': 4.6,
#    'tradeVolume': 14759,
#    'tradeValue': 798866600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4560',
#    'name': '強信-KY',
#    'openPrice': 36.3,
#    'highPrice': 38,
#    'lowPrice': 36.15,
#    'closePrice': 37.9,
#    'change': 1.6,
#    'changePercent': 4.41,
#    'tradeVolume': 233,
#    'tradeValue': 8577000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '910322',
#    'name': '康師傅-DR',
#    'openPrice': 16.05,
#    'highPrice': 17.25,
#    'lowPrice': 16.05,
#    'closePrice': 16.9,
#    'change': 0.7,
#    'changePercent': 4.32,
#    'tradeVolume': 608,
#    'tradeValue': 10120700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1514',
#    'name': '亞力',
#    'openPrice': 86.4,
#    'highPrice': 92.5,
#    'lowPrice': 85,
#    'closePrice': 89.5,
#    'change': 3.7,
#    'changePercent': 4.31,
#    'tradeVolume': 59058,
#    'tradeValue': 5285711800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '9906',
#    'name': '欣巴巴',
#    'openPrice': 68,
#    'highPrice': 70.5,
#    'lowPrice': 67.6,
#    'closePrice': 70.4,
#    'change': 2.8,
#    'changePercent': 4.14,
#    'tradeVolume': 713,
#    'tradeValue': 49141600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6579',
#    'name': '研揚',
#    'openPrice': 164,
#    'highPrice': 178.5,
#    'lowPrice': 163.5,
#    'closePrice': 169,
#    'change': 6.5,
#    'changePercent': 4,
#    'tradeVolume': 3390,
#    'tradeValue': 589837000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2383',
#    'name': '台光電',
#    'openPrice': 507,
#    'highPrice': 520,
#    'lowPrice': 500,
#    'closePrice': 510,
#    'change': 19.5,
#    'changePercent': 3.98,
#    'tradeVolume': 8291,
#    'tradeValue': 4227265000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2527',
#    'name': '宏璟',
#    'openPrice': 30.25,
#    'highPrice': 31.4,
#    'lowPrice': 30.25,
#    'closePrice': 31.4,
#    'change': 1.15,
#    'changePercent': 3.8,
#    'tradeVolume': 1217,
#    'tradeValue': 37810400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2031',
#    'name': '新光鋼',
#    'openPrice': 60.6,
#    'highPrice': 63.9,
#    'lowPrice': 60.2,
#    'closePrice': 62.8,
#    'change': 2.3,
#    'changePercent': 3.8,
#    'tradeVolume': 7708,
#    'tradeValue': 483437900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1530',
#    'name': '亞崴',
#    'openPrice': 32.3,
#    'highPrice': 33.95,
#    'lowPrice': 32.3,
#    'closePrice': 33.2,
#    'change': 1.2,
#    'changePercent': 3.75,
#    'tradeVolume': 402,
#    'tradeValue': 13427900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00893',
#    'name': '國泰智能電動車',
#    'openPrice': 19.53,
#    'highPrice': 19.69,
#    'lowPrice': 19.53,
#    'closePrice': 19.68,
#    'change': 0.69,
#    'changePercent': 3.63,
#    'tradeVolume': 20546,
#    'tradeValue': 403505210,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3515',
#    'name': '華擎',
#    'openPrice': 245,
#    'highPrice': 254.5,
#    'lowPrice': 240,
#    'closePrice': 249.5,
#    'change': 8.5,
#    'changePercent': 3.53,
#    'tradeVolume': 2300,
#    'tradeValue': 571215000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4720',
#    'name': '德淵',
#    'openPrice': 17.45,
#    'highPrice': 18,
#    'lowPrice': 17.2,
#    'closePrice': 17.9,
#    'change': 0.6,
#    'changePercent': 3.47,
#    'tradeVolume': 2472,
#    'tradeValue': 43744750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3450',
#    'name': '聯鈞',
#    'openPrice': 68.9,
#    'highPrice': 73.8,
#    'lowPrice': 67.7,
#    'closePrice': 70.4,
#    'change': 2.3,
#    'changePercent': 3.38,
#    'tradeVolume': 33589,
#    'tradeValue': 2392405100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2360',
#    'name': '致茂',
#    'openPrice': 235.5,
#    'highPrice': 251,
#    'lowPrice': 235,
#    'closePrice': 239,
#    'change': 7.5,
#    'changePercent': 3.24,
#    'tradeVolume': 8523,
#    'tradeValue': 2064771000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00895',
#    'name': '富邦未來車',
#    'openPrice': 23.22,
#    'highPrice': 23.3,
#    'lowPrice': 23.22,
#    'closePrice': 23.29,
#    'change': 0.72,
#    'changePercent': 3.19,
#    'tradeVolume': 4281,
#    'tradeValue': 99596640,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1316',
#    'name': '上曜',
#    'openPrice': 17.35,
#    'highPrice': 18.55,
#    'lowPrice': 17.1,
#    'closePrice': 17.85,
#    'change': 0.55,
#    'changePercent': 3.18,
#    'tradeVolume': 44453,
#    'tradeValue': 798281900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3702',
#    'name': '大聯大',
#    'openPrice': 92.2,
#    'highPrice': 95.5,
#    'lowPrice': 92.2,
#    'closePrice': 94.4,
#    'change': 2.9,
#    'changePercent': 3.17,
#    'tradeVolume': 7003,
#    'tradeValue': 659957700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2059',
#    'name': '川湖',
#    'openPrice': 1375,
#    'highPrice': 1390,
#    'lowPrice': 1315,
#    'closePrice': 1355,
#    'change': 40,
#    'changePercent': 3.04,
#    'tradeVolume': 4129,
#    'tradeValue': 5584105000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2371',
#    'name': '大同',
#    'openPrice': 45.6,
#    'highPrice': 47.45,
#    'lowPrice': 44.7,
#    'closePrice': 46.75,
#    'change': 1.35,
#    'changePercent': 2.97,
#    'tradeVolume': 49141,
#    'tradeValue': 2283800200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2465',
#    'name': '麗臺',
#    'openPrice': 124,
#    'highPrice': 124,
#    'lowPrice': 117,
#    'closePrice': 123,
#    'change': 3.5,
#    'changePercent': 2.93,
#    'tradeVolume': 1381,
#    'tradeValue': 168232000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6756',
#    'name': '威鋒電子',
#    'openPrice': 263,
#    'highPrice': 274,
#    'lowPrice': 262.5,
#    'closePrice': 266.5,
#    'change': 7.5,
#    'changePercent': 2.9,
#    'tradeVolume': 1720,
#    'tradeValue': 463061500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2379',
#    'name': '瑞昱',
#    'openPrice': 554,
#    'highPrice': 563,
#    'lowPrice': 540,
#    'closePrice': 547,
#    'change': 15,
#    'changePercent': 2.82,
#    'tradeVolume': 12913,
#    'tradeValue': 7167055000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3596',
#    'name': '智易',
#    'openPrice': 182,
#    'highPrice': 186,
#    'lowPrice': 180,
#    'closePrice': 183.5,
#    'change': 5,
#    'changePercent': 2.8,
#    'tradeVolume': 6069,
#    'tradeValue': 1115338000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6438',
#    'name': '迅得',
#    'openPrice': 110.5,
#    'highPrice': 114.5,
#    'lowPrice': 109.5,
#    'closePrice': 112,
#    'change': 3,
#    'changePercent': 2.75,
#    'tradeVolume': 3908,
#    'tradeValue': 440570500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00647L',
#    'name': '元大S&P500正2',
#    'openPrice': 78.65,
#    'highPrice': 79,
#    'lowPrice': 78.65,
#    'closePrice': 78.95,
#    'change': 2.1,
#    'changePercent': 2.73,
#    'tradeVolume': 95,
#    'tradeValue': 7485100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2250',
#    'name': 'IKKA-KY',
#    'openPrice': 88.2,
#    'highPrice': 90.7,
#    'lowPrice': 88.1,
#    'closePrice': 90.2,
#    'change': 2.4,
#    'changePercent': 2.73,
#    'tradeVolume': 180,
#    'tradeValue': 16111800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00670L',
#    'name': '富邦NASDAQ正2',
#    'openPrice': 111,
#    'highPrice': 111.35,
#    'lowPrice': 110.95,
#    'closePrice': 111.35,
#    'change': 2.95,
#    'changePercent': 2.72,
#    'tradeVolume': 1631,
#    'tradeValue': 181229550,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3535',
#    'name': '晶彩科',
#    'openPrice': 25.5,
#    'highPrice': 26.6,
#    'lowPrice': 24.95,
#    'closePrice': 25.3,
#    'change': 0.65,
#    'changePercent': 2.64,
#    'tradeVolume': 9282,
#    'tradeValue': 238973500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00757',
#    'name': '統一FANG+',
#    'openPrice': 76.6,
#    'highPrice': 76.85,
#    'lowPrice': 76.6,
#    'closePrice': 76.8,
#    'change': 1.95,
#    'changePercent': 2.61,
#    'tradeVolume': 2805,
#    'tradeValue': 215254650,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6669',
#    'name': '緯穎',
#    'openPrice': 2175,
#    'highPrice': 2235,
#    'lowPrice': 2135,
#    'closePrice': 2170,
#    'change': 55,
#    'changePercent': 2.6,
#    'tradeVolume': 3323,
#    'tradeValue': 7263160000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4977',
#    'name': '眾達-KY',
#    'openPrice': 77.6,
#    'highPrice': 80.2,
#    'lowPrice': 77.2,
#    'closePrice': 79,
#    'change': 2,
#    'changePercent': 2.6,
#    'tradeVolume': 3602,
#    'tradeValue': 285350400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2543',
#    'name': '皇昌',
#    'openPrice': 35.9,
#    'highPrice': 38,
#    'lowPrice': 35,
#    'closePrice': 35.5,
#    'change': 0.9,
#    'changePercent': 2.6,
#    'tradeVolume': 11800,
#    'tradeValue': 430226500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2460',
#    'name': '建通',
#    'openPrice': 38.4,
#    'highPrice': 40.45,
#    'lowPrice': 38,
#    'closePrice': 39.75,
#    'change': 1,
#    'changePercent': 2.58,
#    'tradeVolume': 8604,
#    'tradeValue': 338688000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00653L',
#    'name': '富邦印度正2',
#    'openPrice': 57.55,
#    'highPrice': 58.35,
#    'lowPrice': 57.55,
#    'closePrice': 58.1,
#    'change': 1.45,
#    'changePercent': 2.56,
#    'tradeVolume': 550,
#    'tradeValue': 31992450,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2368',
#    'name': '金像電',
#    'openPrice': 261,
#    'highPrice': 267.5,
#    'lowPrice': 258,
#    'closePrice': 262,
#    'change': 6.5,
#    'changePercent': 2.54,
#    'tradeVolume': 15412,
#    'tradeValue': 4060522000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4994',
#    'name': '傳奇',
#    'openPrice': 75,
#    'highPrice': 78.5,
#    'lowPrice': 74.7,
#    'closePrice': 77.1,
#    'change': 1.9,
#    'changePercent': 2.53,
#    'tradeVolume': 473,
#    'tradeValue': 36380300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6115',
#    'name': '鎰勝',
#    'openPrice': 49.35,
#    'highPrice': 51.3,
#    'lowPrice': 49.35,
#    'closePrice': 50.6,
#    'change': 1.25,
#    'changePercent': 2.53,
#    'tradeVolume': 808,
#    'tradeValue': 40653700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2495',
#    'name': '普安',
#    'openPrice': 22.05,
#    'highPrice': 23.25,
#    'lowPrice': 22.05,
#    'closePrice': 22.45,
#    'change': 0.55,
#    'changePercent': 2.51,
#    'tradeVolume': 5370,
#    'tradeValue': 122276250,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2488',
#    'name': '漢平',
#    'openPrice': 41.95,
#    'highPrice': 42.65,
#    'lowPrice': 41.8,
#    'closePrice': 42.5,
#    'change': 1,
#    'changePercent': 2.41,
#    'tradeVolume': 1453,
#    'tradeValue': 61499050,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6257',
#    'name': '矽格',
#    'openPrice': 72.5,
#    'highPrice': 75,
#    'lowPrice': 72,
#    'closePrice': 72.5,
#    'change': 1.7,
#    'changePercent': 2.4,
#    'tradeVolume': 22220,
#    'tradeValue': 1630891000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2420',
#    'name': '新巨',
#    'openPrice': 50.5,
#    'highPrice': 52,
#    'lowPrice': 49.85,
#    'closePrice': 51.7,
#    'change': 1.2,
#    'changePercent': 2.38,
#    'tradeVolume': 1361,
#    'tradeValue': 69350200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00852L',
#    'name': '國泰美國道瓊正2',
#    'openPrice': 24.16,
#    'highPrice': 24.29,
#    'lowPrice': 24.16,
#    'closePrice': 24.29,
#    'change': 0.56,
#    'changePercent': 2.36,
#    'tradeVolume': 259,
#    'tradeValue': 6276080,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2305',
#    'name': '全友',
#    'openPrice': 23.7,
#    'highPrice': 24.3,
#    'lowPrice': 23.7,
#    'closePrice': 24.1,
#    'change': 0.55,
#    'changePercent': 2.34,
#    'tradeVolume': 1293,
#    'tradeValue': 31062200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00762',
#    'name': '元大全球AI',
#    'openPrice': 56.75,
#    'highPrice': 57.3,
#    'lowPrice': 56.75,
#    'closePrice': 57.2,
#    'change': 1.3,
#    'changePercent': 2.33,
#    'tradeVolume': 983,
#    'tradeValue': 56188500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '9921',
#    'name': '巨大',
#    'openPrice': 195,
#    'highPrice': 200.5,
#    'lowPrice': 194.5,
#    'closePrice': 200,
#    'change': 4.5,
#    'changePercent': 2.3,
#    'tradeVolume': 1694,
#    'tradeValue': 336860500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2239',
#    'name': '英利-KY',
#    'openPrice': 57.1,
#    'highPrice': 58.4,
#    'lowPrice': 56.5,
#    'closePrice': 58.4,
#    'change': 1.3,
#    'changePercent': 2.28,
#    'tradeVolume': 59,
#    'tradeValue': 3395800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4755',
#    'name': '三福化',
#    'openPrice': 134.5,
#    'highPrice': 142.5,
#    'lowPrice': 133.5,
#    'closePrice': 136,
#    'change': 3,
#    'changePercent': 2.26,
#    'tradeVolume': 1840,
#    'tradeValue': 253381000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2429',
#    'name': '銘旺科',
#    'openPrice': 20.8,
#    'highPrice': 21.45,
#    'lowPrice': 20.55,
#    'closePrice': 20.8,
#    'change': 0.45,
#    'changePercent': 2.21,
#    'tradeVolume': 249,
#    'tradeValue': 5234250,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5388',
#    'name': '中磊',
#    'openPrice': 137,
#    'highPrice': 140.5,
#    'lowPrice': 134,
#    'closePrice': 139.5,
#    'change': 3,
#    'changePercent': 2.2,
#    'tradeVolume': 13876,
#    'tradeValue': 1914024500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3711',
#    'name': '日月光投控',
#    'openPrice': 140,
#    'highPrice': 143,
#    'lowPrice': 139,
#    'closePrice': 141.5,
#    'change': 3,
#    'changePercent': 2.17,
#    'tradeVolume': 14274,
#    'tradeValue': 2017298000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00926',
#    'name': '凱基全球菁英55',
#    'openPrice': 19.3,
#    'highPrice': 19.35,
#    'lowPrice': 19.28,
#    'closePrice': 19.35,
#    'change': 0.41,
#    'changePercent': 2.16,
#    'tradeVolume': 537,
#    'tradeValue': 10375800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4576',
#    'name': '大銀微系統',
#    'openPrice': 72,
#    'highPrice': 73.5,
#    'lowPrice': 70.9,
#    'closePrice': 71.4,
#    'change': 1.5,
#    'changePercent': 2.15,
#    'tradeVolume': 327,
#    'tradeValue': 23572700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2462',
#    'name': '良得電',
#    'openPrice': 37.35,
#    'highPrice': 38.75,
#    'lowPrice': 37.25,
#    'closePrice': 38.1,
#    'change': 0.8,
#    'changePercent': 2.14,
#    'tradeVolume': 2436,
#    'tradeValue': 93192050,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3563',
#    'name': '牧德',
#    'openPrice': 315.5,
#    'highPrice': 323.5,
#    'lowPrice': 308,
#    'closePrice': 315,
#    'change': 6.5,
#    'changePercent': 2.11,
#    'tradeVolume': 2208,
#    'tradeValue': 698314000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00770',
#    'name': '國泰北美科技',
#    'openPrice': 40.56,
#    'highPrice': 40.65,
#    'lowPrice': 40.53,
#    'closePrice': 40.65,
#    'change': 0.83,
#    'changePercent': 2.08,
#    'tradeVolume': 12542,
#    'tradeValue': 508891400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00876',
#    'name': '元大全球5G',
#    'openPrice': 36.15,
#    'highPrice': 36.49,
#    'lowPrice': 36.15,
#    'closePrice': 36.48,
#    'change': 0.74,
#    'changePercent': 2.07,
#    'tradeVolume': 2726,
#    'tradeValue': 99215360,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2302',
#    'name': '麗正',
#    'openPrice': 19.8,
#    'highPrice': 20.3,
#    'lowPrice': 19.75,
#    'closePrice': 19.85,
#    'change': 0.4,
#    'changePercent': 2.06,
#    'tradeVolume': 1862,
#    'tradeValue': 37259300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6239',
#    'name': '力成',
#    'openPrice': 147.5,
#    'highPrice': 151.5,
#    'lowPrice': 147,
#    'closePrice': 149.5,
#    'change': 3,
#    'changePercent': 2.05,
#    'tradeVolume': 7117,
#    'tradeValue': 1064002000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3413',
#    'name': '京鼎',
#    'openPrice': 247.5,
#    'highPrice': 254.5,
#    'lowPrice': 244.5,
#    'closePrice': 250,
#    'change': 5,
#    'changePercent': 2.04,
#    'tradeVolume': 4551,
#    'tradeValue': 1140327000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2537',
#    'name': '聯上發',
#    'openPrice': 9.87,
#    'highPrice': 10.1,
#    'lowPrice': 9.81,
#    'closePrice': 10.05,
#    'change': 0.2,
#    'changePercent': 2.03,
#    'tradeVolume': 3607,
#    'tradeValue': 35962710,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3029',
#    'name': '零壹',
#    'openPrice': 71.8,
#    'highPrice': 73.5,
#    'lowPrice': 71.2,
#    'closePrice': 72.5,
#    'change': 1.4,
#    'changePercent': 1.97,
#    'tradeVolume': 2676,
#    'tradeValue': 194120000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00911',
#    'name': '兆豐洲際半導體',
#    'openPrice': 25.32,
#    'highPrice': 25.68,
#    'lowPrice': 25.32,
#    'closePrice': 25.58,
#    'change': 0.49,
#    'changePercent': 1.95,
#    'tradeVolume': 947,
#    'tradeValue': 24252480,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3653',
#    'name': '健策',
#    'openPrice': 853,
#    'highPrice': 876,
#    'lowPrice': 848,
#    'closePrice': 855,
#    'change': 16,
#    'changePercent': 1.91,
#    'tradeVolume': 1501,
#    'tradeValue': 1292004000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1504',
#    'name': '東元',
#    'openPrice': 47.5,
#    'highPrice': 48.15,
#    'lowPrice': 47.2,
#    'closePrice': 47.95,
#    'change': 0.9,
#    'changePercent': 1.91,
#    'tradeVolume': 12971,
#    'tradeValue': 620375350,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00891',
#    'name': '中信關鍵半導體',
#    'openPrice': 17.5,
#    'highPrice': 17.7,
#    'lowPrice': 17.42,
#    'closePrice': 17.65,
#    'change': 0.33,
#    'changePercent': 1.91,
#    'tradeVolume': 24804,
#    'tradeValue': 436034650,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2114',
#    'name': '鑫永銓',
#    'openPrice': 107,
#    'highPrice': 109,
#    'lowPrice': 107,
#    'closePrice': 108,
#    'change': 2,
#    'changePercent': 1.89,
#    'tradeVolume': 97,
#    'tradeValue': 10457000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2030',
#    'name': '彰源',
#    'openPrice': 18.9,
#    'highPrice': 19.25,
#    'lowPrice': 18.85,
#    'closePrice': 19.2,
#    'change': 0.35,
#    'changePercent': 1.86,
#    'tradeVolume': 873,
#    'tradeValue': 16598900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1512',
#    'name': '瑞利',
#    'openPrice': 10.85,
#    'highPrice': 11.1,
#    'lowPrice': 10.8,
#    'closePrice': 11,
#    'change': 0.2,
#    'changePercent': 1.85,
#    'tradeVolume': 72,
#    'tradeValue': 789800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3311',
#    'name': '閎暉',
#    'openPrice': 41.95,
#    'highPrice': 43.1,
#    'lowPrice': 41.6,
#    'closePrice': 42.65,
#    'change': 0.75,
#    'changePercent': 1.79,
#    'tradeVolume': 1259,
#    'tradeValue': 53192600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5225',
#    'name': '東科-KY',
#    'openPrice': 90.1,
#    'highPrice': 91.6,
#    'lowPrice': 89.4,
#    'closePrice': 91.1,
#    'change': 1.6,
#    'changePercent': 1.79,
#    'tradeVolume': 1073,
#    'tradeValue': 97302500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00909',
#    'name': '國泰數位支付服務',
#    'openPrice': 24.82,
#    'highPrice': 24.82,
#    'lowPrice': 24.62,
#    'closePrice': 24.65,
#    'change': 0.43,
#    'changePercent': 1.78,
#    'tradeVolume': 532,
#    'tradeValue': 13148530,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00935',
#    'name': '野村臺灣新科技50',
#    'openPrice': 18.39,
#    'highPrice': 18.52,
#    'lowPrice': 18.3,
#    'closePrice': 18.52,
#    'change': 0.32,
#    'changePercent': 1.76,
#    'tradeVolume': 11995,
#    'tradeValue': 221281490,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1470',
#    'name': '大統新創',
#    'openPrice': 20.45,
#    'highPrice': 20.5,
#    'lowPrice': 20.3,
#    'closePrice': 20.4,
#    'change': 0.35,
#    'changePercent': 1.75,
#    'tradeVolume': 15,
#    'tradeValue': 306200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4557',
#    'name': '永新-KY',
#    'openPrice': 115,
#    'highPrice': 118,
#    'lowPrice': 115,
#    'closePrice': 117,
#    'change': 2,
#    'changePercent': 1.74,
#    'tradeVolume': 150,
#    'tradeValue': 17465000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '020019',
#    'name': '統一特選台灣5GN',
#    'openPrice': 16.25,
#    'highPrice': 16.41,
#    'lowPrice': 16.25,
#    'closePrice': 16.38,
#    'change': 0.28,
#    'changePercent': 1.74,
#    'tradeVolume': 20,
#    'tradeValue': 327290,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00851',
#    'name': '台新全球AI',
#    'openPrice': 41.39,
#    'highPrice': 41.39,
#    'lowPrice': 41.1,
#    'closePrice': 41.3,
#    'change': 0.7,
#    'changePercent': 1.72,
#    'tradeVolume': 129,
#    'tradeValue': 5319550,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2606',
#    'name': '裕民',
#    'openPrice': 53.8,
#    'highPrice': 54.3,
#    'lowPrice': 53.2,
#    'closePrice': 53.6,
#    'change': 0.9,
#    'changePercent': 1.71,
#    'tradeVolume': 9814,
#    'tradeValue': 527817400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5234',
#    'name': '達興材料',
#    'openPrice': 118.5,
#    'highPrice': 122.5,
#    'lowPrice': 117.5,
#    'closePrice': 119,
#    'change': 2,
#    'changePercent': 1.71,
#    'tradeVolume': 3037,
#    'tradeValue': 364138500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00646',
#    'name': '元大S&P500',
#    'openPrice': 49.8,
#    'highPrice': 50.25,
#    'lowPrice': 49.8,
#    'closePrice': 50.25,
#    'change': 0.84,
#    'changePercent': 1.7,
#    'tradeVolume': 4942,
#    'tradeValue': 247810290,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00924',
#    'name': '復華S&P500成長',
#    'openPrice': 19.7,
#    'highPrice': 19.8,
#    'lowPrice': 19.69,
#    'closePrice': 19.79,
#    'change': 0.33,
#    'changePercent': 1.7,
#    'tradeVolume': 1513,
#    'tradeValue': 29894660,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2945',
#    'name': '三商家購',
#    'openPrice': 41.3,
#    'highPrice': 42,
#    'lowPrice': 41.3,
#    'closePrice': 42,
#    'change': 0.7,
#    'changePercent': 1.69,
#    'tradeVolume': 18,
#    'tradeValue': 747950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4915',
#    'name': '致伸',
#    'openPrice': 72.2,
#    'highPrice': 72.6,
#    'lowPrice': 71.3,
#    'closePrice': 72.4,
#    'change': 1.2,
#    'changePercent': 1.69,
#    'tradeVolume': 6503,
#    'tradeValue': 468969300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '020034',
#    'name': '元大IC設計N',
#    'openPrice': 8,
#    'highPrice': 8.05,
#    'lowPrice': 7.93,
#    'closePrice': 8,
#    'change': 0.13,
#    'changePercent': 1.65,
#    'tradeVolume': 311,
#    'tradeValue': 2491670,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00903',
#    'name': '富邦元宇宙',
#    'openPrice': 12.95,
#    'highPrice': 12.98,
#    'lowPrice': 12.94,
#    'closePrice': 12.96,
#    'change': 0.2,
#    'changePercent': 1.57,
#    'tradeVolume': 3519,
#    'tradeValue': 45602290,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00927',
#    'name': '群益半導體收益',
#    'openPrice': 18,
#    'highPrice': 18.17,
#    'lowPrice': 17.94,
#    'closePrice': 18.12,
#    'change': 0.28,
#    'changePercent': 1.57,
#    'tradeVolume': 10641,
#    'tradeValue': 192271830,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3308',
#    'name': '聯德',
#    'openPrice': 35.4,
#    'highPrice': 36.3,
#    'lowPrice': 34.8,
#    'closePrice': 35.85,
#    'change': 0.55,
#    'changePercent': 1.56,
#    'tradeVolume': 821,
#    'tradeValue': 29226150,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3669',
#    'name': '圓展',
#    'openPrice': 48.9,
#    'highPrice': 49.65,
#    'lowPrice': 48.1,
#    'closePrice': 49.6,
#    'change': 0.75,
#    'changePercent': 1.54,
#    'tradeVolume': 611,
#    'tradeValue': 29891500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1786',
#    'name': '科妍',
#    'openPrice': 84.6,
#    'highPrice': 87.2,
#    'lowPrice': 84.3,
#    'closePrice': 85.9,
#    'change': 1.3,
#    'changePercent': 1.54,
#    'tradeVolume': 643,
#    'tradeValue': 55350700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00897',
#    'name': '富邦基因免疫生技',
#    'openPrice': 7.92,
#    'highPrice': 7.98,
#    'lowPrice': 7.92,
#    'closePrice': 7.96,
#    'change': 0.12,
#    'changePercent': 1.53,
#    'tradeVolume': 1805,
#    'tradeValue': 14352750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00728',
#    'name': '第一金工業30',
#    'openPrice': 28.41,
#    'highPrice': 28.74,
#    'lowPrice': 28.41,
#    'closePrice': 28.72,
#    'change': 0.43,
#    'changePercent': 1.52,
#    'tradeVolume': 1867,
#    'tradeValue': 53358920,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2314',
#    'name': '台揚',
#    'openPrice': 33.35,
#    'highPrice': 34.35,
#    'lowPrice': 33.1,
#    'closePrice': 33.85,
#    'change': 0.5,
#    'changePercent': 1.5,
#    'tradeVolume': 1294,
#    'tradeValue': 43500600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00662',
#    'name': '富邦NASDAQ',
#    'openPrice': 72.95,
#    'highPrice': 73.15,
#    'lowPrice': 72.9,
#    'closePrice': 73,
#    'change': 1.05,
#    'changePercent': 1.46,
#    'tradeVolume': 7775,
#    'tradeValue': 567356100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00861',
#    'name': '元大全球未來通訊',
#    'openPrice': 37.29,
#    'highPrice': 37.62,
#    'lowPrice': 37.29,
#    'closePrice': 37.61,
#    'change': 0.53,
#    'changePercent': 1.43,
#    'tradeVolume': 1294,
#    'tradeValue': 48555000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6192',
#    'name': '巨路',
#    'openPrice': 92.3,
#    'highPrice': 94.1,
#    'lowPrice': 92.3,
#    'closePrice': 93.5,
#    'change': 1.3,
#    'changePercent': 1.41,
#    'tradeVolume': 352,
#    'tradeValue': 32880700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1532',
#    'name': '勤美',
#    'openPrice': 38.9,
#    'highPrice': 39.6,
#    'lowPrice': 38.8,
#    'closePrice': 39.5,
#    'change': 0.55,
#    'changePercent': 1.41,
#    'tradeVolume': 1571,
#    'tradeValue': 61902500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '020012',
#    'name': '富邦行動通訊N',
#    'openPrice': 10.24,
#    'highPrice': 10.24,
#    'lowPrice': 10.2,
#    'closePrice': 10.24,
#    'change': 0.14,
#    'changePercent': 1.39,
#    'tradeVolume': 16,
#    'tradeValue': 163440,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2449',
#    'name': '京元電子',
#    'openPrice': 95.5,
#    'highPrice': 99.8,
#    'lowPrice': 93.7,
#    'closePrice': 94.8,
#    'change': 1.3,
#    'changePercent': 1.39,
#    'tradeVolume': 55671,
#    'tradeValue': 5386252600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00904',
#    'name': '新光臺灣半導體30',
#    'openPrice': 16,
#    'highPrice': 16.16,
#    'lowPrice': 15.98,
#    'closePrice': 16.1,
#    'change': 0.22,
#    'changePercent': 1.39,
#    'tradeVolume': 4684,
#    'tradeValue': 75263060,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4148',
#    'name': '全宇生技-KY',
#    'openPrice': 50.7,
#    'highPrice': 52.1,
#    'lowPrice': 50.7,
#    'closePrice': 50.9,
#    'change': 0.7,
#    'changePercent': 1.39,
#    'tradeVolume': 101,
#    'tradeValue': 5189300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00657',
#    'name': '國泰日經225',
#    'openPrice': 45.96,
#    'highPrice': 46.31,
#    'lowPrice': 45.92,
#    'closePrice': 46.22,
#    'change': 0.61,
#    'changePercent': 1.34,
#    'tradeVolume': 1184,
#    'tradeValue': 54655160,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00657K',
#    'name': '國泰日經225+U',
#    'openPrice': 14.61,
#    'highPrice': 14.61,
#    'lowPrice': 14.61,
#    'closePrice': 14.61,
#    'change': 0.19,
#    'changePercent': 1.32,
#    'tradeVolume': 2,
#    'tradeValue': 2922,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '020020',
#    'name': '元大台股領航N',
#    'openPrice': 9.06,
#    'highPrice': 9.2,
#    'lowPrice': 9.06,
#    'closePrice': 9.18,
#    'change': 0.12,
#    'changePercent': 1.32,
#    'tradeVolume': 172,
#    'tradeValue': 1571680,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00913',
#    'name': '兆豐台灣晶圓製造',
#    'openPrice': 19.33,
#    'highPrice': 19.42,
#    'lowPrice': 19.22,
#    'closePrice': 19.38,
#    'change': 0.25,
#    'changePercent': 1.31,
#    'tradeVolume': 910,
#    'tradeValue': 17596100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00668K',
#    'name': '國泰美國道瓊+U',
#    'openPrice': 14.17,
#    'highPrice': 14.17,
#    'lowPrice': 14.17,
#    'closePrice': 14.17,
#    'change': 0.18,
#    'changePercent': 1.29,
#    'tradeVolume': 2,
#    'tradeValue': 2834,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4763',
#    'name': '材料-KY',
#    'openPrice': 864,
#    'highPrice': 884,
#    'lowPrice': 864,
#    'closePrice': 869,
#    'change': 11,
#    'changePercent': 1.28,
#    'tradeVolume': 2548,
#    'tradeValue': 2228903000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1236',
#    'name': '宏亞',
#    'openPrice': 23.75,
#    'highPrice': 24,
#    'lowPrice': 23.65,
#    'closePrice': 23.85,
#    'change': 0.3,
#    'changePercent': 1.27,
#    'tradeVolume': 53,
#    'tradeValue': 1268400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6792',
#    'name': '詠業',
#    'openPrice': 87.5,
#    'highPrice': 90.1,
#    'lowPrice': 87.3,
#    'closePrice': 88.2,
#    'change': 1.1,
#    'changePercent': 1.26,
#    'tradeVolume': 150,
#    'tradeValue': 13294500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3296',
#    'name': '勝德',
#    'openPrice': 23.85,
#    'highPrice': 24.55,
#    'lowPrice': 23.6,
#    'closePrice': 24.1,
#    'change': 0.3,
#    'changePercent': 1.26,
#    'tradeVolume': 1894,
#    'tradeValue': 45650100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00652',
#    'name': '富邦印度',
#    'openPrice': 36.14,
#    'highPrice': 36.44,
#    'lowPrice': 36.14,
#    'closePrice': 36.37,
#    'change': 0.45,
#    'changePercent': 1.25,
#    'tradeVolume': 727,
#    'tradeValue': 26425650,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3033',
#    'name': '威健',
#    'openPrice': 32.4,
#    'highPrice': 33.3,
#    'lowPrice': 32.4,
#    'closePrice': 32.7,
#    'change': 0.4,
#    'changePercent': 1.24,
#    'tradeVolume': 7309,
#    'tradeValue': 240424100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00875',
#    'name': '國泰網路資安',
#    'openPrice': 31.77,
#    'highPrice': 31.93,
#    'lowPrice': 31.77,
#    'closePrice': 31.92,
#    'change': 0.39,
#    'changePercent': 1.24,
#    'tradeVolume': 311,
#    'tradeValue': 9913610,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00668',
#    'name': '國泰美國道瓊',
#    'openPrice': 44.71,
#    'highPrice': 44.8,
#    'lowPrice': 44.71,
#    'closePrice': 44.8,
#    'change': 0.54,
#    'changePercent': 1.22,
#    'tradeVolume': 7,
#    'tradeValue': 313300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3605',
#    'name': '宏致',
#    'openPrice': 37.7,
#    'highPrice': 38.45,
#    'lowPrice': 37.1,
#    'closePrice': 37.7,
#    'change': 0.45,
#    'changePercent': 1.21,
#    'tradeVolume': 1533,
#    'tradeValue': 58198900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2455',
#    'name': '全新',
#    'openPrice': 167,
#    'highPrice': 169.5,
#    'lowPrice': 163.5,
#    'closePrice': 167.5,
#    'change': 2,
#    'changePercent': 1.21,
#    'tradeVolume': 5283,
#    'tradeValue': 883865500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00894',
#    'name': '中信小資高價30',
#    'openPrice': 17.67,
#    'highPrice': 17.85,
#    'lowPrice': 17.65,
#    'closePrice': 17.75,
#    'change': 0.21,
#    'changePercent': 1.2,
#    'tradeVolume': 2657,
#    'tradeValue': 47160880,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00830',
#    'name': '國泰費城半導體',
#    'openPrice': 41.46,
#    'highPrice': 41.47,
#    'lowPrice': 41.24,
#    'closePrice': 41.31,
#    'change': 0.48,
#    'changePercent': 1.18,
#    'tradeVolume': 21089,
#    'tradeValue': 871575640,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3002',
#    'name': '歐格',
#    'openPrice': 17.65,
#    'highPrice': 17.75,
#    'lowPrice': 17.1,
#    'closePrice': 17.35,
#    'change': 0.2,
#    'changePercent': 1.17,
#    'tradeVolume': 1115,
#    'tradeValue': 19383650,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '006203',
#    'name': '元大MSCI台灣',
#    'openPrice': 68.7,
#    'highPrice': 69.3,
#    'lowPrice': 68.7,
#    'closePrice': 69.3,
#    'change': 0.8,
#    'changePercent': 1.17,
#    'tradeVolume': 29,
#    'tradeValue': 1998350,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1503',
#    'name': '士電',
#    'openPrice': 173,
#    'highPrice': 179.5,
#    'lowPrice': 170.5,
#    'closePrice': 174,
#    'change': 2,
#    'changePercent': 1.16,
#    'tradeVolume': 43884,
#    'tradeValue': 7684123000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00690',
#    'name': '兆豐藍籌30',
#    'openPrice': 30.88,
#    'highPrice': 31.2,
#    'lowPrice': 30.87,
#    'closePrice': 31.08,
#    'change': 0.35,
#    'changePercent': 1.14,
#    'tradeVolume': 1850,
#    'tradeValue': 57360350,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '020029',
#    'name': '元大ESG高股息N',
#    'openPrice': 7.96,
#    'highPrice': 8.02,
#    'lowPrice': 7.95,
#    'closePrice': 7.99,
#    'change': 0.09,
#    'changePercent': 1.14,
#    'tradeVolume': 71,
#    'tradeValue': 566200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6541',
#    'name': '泰福-KY',
#    'openPrice': 61.5,
#    'highPrice': 62.8,
#    'lowPrice': 61.5,
#    'closePrice': 62.5,
#    'change': 0.7,
#    'changePercent': 1.13,
#    'tradeVolume': 277,
#    'tradeValue': 17244500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3028',
#    'name': '增你強',
#    'openPrice': 35.55,
#    'highPrice': 36.15,
#    'lowPrice': 35.55,
#    'closePrice': 35.85,
#    'change': 0.4,
#    'changePercent': 1.13,
#    'tradeVolume': 1517,
#    'tradeValue': 54423700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2388',
#    'name': '威盛',
#    'openPrice': 134,
#    'highPrice': 137,
#    'lowPrice': 133.5,
#    'closePrice': 134,
#    'change': 1.5,
#    'changePercent': 1.13,
#    'tradeVolume': 7826,
#    'tradeValue': 1058259000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00678',
#    'name': '群益那斯達克生技',
#    'openPrice': 27.91,
#    'highPrice': 27.97,
#    'lowPrice': 27.91,
#    'closePrice': 27.97,
#    'change': 0.31,
#    'changePercent': 1.12,
#    'tradeVolume': 262,
#    'tradeValue': 7324550,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00752',
#    'name': '中信中國50',
#    'openPrice': 16.2,
#    'highPrice': 16.51,
#    'lowPrice': 16.2,
#    'closePrice': 16.36,
#    'change': 0.18,
#    'changePercent': 1.11,
#    'tradeVolume': 3726,
#    'tradeValue': 60947060,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00665L',
#    'name': '富邦恒生國企正2',
#    'openPrice': 5.52,
#    'highPrice': 5.68,
#    'lowPrice': 5.45,
#    'closePrice': 5.53,
#    'change': 0.06,
#    'changePercent': 1.1,
#    'tradeVolume': 67623,
#    'tradeValue': 374718160,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00917',
#    'name': '中信特選金融',
#    'openPrice': 17.64,
#    'highPrice': 17.7,
#    'lowPrice': 17.64,
#    'closePrice': 17.7,
#    'change': 0.19,
#    'changePercent': 1.09,
#    'tradeVolume': 648,
#    'tradeValue': 11462410,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '0053',
#    'name': '元大電子',
#    'openPrice': 78.6,
#    'highPrice': 78.65,
#    'lowPrice': 78.3,
#    'closePrice': 78.65,
#    'change': 0.85,
#    'changePercent': 1.09,
#    'tradeVolume': 17,
#    'tradeValue': 1331750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '020032',
#    'name': '元大綠能N',
#    'openPrice': 5.51,
#    'highPrice': 5.59,
#    'lowPrice': 5.51,
#    'closePrice': 5.55,
#    'change': 0.06,
#    'changePercent': 1.09,
#    'tradeVolume': 51,
#    'tradeValue': 283070,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00700',
#    'name': '富邦恒生國企',
#    'openPrice': 11.15,
#    'highPrice': 11.37,
#    'lowPrice': 11.13,
#    'closePrice': 11.23,
#    'change': 0.12,
#    'changePercent': 1.08,
#    'tradeVolume': 1741,
#    'tradeValue': 19569740,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2357',
#    'name': '華碩',
#    'openPrice': 473,
#    'highPrice': 482.5,
#    'lowPrice': 473,
#    'closePrice': 474,
#    'change': 5,
#    'changePercent': 1.07,
#    'tradeVolume': 3535,
#    'tradeValue': 1690962500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2431',
#    'name': '聯昌',
#    'openPrice': 14.05,
#    'highPrice': 14.55,
#    'lowPrice': 14.05,
#    'closePrice': 14.15,
#    'change': 0.15,
#    'changePercent': 1.07,
#    'tradeVolume': 1710,
#    'tradeValue': 24407400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6598',
#    'name': 'ABC-KY',
#    'openPrice': 23.35,
#    'highPrice': 23.7,
#    'lowPrice': 23.25,
#    'closePrice': 23.6,
#    'change': 0.25,
#    'changePercent': 1.07,
#    'tradeVolume': 47,
#    'tradeValue': 1101800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2377',
#    'name': '微星',
#    'openPrice': 191,
#    'highPrice': 194,
#    'lowPrice': 190.5,
#    'closePrice': 191.5,
#    'change': 2,
#    'changePercent': 1.06,
#    'tradeVolume': 4373,
#    'tradeValue': 840585000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3035',
#    'name': '智原',
#    'openPrice': 387.5,
#    'highPrice': 392.5,
#    'lowPrice': 384,
#    'closePrice': 386,
#    'change': 4,
#    'changePercent': 1.05,
#    'tradeVolume': 14440,
#    'tradeValue': 5603712500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2530',
#    'name': '華建',
#    'openPrice': 38.75,
#    'highPrice': 39.4,
#    'lowPrice': 38.5,
#    'closePrice': 38.9,
#    'change': 0.4,
#    'changePercent': 1.04,
#    'tradeVolume': 1412,
#    'tradeValue': 54894450,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00640L',
#    'name': '富邦日本正2',
#    'openPrice': 53.65,
#    'highPrice': 54.1,
#    'lowPrice': 53.55,
#    'closePrice': 54.1,
#    'change': 0.55,
#    'changePercent': 1.03,
#    'tradeVolume': 389,
#    'tradeValue': 20931700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '020038',
#    'name': '元大ESG配息N',
#    'openPrice': 6.8,
#    'highPrice': 6.91,
#    'lowPrice': 6.8,
#    'closePrice': 6.87,
#    'change': 0.07,
#    'changePercent': 1.03,
#    'tradeVolume': 247,
#    'tradeValue': 1698900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00753L',
#    'name': '中信中國50正2',
#    'openPrice': 6.86,
#    'highPrice': 7.02,
#    'lowPrice': 6.77,
#    'closePrice': 6.84,
#    'change': 0.07,
#    'changePercent': 1.03,
#    'tradeVolume': 37668,
#    'tradeValue': 258829590,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00916',
#    'name': '國泰全球品牌50',
#    'openPrice': 20.75,
#    'highPrice': 20.79,
#    'lowPrice': 20.73,
#    'closePrice': 20.78,
#    'change': 0.21,
#    'changePercent': 1.02,
#    'tradeVolume': 676,
#    'tradeValue': 14034170,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2482',
#    'name': '連宇',
#    'openPrice': 34.5,
#    'highPrice': 35.25,
#    'lowPrice': 34.1,
#    'closePrice': 34.55,
#    'change': 0.35,
#    'changePercent': 1.02,
#    'tradeVolume': 862,
#    'tradeValue': 29952200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6581',
#    'name': '鋼聯',
#    'openPrice': 89.4,
#    'highPrice': 90.3,
#    'lowPrice': 89.2,
#    'closePrice': 90,
#    'change': 0.9,
#    'changePercent': 1.01,
#    'tradeVolume': 94,
#    'tradeValue': 8435800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '0052',
#    'name': '富邦科技',
#    'openPrice': 144.35,
#    'highPrice': 145,
#    'lowPrice': 144.1,
#    'closePrice': 144.75,
#    'change': 1.45,
#    'changePercent': 1.01,
#    'tradeVolume': 510,
#    'tradeValue': 73828700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00660',
#    'name': '元大歐洲50',
#    'openPrice': 34.76,
#    'highPrice': 34.94,
#    'lowPrice': 34.76,
#    'closePrice': 34.93,
#    'change': 0.35,
# ...
#    'symbol': '3130',
#    'name': '一零四',
#    'openPrice': 233,
#    'highPrice': 233,
#    'lowPrice': 228,
#    'closePrice': 230,
#    'change': -2,
#    'changePercent': -0.86,
#    'tradeVolume': 15,
#    'tradeValue': 3462500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2022',
#    'name': '聚亨',
#    'openPrice': 11.55,
#    'highPrice': 11.65,
#    'lowPrice': 11.45,
#    'closePrice': 11.45,
#    'change': -0.1,
#    'changePercent': -0.87,
#    'tradeVolume': 577,
#    'tradeValue': 6645750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8462',
#    'name': '柏文',
#    'openPrice': 114.5,
#    'highPrice': 115,
#    'lowPrice': 113.5,
#    'closePrice': 113.5,
#    'change': -1,
#    'changePercent': -0.87,
#    'tradeVolume': 70,
#    'tradeValue': 7974000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4306',
#    'name': '炎洲',
#    'openPrice': 17.3,
#    'highPrice': 17.3,
#    'lowPrice': 17.05,
#    'closePrice': 17.15,
#    'change': -0.15,
#    'changePercent': -0.87,
#    'tradeVolume': 1781,
#    'tradeValue': 30615450,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2406',
#    'name': '國碩',
#    'openPrice': 17.3,
#    'highPrice': 17.4,
#    'lowPrice': 17.1,
#    'closePrice': 17.1,
#    'change': -0.15,
#    'changePercent': -0.87,
#    'tradeVolume': 737,
#    'tradeValue': 12705050,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1538',
#    'name': '正峰',
#    'openPrice': 22.6,
#    'highPrice': 22.7,
#    'lowPrice': 22.5,
#    'closePrice': 22.5,
#    'change': -0.2,
#    'changePercent': -0.88,
#    'tradeVolume': 71,
#    'tradeValue': 1603250,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1722',
#    'name': '台肥',
#    'openPrice': 67.9,
#    'highPrice': 68.1,
#    'lowPrice': 67.2,
#    'closePrice': 67.3,
#    'change': -0.6,
#    'changePercent': -0.88,
#    'tradeVolume': 1961,
#    'tradeValue': 132378400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1727',
#    'name': '中華化',
#    'openPrice': 28.1,
#    'highPrice': 28.5,
#    'lowPrice': 27.95,
#    'closePrice': 28,
#    'change': -0.25,
#    'changePercent': -0.88,
#    'tradeVolume': 295,
#    'tradeValue': 8320450,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1338',
#    'name': '廣華-KY',
#    'openPrice': 39.9,
#    'highPrice': 39.9,
#    'lowPrice': 39.2,
#    'closePrice': 39.5,
#    'change': -0.35,
#    'changePercent': -0.88,
#    'tradeVolume': 83,
#    'tradeValue': 3286800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5484',
#    'name': '慧友',
#    'openPrice': 28.5,
#    'highPrice': 28.8,
#    'lowPrice': 28.15,
#    'closePrice': 28.25,
#    'change': -0.25,
#    'changePercent': -0.88,
#    'tradeVolume': 189,
#    'tradeValue': 5355850,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1339',
#    'name': '昭輝',
#    'openPrice': 68.6,
#    'highPrice': 69.2,
#    'lowPrice': 67.4,
#    'closePrice': 67.9,
#    'change': -0.6,
#    'changePercent': -0.88,
#    'tradeVolume': 530,
#    'tradeValue': 36164500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3356',
#    'name': '奇偶',
#    'openPrice': 45.7,
#    'highPrice': 45.9,
#    'lowPrice': 44.5,
#    'closePrice': 44.5,
#    'change': -0.4,
#    'changePercent': -0.89,
#    'tradeVolume': 603,
#    'tradeValue': 27241750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6213',
#    'name': '聯茂',
#    'openPrice': 90.2,
#    'highPrice': 91.2,
#    'lowPrice': 88.6,
#    'closePrice': 88.9,
#    'change': -0.8,
#    'changePercent': -0.89,
#    'tradeVolume': 4621,
#    'tradeValue': 414081000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3021',
#    'name': '鴻名',
#    'openPrice': 22.45,
#    'highPrice': 22.5,
#    'lowPrice': 22.05,
#    'closePrice': 22.05,
#    'change': -0.2,
#    'changePercent': -0.9,
#    'tradeVolume': 223,
#    'tradeValue': 4963100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1467',
#    'name': '南緯',
#    'openPrice': 11.15,
#    'highPrice': 11.15,
#    'lowPrice': 11,
#    'closePrice': 11.05,
#    'change': -0.1,
#    'changePercent': -0.9,
#    'tradeVolume': 99,
#    'tradeValue': 1095650,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8072',
#    'name': '陞泰',
#    'openPrice': 27.9,
#    'highPrice': 27.9,
#    'lowPrice': 27.4,
#    'closePrice': 27.4,
#    'change': -0.25,
#    'changePercent': -0.9,
#    'tradeVolume': 118,
#    'tradeValue': 3261950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2344',
#    'name': '華邦電',
#    'openPrice': 28.15,
#    'highPrice': 28.2,
#    'lowPrice': 27.65,
#    'closePrice': 27.65,
#    'change': -0.25,
#    'changePercent': -0.9,
#    'tradeVolume': 28845,
#    'tradeValue': 804243000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1568',
#    'name': '倉佑',
#    'openPrice': 33.1,
#    'highPrice': 33.3,
#    'lowPrice': 32.65,
#    'closePrice': 32.65,
#    'change': -0.3,
#    'changePercent': -0.91,
#    'tradeVolume': 1161,
#    'tradeValue': 38318000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6117',
#    'name': '迎廣',
#    'openPrice': 78.1,
#    'highPrice': 82.6,
#    'lowPrice': 76.3,
#    'closePrice': 76.4,
#    'change': -0.7,
#    'changePercent': -0.91,
#    'tradeVolume': 9463,
#    'tradeValue': 749546300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2885',
#    'name': '元大金',
#    'openPrice': 27.5,
#    'highPrice': 27.55,
#    'lowPrice': 27.2,
#    'closePrice': 27.3,
#    'change': -0.25,
#    'changePercent': -0.91,
#    'tradeVolume': 10280,
#    'tradeValue': 281197450,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4967',
#    'name': '十銓',
#    'openPrice': 88.9,
#    'highPrice': 89.8,
#    'lowPrice': 85.8,
#    'closePrice': 85.9,
#    'change': -0.8,
#    'changePercent': -0.92,
#    'tradeVolume': 4700,
#    'tradeValue': 411294000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6120',
#    'name': '達運',
#    'openPrice': 16.5,
#    'highPrice': 16.85,
#    'lowPrice': 16.2,
#    'closePrice': 16.2,
#    'change': -0.15,
#    'changePercent': -0.92,
#    'tradeVolume': 7672,
#    'tradeValue': 126949850,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1216',
#    'name': '統一',
#    'openPrice': 76,
#    'highPrice': 76.2,
#    'lowPrice': 75.6,
#    'closePrice': 75.8,
#    'change': -0.7,
#    'changePercent': -0.92,
#    'tradeVolume': 4213,
#    'tradeValue': 319686100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1725',
#    'name': '元禎',
#    'openPrice': 21.6,
#    'highPrice': 21.65,
#    'lowPrice': 21.5,
#    'closePrice': 21.5,
#    'change': -0.2,
#    'changePercent': -0.92,
#    'tradeVolume': 13,
#    'tradeValue': 280000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3016',
#    'name': '嘉晶',
#    'openPrice': 54.6,
#    'highPrice': 55.2,
#    'lowPrice': 54,
#    'closePrice': 54,
#    'change': -0.5,
#    'changePercent': -0.92,
#    'tradeVolume': 527,
#    'tradeValue': 28784600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1702',
#    'name': '南僑',
#    'openPrice': 54.8,
#    'highPrice': 55,
#    'lowPrice': 54.1,
#    'closePrice': 54.1,
#    'change': -0.5,
#    'changePercent': -0.92,
#    'tradeVolume': 664,
#    'tradeValue': 36131700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6472',
#    'name': '保瑞',
#    'openPrice': 658,
#    'highPrice': 658,
#    'lowPrice': 646,
#    'closePrice': 646,
#    'change': -6,
#    'changePercent': -0.92,
#    'tradeVolume': 660,
#    'tradeValue': 427879000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4989',
#    'name': '榮科',
#    'openPrice': 26.8,
#    'highPrice': 26.95,
#    'lowPrice': 26.5,
#    'closePrice': 26.55,
#    'change': -0.25,
#    'changePercent': -0.93,
#    'tradeVolume': 224,
#    'tradeValue': 5985750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1615',
#    'name': '大山',
#    'openPrice': 48.15,
#    'highPrice': 48.15,
#    'lowPrice': 47.4,
#    'closePrice': 47.8,
#    'change': -0.45,
#    'changePercent': -0.93,
#    'tradeVolume': 245,
#    'tradeValue': 11698900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2303',
#    'name': '聯電',
#    'openPrice': 48.5,
#    'highPrice': 48.9,
#    'lowPrice': 48.15,
#    'closePrice': 48.15,
#    'change': -0.45,
#    'changePercent': -0.93,
#    'tradeVolume': 53842,
#    'tradeValue': 2608412500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1903',
#    'name': '士紙',
#    'openPrice': 53.7,
#    'highPrice': 53.8,
#    'lowPrice': 53.3,
#    'closePrice': 53.4,
#    'change': -0.5,
#    'changePercent': -0.93,
#    'tradeVolume': 147,
#    'tradeValue': 7865700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8429',
#    'name': '金麗-KY',
#    'openPrice': 10.85,
#    'highPrice': 10.85,
#    'lowPrice': 10.65,
#    'closePrice': 10.65,
#    'change': -0.1,
#    'changePercent': -0.93,
#    'tradeVolume': 224,
#    'tradeValue': 2400950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1410',
#    'name': '南染',
#    'openPrice': 37.45,
#    'highPrice': 37.45,
#    'lowPrice': 36.9,
#    'closePrice': 36.9,
#    'change': -0.35,
#    'changePercent': -0.94,
#    'tradeVolume': 214,
#    'tradeValue': 7943200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '9945',
#    'name': '潤泰新',
#    'openPrice': 37.15,
#    'highPrice': 37.15,
#    'lowPrice': 36.6,
#    'closePrice': 36.7,
#    'change': -0.35,
#    'changePercent': -0.94,
#    'tradeVolume': 3672,
#    'tradeValue': 135110300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2832',
#    'name': '台產',
#    'openPrice': 26.6,
#    'highPrice': 26.65,
#    'lowPrice': 26.35,
#    'closePrice': 26.35,
#    'change': -0.25,
#    'changePercent': -0.94,
#    'tradeVolume': 254,
#    'tradeValue': 6728150,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8341',
#    'name': '日友',
#    'openPrice': 105.5,
#    'highPrice': 106,
#    'lowPrice': 105,
#    'closePrice': 105,
#    'change': -1,
#    'changePercent': -0.94,
#    'tradeVolume': 157,
#    'tradeValue': 16526500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2888',
#    'name': '新光金',
#    'openPrice': 8.4,
#    'highPrice': 8.41,
#    'lowPrice': 8.32,
#    'closePrice': 8.33,
#    'change': -0.08,
#    'changePercent': -0.95,
#    'tradeVolume': 25790,
#    'tradeValue': 215308170,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6830',
#    'name': '汎銓',
#    'openPrice': 158,
#    'highPrice': 160.5,
#    'lowPrice': 155,
#    'closePrice': 155.5,
#    'change': -1.5,
#    'changePercent': -0.96,
#    'tradeVolume': 953,
#    'tradeValue': 150253000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3049',
#    'name': '精金',
#    'openPrice': 9.39,
#    'highPrice': 9.39,
#    'lowPrice': 9.29,
#    'closePrice': 9.3,
#    'change': -0.09,
#    'changePercent': -0.96,
#    'tradeVolume': 1860,
#    'tradeValue': 17342590,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6672',
#    'name': '騰輝電子-KY',
#    'openPrice': 94.2,
#    'highPrice': 94.4,
#    'lowPrice': 92.7,
#    'closePrice': 92.7,
#    'change': -0.9,
#    'changePercent': -0.96,
#    'tradeVolume': 502,
#    'tradeValue': 46869300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2478',
#    'name': '大毅',
#    'openPrice': 46.85,
#    'highPrice': 46.85,
#    'lowPrice': 46.35,
#    'closePrice': 46.35,
#    'change': -0.45,
#    'changePercent': -0.96,
#    'tradeVolume': 117,
#    'tradeValue': 5452250,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2049',
#    'name': '上銀',
#    'openPrice': 262,
#    'highPrice': 265,
#    'lowPrice': 255,
#    'closePrice': 255,
#    'change': -2.5,
#    'changePercent': -0.97,
#    'tradeVolume': 2757,
#    'tradeValue': 712910000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1413',
#    'name': '宏洲',
#    'openPrice': 9.35,
#    'highPrice': 9.35,
#    'lowPrice': 9.17,
#    'closePrice': 9.17,
#    'change': -0.09,
#    'changePercent': -0.97,
#    'tradeVolume': 37,
#    'tradeValue': 340710,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2374',
#    'name': '佳能',
#    'openPrice': 25.9,
#    'highPrice': 26.05,
#    'lowPrice': 25.5,
#    'closePrice': 25.55,
#    'change': -0.25,
#    'changePercent': -0.97,
#    'tradeVolume': 1271,
#    'tradeValue': 32720400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6782',
#    'name': '視陽',
#    'openPrice': 259,
#    'highPrice': 261,
#    'lowPrice': 249.5,
#    'closePrice': 254,
#    'change': -2.5,
#    'changePercent': -0.97,
#    'tradeVolume': 868,
#    'tradeValue': 220353000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00669R',
#    'name': '國泰美國道瓊反1',
#    'openPrice': 7.06,
#    'highPrice': 7.06,
#    'lowPrice': 7.04,
#    'closePrice': 7.05,
#    'change': -0.07,
#    'changePercent': -0.98,
#    'tradeVolume': 3310,
#    'tradeValue': 23321910,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1444',
#    'name': '力麗',
#    'openPrice': 10.4,
#    'highPrice': 10.4,
#    'lowPrice': 10.15,
#    'closePrice': 10.15,
#    'change': -0.1,
#    'changePercent': -0.98,
#    'tradeVolume': 1624,
#    'tradeValue': 16626750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3062',
#    'name': '建漢',
#    'openPrice': 20.4,
#    'highPrice': 20.65,
#    'lowPrice': 20.05,
#    'closePrice': 20.15,
#    'change': -0.2,
#    'changePercent': -0.98,
#    'tradeVolume': 1326,
#    'tradeValue': 26939550,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1583',
#    'name': '程泰',
#    'openPrice': 70,
#    'highPrice': 70.6,
#    'lowPrice': 70,
#    'closePrice': 70.2,
#    'change': -0.7,
#    'changePercent': -0.99,
#    'tradeVolume': 6,
#    'tradeValue': 421000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6743',
#    'name': '安普新',
#    'openPrice': 50.4,
#    'highPrice': 50.8,
#    'lowPrice': 49.7,
#    'closePrice': 49.8,
#    'change': -0.5,
#    'changePercent': -0.99,
#    'tradeVolume': 201,
#    'tradeValue': 10042800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2247',
#    'name': '汎德永業',
#    'openPrice': 301,
#    'highPrice': 301,
#    'lowPrice': 298,
#    'closePrice': 298,
#    'change': -3,
#    'changePercent': -1,
#    'tradeVolume': 83,
#    'tradeValue': 24814000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2702',
#    'name': '華園',
#    'openPrice': 20,
#    'highPrice': 20,
#    'lowPrice': 19.8,
#    'closePrice': 19.8,
#    'change': -0.2,
#    'changePercent': -1,
#    'tradeVolume': 132,
#    'tradeValue': 2621400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6742',
#    'name': '澤米',
#    'openPrice': 70.8,
#    'highPrice': 71.5,
#    'lowPrice': 69.5,
#    'closePrice': 69.5,
#    'change': -0.7,
#    'changePercent': -1,
#    'tradeVolume': 485,
#    'tradeValue': 34231400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4999',
#    'name': '鑫禾',
#    'openPrice': 35.25,
#    'highPrice': 35.3,
#    'lowPrice': 34.7,
#    'closePrice': 34.7,
#    'change': -0.35,
#    'changePercent': -1,
#    'tradeVolume': 122,
#    'tradeValue': 4258950,
#    'lastUpdated': 1708666380000000},
#   {'type': 'EQUITY',
#    'symbol': '2882',
#    'name': '國泰金',
#    'openPrice': 44.8,
#    'highPrice': 44.85,
#    'lowPrice': 44.45,
#    'closePrice': 44.45,
#    'change': -0.45,
#    'changePercent': -1,
#    'tradeVolume': 14486,
#    'tradeValue': 646660050,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2616',
#    'name': '山隆',
#    'openPrice': 29.85,
#    'highPrice': 29.85,
#    'lowPrice': 29.65,
#    'closePrice': 29.65,
#    'change': -0.3,
#    'changePercent': -1,
#    'tradeVolume': 234,
#    'tradeValue': 6959950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1438',
#    'name': '三地開發',
#    'openPrice': 49.8,
#    'highPrice': 50.5,
#    'lowPrice': 49.1,
#    'closePrice': 49.3,
#    'change': -0.5,
#    'changePercent': -1,
#    'tradeVolume': 314,
#    'tradeValue': 15550250,
#    'lastUpdated': 1708666200000000},
#   ...]}

# %%
#取得股票成交量值排行
stock.snapshot.actives(market='TSE', trade='value')
# Out:
# {'date': '2024-02-23',
#  'time': '140000',
#  'market': 'TSE',
#  'trade': 'value',
#  'data': [{'type': 'EQUITY',
#    'symbol': '2330',
#    'name': '台積電',
#    'openPrice': 701,
#    'highPrice': 703,
#    'lowPrice': 696,
#    'closePrice': 697,
#    'change': 5,
#    'changePercent': 0.72,
#    'tradeVolume': 46335,
#    'tradeValue': 32400762000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2454',
#    'name': '聯發科',
#    'openPrice': 1035,
#    'highPrice': 1100,
#    'lowPrice': 1010,
#    'closePrice': 1100,
#    'change': 85,
#    'changePercent': 8.37,
#    'tradeVolume': 23373,
#    'tradeValue': 24862155000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3231',
#    'name': '緯創',
#    'openPrice': 122.5,
#    'highPrice': 123,
#    'lowPrice': 116,
#    'closePrice': 116,
#    'change': -3,
#    'changePercent': -2.52,
#    'tradeVolume': 101364,
#    'tradeValue': 12076352500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2329',
#    'name': '華泰',
#    'openPrice': 86.8,
#    'highPrice': 88.4,
#    'lowPrice': 75.8,
#    'closePrice': 77.1,
#    'change': -5.7,
#    'changePercent': -6.88,
#    'tradeVolume': 144626,
#    'tradeValue': 11847296600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1513',
#    'name': '中興電',
#    'openPrice': 135,
#    'highPrice': 146,
#    'lowPrice': 131.5,
#    'closePrice': 143,
#    'change': 9.5,
#    'changePercent': 7.12,
#    'tradeVolume': 78206,
#    'tradeValue': 11032031000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2313',
#    'name': '華通',
#    'openPrice': 82,
#    'highPrice': 82.3,
#    'lowPrice': 76.6,
#    'closePrice': 78.4,
#    'change': -1.7,
#    'changePercent': -2.12,
#    'tradeVolume': 127523,
#    'tradeValue': 10116284800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2376',
#    'name': '技嘉',
#    'openPrice': 358,
#    'highPrice': 360,
#    'lowPrice': 342.5,
#    'closePrice': 342.5,
#    'change': -4.5,
#    'changePercent': -1.3,
#    'tradeVolume': 27881,
#    'tradeValue': 9780308000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1519',
#    'name': '華城',
#    'openPrice': 528,
#    'highPrice': 568,
#    'lowPrice': 515,
#    'closePrice': 560,
#    'change': 43,
#    'changePercent': 8.32,
#    'tradeVolume': 15651,
#    'tradeValue': 8479882000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2382',
#    'name': '廣達',
#    'openPrice': 248.5,
#    'highPrice': 249,
#    'lowPrice': 241,
#    'closePrice': 241,
#    'change': -2.5,
#    'changePercent': -1.03,
#    'tradeVolume': 33987,
#    'tradeValue': 8327996000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3661',
#    'name': '世芯-KY',
#    'openPrice': 4145,
#    'highPrice': 4170,
#    'lowPrice': 3900,
#    'closePrice': 3900,
#    'change': -115,
#    'changePercent': -2.86,
#    'tradeVolume': 2021,
#    'tradeValue': 8066840000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1503',
#    'name': '士電',
#    'openPrice': 173,
#    'highPrice': 179.5,
#    'lowPrice': 170.5,
#    'closePrice': 174,
#    'change': 2,
#    'changePercent': 1.16,
#    'tradeVolume': 43884,
#    'tradeValue': 7684123000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6669',
#    'name': '緯穎',
#    'openPrice': 2175,
#    'highPrice': 2235,
#    'lowPrice': 2135,
#    'closePrice': 2170,
#    'change': 55,
#    'changePercent': 2.6,
#    'tradeVolume': 3323,
#    'tradeValue': 7263160000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3017',
#    'name': '奇鋐',
#    'openPrice': 520,
#    'highPrice': 523,
#    'lowPrice': 497,
#    'closePrice': 498.5,
#    'change': -21.5,
#    'changePercent': -4.13,
#    'tradeVolume': 14219,
#    'tradeValue': 7210901000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2379',
#    'name': '瑞昱',
#    'openPrice': 554,
#    'highPrice': 563,
#    'lowPrice': 540,
#    'closePrice': 547,
#    'change': 15,
#    'changePercent': 2.82,
#    'tradeVolume': 12913,
#    'tradeValue': 7167055000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3035',
#    'name': '智原',
#    'openPrice': 387.5,
#    'highPrice': 392.5,
#    'lowPrice': 384,
#    'closePrice': 386,
#    'change': 4,
#    'changePercent': 1.05,
#    'tradeVolume': 14440,
#    'tradeValue': 5603712500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2059',
#    'name': '川湖',
#    'openPrice': 1375,
#    'highPrice': 1390,
#    'lowPrice': 1315,
#    'closePrice': 1355,
#    'change': 40,
#    'changePercent': 3.04,
#    'tradeVolume': 4129,
#    'tradeValue': 5584105000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2449',
#    'name': '京元電子',
#    'openPrice': 95.5,
#    'highPrice': 99.8,
#    'lowPrice': 93.7,
#    'closePrice': 94.8,
#    'change': 1.3,
#    'changePercent': 1.39,
#    'tradeVolume': 55671,
#    'tradeValue': 5386252600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1514',
#    'name': '亞力',
#    'openPrice': 86.4,
#    'highPrice': 92.5,
#    'lowPrice': 85,
#    'closePrice': 89.5,
#    'change': 3.7,
#    'changePercent': 4.31,
#    'tradeVolume': 59058,
#    'tradeValue': 5285711800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2603',
#    'name': '長榮',
#    'openPrice': 163.5,
#    'highPrice': 164.5,
#    'lowPrice': 158.5,
#    'closePrice': 159.5,
#    'change': -3,
#    'changePercent': -1.85,
#    'tradeVolume': 27318,
#    'tradeValue': 4403003500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2383',
#    'name': '台光電',
#    'openPrice': 507,
#    'highPrice': 520,
#    'lowPrice': 500,
#    'closePrice': 510,
#    'change': 19.5,
#    'changePercent': 3.98,
#    'tradeVolume': 8291,
#    'tradeValue': 4227265000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5269',
#    'name': '祥碩',
#    'openPrice': 2190,
#    'highPrice': 2285,
#    'lowPrice': 2185,
#    'closePrice': 2280,
#    'change': 115,
#    'changePercent': 5.31,
#    'tradeVolume': 1844,
#    'tradeValue': 4141410000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1560',
#    'name': '中砂',
#    'openPrice': 287.5,
#    'highPrice': 295,
#    'lowPrice': 275,
#    'closePrice': 276.5,
#    'change': 1,
#    'changePercent': 0.36,
#    'tradeVolume': 14382,
#    'tradeValue': 4105421500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2368',
#    'name': '金像電',
#    'openPrice': 261,
#    'highPrice': 267.5,
#    'lowPrice': 258,
#    'closePrice': 262,
#    'change': 6.5,
#    'changePercent': 2.54,
#    'tradeVolume': 15412,
#    'tradeValue': 4060522000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00929',
#    'name': '復華台灣科技優息',
#    'openPrice': 19.71,
#    'highPrice': 19.8,
#    'lowPrice': 19.62,
#    'closePrice': 19.62,
#    'change': 0.06,
#    'changePercent': 0.31,
#    'tradeVolume': 203325,
#    'tradeValue': 4006658180,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3443',
#    'name': '創意',
#    'openPrice': 1495,
#    'highPrice': 1510,
#    'lowPrice': 1445,
#    'closePrice': 1455,
#    'change': -10,
#    'changePercent': -0.68,
#    'tradeVolume': 2691,
#    'tradeValue': 3956955000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3034',
#    'name': '聯詠',
#    'openPrice': 589,
#    'highPrice': 595,
#    'lowPrice': 580,
#    'closePrice': 580,
#    'change': -4,
#    'changePercent': -0.68,
#    'tradeVolume': 6289,
#    'tradeValue': 3686874000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2421',
#    'name': '建準',
#    'openPrice': 134,
#    'highPrice': 135,
#    'lowPrice': 125,
#    'closePrice': 125,
#    'change': -7.5,
#    'changePercent': -5.66,
#    'tradeVolume': 26952,
#    'tradeValue': 3465337500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6789',
#    'name': '采鈺',
#    'openPrice': 311,
#    'highPrice': 333,
#    'lowPrice': 310.5,
#    'closePrice': 327.5,
#    'change': 20,
#    'changePercent': 6.5,
#    'tradeVolume': 10306,
#    'tradeValue': 3359278000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6526',
#    'name': '達發',
#    'openPrice': 658,
#    'highPrice': 693,
#    'lowPrice': 656,
#    'closePrice': 688,
#    'change': 38,
#    'changePercent': 5.85,
#    'tradeVolume': 4856,
#    'tradeValue': 3287859000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2356',
#    'name': '英業達',
#    'openPrice': 57.1,
#    'highPrice': 57.4,
#    'lowPrice': 55,
#    'closePrice': 55.1,
#    'change': -1.2,
#    'changePercent': -2.13,
#    'tradeVolume': 57806,
#    'tradeValue': 3250661200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00919',
#    'name': '群益台灣精選高息',
#    'openPrice': 23.88,
#    'highPrice': 23.97,
#    'lowPrice': 23.63,
#    'closePrice': 23.63,
#    'change': 0.01,
#    'changePercent': 0.04,
#    'tradeVolume': 133732,
#    'tradeValue': 3182184830,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3037',
#    'name': '欣興',
#    'openPrice': 191,
#    'highPrice': 192.5,
#    'lowPrice': 187,
#    'closePrice': 188,
#    'change': -1,
#    'changePercent': -0.53,
#    'tradeVolume': 16066,
#    'tradeValue': 3045827000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6442',
#    'name': '光聖',
#    'openPrice': 158.5,
#    'highPrice': 161.5,
#    'lowPrice': 141.5,
#    'closePrice': 145.5,
#    'change': -5.5,
#    'changePercent': -3.64,
#    'tradeVolume': 19773,
#    'tradeValue': 3015713500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6285',
#    'name': '啟碁',
#    'openPrice': 157,
#    'highPrice': 160,
#    'lowPrice': 153,
#    'closePrice': 156,
#    'change': -0.5,
#    'changePercent': -0.32,
#    'tradeVolume': 19069,
#    'tradeValue': 2990773500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3025',
#    'name': '星通',
#    'openPrice': 84.5,
#    'highPrice': 85,
#    'lowPrice': 76.9,
#    'closePrice': 77,
#    'change': -3.3,
#    'changePercent': -4.11,
#    'tradeVolume': 35828,
#    'tradeValue': 2894921900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '0050',
#    'name': '元大台灣50',
#    'openPrice': 143.45,
#    'highPrice': 144.1,
#    'lowPrice': 143.3,
#    'closePrice': 143.75,
#    'change': 0.95,
#    'changePercent': 0.67,
#    'tradeVolume': 19128,
#    'tradeValue': 2750682150,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3583',
#    'name': '辛耘',
#    'openPrice': 258,
#    'highPrice': 278.5,
#    'lowPrice': 256.5,
#    'closePrice': 278.5,
#    'change': 25,
#    'changePercent': 9.86,
#    'tradeVolume': 9985,
#    'tradeValue': 2714591500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2308',
#    'name': '台達電',
#    'openPrice': 294,
#    'highPrice': 295,
#    'lowPrice': 292,
#    'closePrice': 292.5,
#    'change': -1,
#    'changePercent': -0.34,
#    'tradeVolume': 9043,
#    'tradeValue': 2656820000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6189',
#    'name': '豐藝',
#    'openPrice': 88.6,
#    'highPrice': 90.5,
#    'lowPrice': 80.2,
#    'closePrice': 82,
#    'change': -3.8,
#    'changePercent': -4.43,
#    'tradeVolume': 30870,
#    'tradeValue': 2638099200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2303',
#    'name': '聯電',
#    'openPrice': 48.5,
#    'highPrice': 48.9,
#    'lowPrice': 48.15,
#    'closePrice': 48.15,
#    'change': -0.45,
#    'changePercent': -0.93,
#    'tradeVolume': 53842,
#    'tradeValue': 2608412500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '9958',
#    'name': '世紀鋼',
#    'openPrice': 255.5,
#    'highPrice': 268,
#    'lowPrice': 252,
#    'closePrice': 253,
#    'change': -1.5,
#    'changePercent': -0.59,
#    'tradeVolume': 9882,
#    'tradeValue': 2557027500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6531',
#    'name': '愛普*',
#    'openPrice': 454,
#    'highPrice': 457,
#    'lowPrice': 439.5,
#    'closePrice': 439.5,
#    'change': -10.5,
#    'changePercent': -2.33,
#    'tradeVolume': 5550,
#    'tradeValue': 2464353500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00878',
#    'name': '國泰永續高股息',
#    'openPrice': 22.5,
#    'highPrice': 22.6,
#    'lowPrice': 22.46,
#    'closePrice': 22.46,
#    'change': 0.05,
#    'changePercent': 0.22,
#    'tradeVolume': 109023,
#    'tradeValue': 2456856940,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3450',
#    'name': '聯鈞',
#    'openPrice': 68.9,
#    'highPrice': 73.8,
#    'lowPrice': 67.7,
#    'closePrice': 70.4,
#    'change': 2.3,
#    'changePercent': 3.38,
#    'tradeVolume': 33589,
#    'tradeValue': 2392405100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2371',
#    'name': '大同',
#    'openPrice': 45.6,
#    'highPrice': 47.45,
#    'lowPrice': 44.7,
#    'closePrice': 46.75,
#    'change': 1.35,
#    'changePercent': 2.97,
#    'tradeVolume': 49141,
#    'tradeValue': 2283800200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4763',
#    'name': '材料-KY',
#    'openPrice': 864,
#    'highPrice': 884,
#    'lowPrice': 864,
#    'closePrice': 869,
#    'change': 11,
#    'changePercent': 1.28,
#    'tradeVolume': 2548,
#    'tradeValue': 2228903000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2360',
#    'name': '致茂',
#    'openPrice': 235.5,
#    'highPrice': 251,
#    'lowPrice': 235,
#    'closePrice': 239,
#    'change': 7.5,
#    'changePercent': 3.24,
#    'tradeVolume': 8523,
#    'tradeValue': 2064771000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3711',
#    'name': '日月光投控',
#    'openPrice': 140,
#    'highPrice': 143,
#    'lowPrice': 139,
#    'closePrice': 141.5,
#    'change': 3,
#    'changePercent': 2.17,
#    'tradeVolume': 14274,
#    'tradeValue': 2017298000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3008',
#    'name': '大立光',
#    'openPrice': 2550,
#    'highPrice': 2565,
#    'lowPrice': 2515,
#    'closePrice': 2545,
#    'change': 15,
#    'changePercent': 0.59,
#    'tradeVolume': 783,
#    'tradeValue': 1988995000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2609',
#    'name': '陽明',
#    'openPrice': 50.2,
#    'highPrice': 50.4,
#    'lowPrice': 48.85,
#    'closePrice': 49.1,
#    'change': -0.85,
#    'changePercent': -1.7,
#    'tradeVolume': 39324,
#    'tradeValue': 1945113950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8210',
#    'name': '勤誠',
#    'openPrice': 281.5,
#    'highPrice': 286,
#    'lowPrice': 270,
#    'closePrice': 270,
#    'change': -5,
#    'changePercent': -1.82,
#    'tradeVolume': 6899,
#    'tradeValue': 1917514000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5388',
#    'name': '中磊',
#    'openPrice': 137,
#    'highPrice': 140.5,
#    'lowPrice': 134,
#    'closePrice': 139.5,
#    'change': 3,
#    'changePercent': 2.2,
#    'tradeVolume': 13876,
#    'tradeValue': 1914024500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3036',
#    'name': '文曄',
#    'openPrice': 174.5,
#    'highPrice': 176.5,
#    'lowPrice': 169.5,
#    'closePrice': 169.5,
#    'change': -4,
#    'changePercent': -2.31,
#    'tradeVolume': 10608,
#    'tradeValue': 1826649000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2317',
#    'name': '鴻海',
#    'openPrice': 103.5,
#    'highPrice': 104,
#    'lowPrice': 103,
#    'closePrice': 103,
#    'change': -0.5,
#    'changePercent': -0.48,
#    'tradeVolume': 17187,
#    'tradeValue': 1775210000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3005',
#    'name': '神基',
#    'openPrice': 119.5,
#    'highPrice': 120.5,
#    'lowPrice': 113.5,
#    'closePrice': 114,
#    'change': -5,
#    'changePercent': -4.2,
#    'tradeVolume': 15275,
#    'tradeValue': 1775209500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2353',
#    'name': '宏碁',
#    'openPrice': 47.25,
#    'highPrice': 47.45,
#    'lowPrice': 45.75,
#    'closePrice': 45.75,
#    'change': -1.1,
#    'changePercent': -2.35,
#    'tradeVolume': 36897,
#    'tradeValue': 1716003900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2357',
#    'name': '華碩',
#    'openPrice': 473,
#    'highPrice': 482.5,
#    'lowPrice': 473,
#    'closePrice': 474,
#    'change': 5,
#    'changePercent': 1.07,
#    'tradeVolume': 3535,
#    'tradeValue': 1690962500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2301',
#    'name': '光寶科',
#    'openPrice': 110,
#    'highPrice': 110.5,
#    'lowPrice': 108.5,
#    'closePrice': 108.5,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 15242,
#    'tradeValue': 1670351500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6451',
#    'name': '訊芯-KY',
#    'openPrice': 230.5,
#    'highPrice': 232,
#    'lowPrice': 213,
#    'closePrice': 220.5,
#    'change': -3.5,
#    'changePercent': -1.56,
#    'tradeVolume': 7534,
#    'tradeValue': 1664638500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2408',
#    'name': '南亞科',
#    'openPrice': 68.7,
#    'highPrice': 69.2,
#    'lowPrice': 67.6,
#    'closePrice': 67.7,
#    'change': -0.4,
#    'changePercent': -0.59,
#    'tradeVolume': 24098,
#    'tradeValue': 1648602300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6257',
#    'name': '矽格',
#    'openPrice': 72.5,
#    'highPrice': 75,
#    'lowPrice': 72,
#    'closePrice': 72.5,
#    'change': 1.7,
#    'changePercent': 2.4,
#    'tradeVolume': 22220,
#    'tradeValue': 1630891000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3044',
#    'name': '健鼎',
#    'openPrice': 220,
#    'highPrice': 220.5,
#    'lowPrice': 213,
#    'closePrice': 214,
#    'change': -5.5,
#    'changePercent': -2.51,
#    'tradeVolume': 7447,
#    'tradeValue': 1602983500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2345',
#    'name': '智邦',
#    'openPrice': 545,
#    'highPrice': 550,
#    'lowPrice': 531,
#    'closePrice': 532,
#    'change': -3,
#    'changePercent': -0.56,
#    'tradeVolume': 2591,
#    'tradeValue': 1395326000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4968',
#    'name': '立積',
#    'openPrice': 228,
#    'highPrice': 232,
#    'lowPrice': 220,
#    'closePrice': 223.5,
#    'change': -2.5,
#    'changePercent': -1.11,
#    'tradeVolume': 6169,
#    'tradeValue': 1388531000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4770',
#    'name': '上品',
#    'openPrice': 351.5,
#    'highPrice': 385,
#    'lowPrice': 346,
#    'closePrice': 378,
#    'change': 28,
#    'changePercent': 8,
#    'tradeVolume': 3705,
#    'tradeValue': 1378658500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2618',
#    'name': '長榮航',
#    'openPrice': 31.2,
#    'highPrice': 31.25,
#    'lowPrice': 30.8,
#    'closePrice': 30.8,
#    'change': -0.4,
#    'changePercent': -1.28,
#    'tradeVolume': 43746,
#    'tradeValue': 1354223700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5258',
#    'name': '虹堡',
#    'openPrice': 136,
#    'highPrice': 140,
#    'lowPrice': 131.5,
#    'closePrice': 132,
#    'change': -2,
#    'changePercent': -1.49,
#    'tradeVolume': 9528,
#    'tradeValue': 1301712000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3653',
#    'name': '健策',
#    'openPrice': 853,
#    'highPrice': 876,
#    'lowPrice': 848,
#    'closePrice': 855,
#    'change': 16,
#    'changePercent': 1.91,
#    'tradeVolume': 1501,
#    'tradeValue': 1292004000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2458',
#    'name': '義隆',
#    'openPrice': 165,
#    'highPrice': 167,
#    'lowPrice': 160,
#    'closePrice': 164,
#    'change': -3.5,
#    'changePercent': -2.09,
#    'tradeVolume': 7839,
#    'tradeValue': 1284291000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8996',
#    'name': '高力',
#    'openPrice': 280,
#    'highPrice': 280.5,
#    'lowPrice': 270,
#    'closePrice': 270,
#    'change': -7,
#    'changePercent': -2.53,
#    'tradeVolume': 4540,
#    'tradeValue': 1247611500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2327',
#    'name': '國巨',
#    'openPrice': 554,
#    'highPrice': 554,
#    'lowPrice': 541,
#    'closePrice': 541,
#    'change': -11,
#    'changePercent': -1.99,
#    'tradeVolume': 2280,
#    'tradeValue': 1245280000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '0056',
#    'name': '元大高股息',
#    'openPrice': 37.82,
#    'highPrice': 37.98,
#    'lowPrice': 37.59,
#    'closePrice': 37.59,
#    'change': -0.06,
#    'changePercent': -0.16,
#    'tradeVolume': 31116,
#    'tradeValue': 1176449960,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3413',
#    'name': '京鼎',
#    'openPrice': 247.5,
#    'highPrice': 254.5,
#    'lowPrice': 244.5,
#    'closePrice': 250,
#    'change': 5,
#    'changePercent': 2.04,
#    'tradeVolume': 4551,
#    'tradeValue': 1140327000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3596',
#    'name': '智易',
#    'openPrice': 182,
#    'highPrice': 186,
#    'lowPrice': 180,
#    'closePrice': 183.5,
#    'change': 5,
#    'changePercent': 2.8,
#    'tradeVolume': 6069,
#    'tradeValue': 1115338000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6806',
#    'name': '森崴能源',
#    'openPrice': 125.5,
#    'highPrice': 128,
#    'lowPrice': 122,
#    'closePrice': 124,
#    'change': 0.5,
#    'changePercent': 0.4,
#    'tradeVolume': 8864,
#    'tradeValue': 1111688000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3481',
#    'name': '群創',
#    'openPrice': 15.8,
#    'highPrice': 15.8,
#    'lowPrice': 15.5,
#    'closePrice': 15.55,
#    'change': -0.25,
#    'changePercent': -1.58,
#    'tradeVolume': 70573,
#    'tradeValue': 1101656950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3533',
#    'name': '嘉澤',
#    'openPrice': 1065,
#    'highPrice': 1065,
#    'lowPrice': 1035,
#    'closePrice': 1050,
#    'change': 5,
#    'changePercent': 0.48,
#    'tradeVolume': 1037,
#    'tradeValue': 1089140000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6415',
#    'name': '矽力*-KY',
#    'openPrice': 420.5,
#    'highPrice': 424.5,
#    'lowPrice': 410.5,
#    'closePrice': 410.5,
#    'change': -10.5,
#    'changePercent': -2.49,
#    'tradeVolume': 2588,
#    'tradeValue': 1080365000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6239',
#    'name': '力成',
#    'openPrice': 147.5,
#    'highPrice': 151.5,
#    'lowPrice': 147,
#    'closePrice': 149.5,
#    'change': 3,
#    'changePercent': 2.05,
#    'tradeVolume': 7117,
#    'tradeValue': 1064002000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2388',
#    'name': '威盛',
#    'openPrice': 134,
#    'highPrice': 137,
#    'lowPrice': 133.5,
#    'closePrice': 134,
#    'change': 1.5,
#    'changePercent': 1.13,
#    'tradeVolume': 7826,
#    'tradeValue': 1058259000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3715',
#    'name': '定穎投控',
#    'openPrice': 78.8,
#    'highPrice': 79.2,
#    'lowPrice': 74.2,
#    'closePrice': 74.2,
#    'change': -4,
#    'changePercent': -5.12,
#    'tradeVolume': 13193,
#    'tradeValue': 1007433100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8467',
#    'name': '波力-KY',
#    'openPrice': 200.5,
#    'highPrice': 205.5,
#    'lowPrice': 176.5,
#    'closePrice': 178.5,
#    'change': -15.5,
#    'changePercent': -7.99,
#    'tradeVolume': 5206,
#    'tradeValue': 987145000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00637L',
#    'name': '元大滬深300正2',
#    'openPrice': 12.79,
#    'highPrice': 12.9,
#    'lowPrice': 12.63,
#    'closePrice': 12.73,
#    'change': 0.02,
#    'changePercent': 0.16,
#    'tradeVolume': 76862,
#    'tradeValue': 981560360,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6196',
#    'name': '帆宣',
#    'openPrice': 161.5,
#    'highPrice': 165,
#    'lowPrice': 159.5,
#    'closePrice': 159.5,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 5815,
#    'tradeValue': 942053000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3706',
#    'name': '神達',
#    'openPrice': 44.9,
#    'highPrice': 45.8,
#    'lowPrice': 43.6,
#    'closePrice': 43.6,
#    'change': -0.85,
#    'changePercent': -1.91,
#    'tradeVolume': 20934,
#    'tradeValue': 935982600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6719',
#    'name': '力智',
#    'openPrice': 297,
#    'highPrice': 307.5,
#    'lowPrice': 297,
#    'closePrice': 297,
#    'change': 2,
#    'changePercent': 0.68,
#    'tradeVolume': 3016,
#    'tradeValue': 907847500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3588',
#    'name': '通嘉',
#    'openPrice': 106,
#    'highPrice': 109,
#    'lowPrice': 100,
#    'closePrice': 101,
#    'change': -2,
#    'changePercent': -1.94,
#    'tradeVolume': 8678,
#    'tradeValue': 897412000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2455',
#    'name': '全新',
#    'openPrice': 167,
#    'highPrice': 169.5,
#    'lowPrice': 163.5,
#    'closePrice': 167.5,
#    'change': 2,
#    'changePercent': 1.21,
#    'tradeVolume': 5283,
#    'tradeValue': 883865500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2324',
#    'name': '仁寶',
#    'openPrice': 36.9,
#    'highPrice': 37.2,
#    'lowPrice': 36.2,
#    'closePrice': 36.2,
#    'change': -0.55,
#    'changePercent': -1.5,
#    'tradeVolume': 24049,
#    'tradeValue': 882051700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00830',
#    'name': '國泰費城半導體',
#    'openPrice': 41.46,
#    'highPrice': 41.47,
#    'lowPrice': 41.24,
#    'closePrice': 41.31,
#    'change': 0.48,
#    'changePercent': 1.18,
#    'tradeVolume': 21089,
#    'tradeValue': 871575640,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2385',
#    'name': '群光',
#    'openPrice': 191,
#    'highPrice': 193,
#    'lowPrice': 183.5,
#    'closePrice': 185.5,
#    'change': -4.5,
#    'changePercent': -2.37,
#    'tradeVolume': 4614,
#    'tradeValue': 860869000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3006',
#    'name': '晶豪科',
#    'openPrice': 94.1,
#    'highPrice': 95.7,
#    'lowPrice': 91.5,
#    'closePrice': 91.5,
#    'change': -1.5,
#    'changePercent': -1.61,
#    'tradeVolume': 9059,
#    'tradeValue': 845450100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2405',
#    'name': '輔信',
#    'openPrice': 19.8,
#    'highPrice': 21,
#    'lowPrice': 19.65,
#    'closePrice': 20.55,
#    'change': 1.25,
#    'changePercent': 6.48,
#    'tradeVolume': 41176,
#    'tradeValue': 844020050,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2377',
#    'name': '微星',
#    'openPrice': 191,
#    'highPrice': 194,
#    'lowPrice': 190.5,
#    'closePrice': 191.5,
#    'change': 2,
#    'changePercent': 1.06,
#    'tradeVolume': 4373,
#    'tradeValue': 840585000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3041',
#    'name': '揚智',
#    'openPrice': 32.85,
#    'highPrice': 33.6,
#    'lowPrice': 31.4,
#    'closePrice': 31.45,
#    'change': -0.8,
#    'changePercent': -2.48,
#    'tradeVolume': 25133,
#    'tradeValue': 814765700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2344',
#    'name': '華邦電',
#    'openPrice': 28.15,
#    'highPrice': 28.2,
#    'lowPrice': 27.65,
#    'closePrice': 27.65,
#    'change': -0.25,
#    'changePercent': -0.9,
#    'tradeVolume': 28845,
#    'tradeValue': 804243000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1536',
#    'name': '和大',
#    'openPrice': 53,
#    'highPrice': 54.9,
#    'lowPrice': 52.9,
#    'closePrice': 54.6,
#    'change': 2.4,
#    'changePercent': 4.6,
#    'tradeVolume': 14759,
#    'tradeValue': 798866600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1316',
#    'name': '上曜',
#    'openPrice': 17.35,
#    'highPrice': 18.55,
#    'lowPrice': 17.1,
#    'closePrice': 17.85,
#    'change': 0.55,
#    'changePercent': 3.18,
#    'tradeVolume': 44453,
#    'tradeValue': 798281900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6533',
#    'name': '晶心科',
#    'openPrice': 502,
#    'highPrice': 505,
#    'lowPrice': 486.5,
#    'closePrice': 486.5,
#    'change': -8.5,
#    'changePercent': -1.72,
#    'tradeVolume': 1608,
#    'tradeValue': 794269000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6117',
#    'name': '迎廣',
#    'openPrice': 78.1,
#    'highPrice': 82.6,
#    'lowPrice': 76.3,
#    'closePrice': 76.4,
#    'change': -0.7,
#    'changePercent': -0.91,
#    'tradeVolume': 9463,
#    'tradeValue': 749546300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2891',
#    'name': '中信金',
#    'openPrice': 29.2,
#    'highPrice': 29.3,
#    'lowPrice': 28.9,
#    'closePrice': 28.9,
#    'change': -0.4,
#    'changePercent': -1.37,
#    'tradeVolume': 25421,
#    'tradeValue': 740615900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2049',
#    'name': '上銀',
#    'openPrice': 262,
#    'highPrice': 265,
#    'lowPrice': 255,
#    'closePrice': 255,
#    'change': -2.5,
#    'changePercent': -0.97,
#    'tradeVolume': 2757,
#    'tradeValue': 712910000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3563',
#    'name': '牧德',
#    'openPrice': 315.5,
#    'highPrice': 323.5,
#    'lowPrice': 308,
#    'closePrice': 315,
#    'change': 6.5,
#    'changePercent': 2.11,
#    'tradeVolume': 2208,
#    'tradeValue': 698314000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3376',
#    'name': '新日興',
#    'openPrice': 172,
#    'highPrice': 172.5,
#    'lowPrice': 165.5,
#    'closePrice': 166,
#    'change': -3.5,
#    'changePercent': -2.06,
#    'tradeVolume': 3956,
#    'tradeValue': 663642000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1590',
#    'name': '亞德客-KY',
#    'openPrice': 1080,
#    'highPrice': 1090,
#    'lowPrice': 1040,
#    'closePrice': 1060,
#    'change': -25,
#    'changePercent': -2.3,
#    'tradeVolume': 623,
#    'tradeValue': 662390000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6168',
#    'name': '宏齊',
#    'openPrice': 28.15,
#    'highPrice': 30.2,
#    'lowPrice': 28.15,
#    'closePrice': 29.3,
#    'change': 1.35,
#    'changePercent': 4.83,
#    'tradeVolume': 22584,
#    'tradeValue': 661180300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3702',
#    'name': '大聯大',
#    'openPrice': 92.2,
#    'highPrice': 95.5,
#    'lowPrice': 92.2,
#    'closePrice': 94.4,
#    'change': 2.9,
#    'changePercent': 3.17,
#    'tradeVolume': 7003,
#    'tradeValue': 659957700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2331',
#    'name': '精英',
#    'openPrice': 29.85,
#    'highPrice': 32.15,
#    'lowPrice': 29.8,
#    'closePrice': 31,
#    'change': 1.5,
#    'changePercent': 5.08,
#    'tradeVolume': 20961,
#    'tradeValue': 654416300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6282',
#    'name': '康舒',
#    'openPrice': 41.7,
#    'highPrice': 41.8,
#    'lowPrice': 40.55,
#    'closePrice': 40.55,
#    'change': -0.95,
#    'changePercent': -2.29,
#    'tradeVolume': 15929,
#    'tradeValue': 653319750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6288',
#    'name': '聯嘉',
#    'openPrice': 33.9,
#    'highPrice': 36,
#    'lowPrice': 33.4,
#    'closePrice': 35.4,
#    'change': 1.8,
#    'changePercent': 5.36,
#    'tradeVolume': 18640,
#    'tradeValue': 650065600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2882',
#    'name': '國泰金',
#    'openPrice': 44.8,
#    'highPrice': 44.85,
#    'lowPrice': 44.45,
#    'closePrice': 44.45,
#    'change': -0.45,
#    'changePercent': -1,
#    'tradeVolume': 14486,
#    'tradeValue': 646660050,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2395',
#    'name': '研華',
#    'openPrice': 385.5,
#    'highPrice': 387,
#    'lowPrice': 379.5,
#    'closePrice': 380,
#    'change': -7,
#    'changePercent': -1.81,
#    'tradeVolume': 1669,
#    'tradeValue': 641394500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2881',
#    'name': '富邦金',
#    'openPrice': 66.8,
#    'highPrice': 66.8,
#    'lowPrice': 66.5,
#    'closePrice': 66.6,
#    'change': 0.1,
#    'changePercent': 0.15,
#    'tradeVolume': 9586,
#    'tradeValue': 639242000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2884',
#    'name': '玉山金',
#    'openPrice': 24.5,
#    'highPrice': 24.55,
#    'lowPrice': 24.4,
#    'closePrice': 24.4,
#    'change': -0.1,
#    'changePercent': -0.41,
#    'tradeVolume': 25941,
#    'tradeValue': 635248400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00881',
#    'name': '國泰台灣5G+',
#    'openPrice': 19.06,
#    'highPrice': 19.24,
#    'lowPrice': 19.06,
#    'closePrice': 19.15,
#    'change': 0.18,
#    'changePercent': 0.95,
#    'tradeVolume': 33069,
#    'tradeValue': 633665830,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5469',
#    'name': '瀚宇博',
#    'openPrice': 61,
#    'highPrice': 61,
#    'lowPrice': 58.3,
#    'closePrice': 58.4,
#    'change': -3.6,
#    'changePercent': -5.81,
#    'tradeVolume': 10504,
#    'tradeValue': 623116000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1504',
#    'name': '東元',
#    'openPrice': 47.5,
#    'highPrice': 48.15,
#    'lowPrice': 47.2,
#    'closePrice': 47.95,
#    'change': 0.9,
#    'changePercent': 1.91,
#    'tradeVolume': 12971,
#    'tradeValue': 620375350,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6491',
#    'name': '晶碩',
#    'openPrice': 403.5,
#    'highPrice': 413.5,
#    'lowPrice': 396.5,
#    'closePrice': 396.5,
#    'change': -2,
#    'changePercent': -0.5,
#    'tradeVolume': 1526,
#    'tradeValue': 618300000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1795',
#    'name': '美時',
#    'openPrice': 274,
#    'highPrice': 275,
#    'lowPrice': 271,
#    'closePrice': 272,
#    'change': -1,
#    'changePercent': -0.37,
#    'tradeVolume': 2246,
#    'tradeValue': 612686000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3047',
#    'name': '訊舟',
#    'openPrice': 19.3,
#    'highPrice': 19.75,
#    'lowPrice': 18.5,
#    'closePrice': 18.5,
#    'change': -0.6,
#    'changePercent': -3.14,
#    'tradeVolume': 31884,
#    'tradeValue': 610952150,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6409',
#    'name': '旭隼',
#    'openPrice': 1535,
#    'highPrice': 1580,
#    'lowPrice': 1515,
#    'closePrice': 1535,
#    'change': 15,
#    'changePercent': 0.99,
#    'tradeVolume': 381,
#    'tradeValue': 590145000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6579',
#    'name': '研揚',
#    'openPrice': 164,
#    'highPrice': 178.5,
#    'lowPrice': 163.5,
#    'closePrice': 169,
#    'change': 6.5,
#    'changePercent': 4,
#    'tradeVolume': 3390,
#    'tradeValue': 589837000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3032',
#    'name': '偉訓',
#    'openPrice': 81.9,
#    'highPrice': 83.1,
#    'lowPrice': 79.1,
#    'closePrice': 79.4,
#    'change': -1.5,
#    'changePercent': -1.85,
#    'tradeVolume': 7167,
#    'tradeValue': 579229800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1609',
#    'name': '大亞',
#    'openPrice': 36.55,
#    'highPrice': 36.9,
#    'lowPrice': 35.95,
#    'closePrice': 36.25,
#    'change': -0.15,
#    'changePercent': -0.41,
#    'tradeVolume': 15734,
#    'tradeValue': 573457500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3055',
#    'name': '蔚華科',
#    'openPrice': 84.2,
#    'highPrice': 84.6,
#    'lowPrice': 81.1,
#    'closePrice': 81.6,
#    'change': -1.7,
#    'changePercent': -2.04,
#    'tradeVolume': 6923,
#    'tradeValue': 572850800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3515',
#    'name': '華擎',
#    'openPrice': 245,
#    'highPrice': 254.5,
#    'lowPrice': 240,
#    'closePrice': 249.5,
#    'change': 8.5,
#    'changePercent': 3.53,
#    'tradeVolume': 2300,
#    'tradeValue': 571215000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4904',
#    'name': '遠傳',
#    'openPrice': 80.8,
#    'highPrice': 81,
#    'lowPrice': 79,
#    'closePrice': 79.4,
#    'change': -1.9,
#    'changePercent': -2.34,
#    'tradeVolume': 7140,
#    'tradeValue': 569009600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00662',
#    'name': '富邦NASDAQ',
#    'openPrice': 72.95,
#    'highPrice': 73.15,
#    'lowPrice': 72.9,
#    'closePrice': 73,
#    'change': 1.05,
#    'changePercent': 1.46,
#    'tradeVolume': 7775,
#    'tradeValue': 567356100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2363',
#    'name': '矽統',
#    'openPrice': 44.5,
#    'highPrice': 44.5,
#    'lowPrice': 42.7,
#    'closePrice': 42.7,
#    'change': -1.3,
#    'changePercent': -2.95,
#    'tradeVolume': 12909,
#    'tradeValue': 558724600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1303',
#    'name': '南亞',
#    'openPrice': 60,
#    'highPrice': 60.2,
#    'lowPrice': 59.7,
#    'closePrice': 59.7,
#    'change': -0.8,
#    'changePercent': -1.32,
#    'tradeVolume': 9190,
#    'tradeValue': 550568800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4961',
#    'name': '天鈺',
#    'openPrice': 254,
#    'highPrice': 254.5,
#    'lowPrice': 245,
#    'closePrice': 245.5,
#    'change': -5.5,
#    'changePercent': -2.19,
#    'tradeVolume': 2213,
#    'tradeValue': 550146500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3013',
#    'name': '晟銘電',
#    'openPrice': 47.85,
#    'highPrice': 49.15,
#    'lowPrice': 46.05,
#    'closePrice': 46.35,
#    'change': -1.45,
#    'changePercent': -3.03,
#    'tradeVolume': 11475,
#    'tradeValue': 548447250,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2355',
#    'name': '敬鵬',
#    'openPrice': 52.2,
#    'highPrice': 52.2,
#    'lowPrice': 50.2,
#    'closePrice': 50.5,
#    'change': -1.2,
#    'changePercent': -2.32,
#    'tradeVolume': 10658,
#    'tradeValue': 543532800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6139',
#    'name': '亞翔',
#    'openPrice': 166.5,
#    'highPrice': 170,
#    'lowPrice': 165.5,
#    'closePrice': 166,
#    'change': 0.5,
#    'changePercent': 0.3,
#    'tradeVolume': 3237,
#    'tradeValue': 541545500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1717',
#    'name': '長興',
#    'openPrice': 30.8,
#    'highPrice': 32.45,
#    'lowPrice': 30.5,
#    'closePrice': 31.75,
#    'change': 1.45,
#    'changePercent': 4.79,
#    'tradeVolume': 16839,
#    'tradeValue': 535795600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2606',
#    'name': '裕民',
#    'openPrice': 53.8,
#    'highPrice': 54.3,
#    'lowPrice': 53.2,
#    'closePrice': 53.6,
#    'change': 0.9,
#    'changePercent': 1.71,
#    'tradeVolume': 9814,
#    'tradeValue': 527817400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5871',
#    'name': '中租-KY',
#    'openPrice': 175.5,
#    'highPrice': 177.5,
#    'lowPrice': 175,
#    'closePrice': 176,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 2961,
#    'tradeValue': 522601000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00770',
#    'name': '國泰北美科技',
#    'openPrice': 40.56,
#    'highPrice': 40.65,
#    'lowPrice': 40.53,
#    'closePrice': 40.65,
#    'change': 0.83,
#    'changePercent': 2.08,
#    'tradeVolume': 12542,
#    'tradeValue': 508891400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4938',
#    'name': '和碩',
#    'openPrice': 86.7,
#    'highPrice': 87.2,
#    'lowPrice': 85.8,
#    'closePrice': 85.9,
#    'change': -0.7,
#    'changePercent': -0.81,
#    'tradeVolume': 5763,
#    'tradeValue': 499616500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2031',
#    'name': '新光鋼',
#    'openPrice': 60.6,
#    'highPrice': 63.9,
#    'lowPrice': 60.2,
#    'closePrice': 62.8,
#    'change': 2.3,
#    'changePercent': 3.8,
#    'tradeVolume': 7708,
#    'tradeValue': 483437900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2610',
#    'name': '華航',
#    'openPrice': 20.1,
#    'highPrice': 20.1,
#    'lowPrice': 19.85,
#    'closePrice': 19.85,
#    'change': -0.15,
#    'changePercent': -0.75,
#    'tradeVolume': 24147,
#    'tradeValue': 481347350,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3312',
#    'name': '弘憶股',
#    'openPrice': 36,
#    'highPrice': 38.65,
#    'lowPrice': 35.9,
#    'closePrice': 38.65,
#    'change': 3.5,
#    'changePercent': 9.96,
#    'tradeVolume': 12552,
#    'tradeValue': 476702750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3712',
#    'name': '永崴投控',
#    'openPrice': 46.1,
#    'highPrice': 46.65,
#    'lowPrice': 44.9,
#    'closePrice': 45,
#    'change': -0.8,
#    'changePercent': -1.75,
#    'tradeVolume': 10361,
#    'tradeValue': 476125500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6799',
#    'name': '來頡',
#    'openPrice': 189,
#    'highPrice': 189,
#    'lowPrice': 181.5,
#    'closePrice': 182,
#    'change': -6,
#    'changePercent': -3.19,
#    'tradeVolume': 2544,
#    'tradeValue': 469421500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4915',
#    'name': '致伸',
#    'openPrice': 72.2,
#    'highPrice': 72.6,
#    'lowPrice': 71.3,
#    'closePrice': 72.4,
#    'change': 1.2,
#    'changePercent': 1.69,
#    'tradeVolume': 6503,
#    'tradeValue': 468969300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00713',
#    'name': '元大台灣高息低波',
#    'openPrice': 51.55,
#    'highPrice': 51.55,
#    'lowPrice': 51.1,
#    'closePrice': 51.1,
#    'change': -0.3,
#    'changePercent': -0.58,
#    'tradeVolume': 9131,
#    'tradeValue': 468753800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6756',
#    'name': '威鋒電子',
#    'openPrice': 263,
#    'highPrice': 274,
#    'lowPrice': 262.5,
#    'closePrice': 266.5,
#    'change': 7.5,
#    'changePercent': 2.9,
#    'tradeVolume': 1720,
#    'tradeValue': 463061500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8046',
#    'name': '南電',
#    'openPrice': 225.5,
#    'highPrice': 226.5,
#    'lowPrice': 221.5,
#    'closePrice': 221.5,
#    'change': -3.5,
#    'changePercent': -1.56,
#    'tradeVolume': 2020,
#    'tradeValue': 450956500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1301',
#    'name': '台塑',
#    'openPrice': 72.5,
#    'highPrice': 72.7,
#    'lowPrice': 72,
#    'closePrice': 72,
#    'change': -1.2,
#    'changePercent': -1.64,
#    'tradeVolume': 6214,
#    'tradeValue': 449154400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2412',
#    'name': '中華電',
#    'openPrice': 122,
#    'highPrice': 122.5,
#    'lowPrice': 122,
#    'closePrice': 122,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 3657,
#    'tradeValue': 446751000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00632R',
#    'name': '元大台灣50反1',
#    'openPrice': 4.21,
#    'highPrice': 4.23,
#    'lowPrice': 4.2,
#    'closePrice': 4.22,
#    'change': -0.02,
#    'changePercent': -0.47,
#    'tradeVolume': 105264,
#    'tradeValue': 443410120,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6438',
#    'name': '迅得',
#    'openPrice': 110.5,
#    'highPrice': 114.5,
#    'lowPrice': 109.5,
#    'closePrice': 112,
#    'change': 3,
#    'changePercent': 2.75,
#    'tradeVolume': 3908,
#    'tradeValue': 440570500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2486',
#    'name': '一詮',
#    'openPrice': 50,
#    'highPrice': 50.2,
#    'lowPrice': 48.25,
#    'closePrice': 48.3,
#    'change': -1.4,
#    'changePercent': -2.82,
#    'tradeVolume': 8956,
#    'tradeValue': 437795900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4588',
#    'name': '玖鼎電力',
#    'openPrice': 98,
#    'highPrice': 101.5,
#    'lowPrice': 91.5,
#    'closePrice': 101.5,
#    'change': 8.9,
#    'changePercent': 9.61,
#    'tradeVolume': 4469,
#    'tradeValue': 437420200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00891',
#    'name': '中信關鍵半導體',
#    'openPrice': 17.5,
#    'highPrice': 17.7,
#    'lowPrice': 17.42,
#    'closePrice': 17.65,
#    'change': 0.33,
#    'changePercent': 1.91,
#    'tradeVolume': 24804,
#    'tradeValue': 436034650,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8454',
#    'name': '富邦媒',
#    'openPrice': 430,
#    'highPrice': 438.5,
#    'lowPrice': 427,
#    'closePrice': 430.5,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 1001,
#    'tradeValue': 433270000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2543',
#    'name': '皇昌',
#    'openPrice': 35.9,
#    'highPrice': 38,
#    'lowPrice': 35,
#    'closePrice': 35.5,
#    'change': 0.9,
#    'changePercent': 2.6,
#    'tradeVolume': 11800,
#    'tradeValue': 430226500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2474',
#    'name': '可成',
#    'openPrice': 200,
#    'highPrice': 200.5,
#    'lowPrice': 196.5,
#    'closePrice': 196.5,
#    'change': -4,
#    'changePercent': -2,
#    'tradeVolume': 2169,
#    'tradeValue': 430023000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2369',
#    'name': '菱生',
#    'openPrice': 27.5,
#    'highPrice': 27.65,
#    'lowPrice': 26.55,
#    'closePrice': 26.65,
#    'change': -0.6,
#    'changePercent': -2.2,
#    'tradeVolume': 15918,
#    'tradeValue': 429164400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6472',
#    'name': '保瑞',
#    'openPrice': 658,
#    'highPrice': 658,
#    'lowPrice': 646,
#    'closePrice': 646,
#    'change': -6,
#    'changePercent': -0.92,
#    'tradeVolume': 660,
#    'tradeValue': 427879000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1342',
#    'name': '八貫',
#    'openPrice': 120.5,
#    'highPrice': 125,
#    'lowPrice': 120.5,
#    'closePrice': 123,
#    'change': 9,
#    'changePercent': 7.89,
#    'tradeVolume': 3478,
#    'tradeValue': 427371000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2476',
#    'name': '鉅祥',
#    'openPrice': 80.8,
#    'highPrice': 81.3,
#    'lowPrice': 78.9,
#    'closePrice': 79.8,
#    'change': -1,
#    'changePercent': -1.24,
#    'tradeVolume': 5295,
#    'tradeValue': 423117900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3545',
#    'name': '敦泰',
#    'openPrice': 106.5,
#    'highPrice': 107,
#    'lowPrice': 103.5,
#    'closePrice': 104,
#    'change': -1.5,
#    'changePercent': -1.42,
#    'tradeVolume': 3999,
#    'tradeValue': 419398500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6213',
#    'name': '聯茂',
#    'openPrice': 90.2,
#    'highPrice': 91.2,
#    'lowPrice': 88.6,
#    'closePrice': 88.9,
#    'change': -0.8,
#    'changePercent': -0.89,
#    'tradeVolume': 4621,
#    'tradeValue': 414081000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '006208',
#    'name': '富邦台50',
#    'openPrice': 83.8,
#    'highPrice': 84.1,
#    'lowPrice': 83.7,
#    'closePrice': 83.9,
#    'change': 0.55,
#    'changePercent': 0.66,
#    'tradeVolume': 4909,
#    'tradeValue': 412026150,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1605',
#    'name': '華新',
#    'openPrice': 36.8,
#    'highPrice': 36.85,
#    'lowPrice': 35.95,
#    'closePrice': 36.05,
#    'change': -0.6,
#    'changePercent': -1.64,
#    'tradeVolume': 11351,
#    'tradeValue': 411658600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2409',
#    'name': '友達',
#    'openPrice': 17.85,
#    'highPrice': 18.05,
#    'lowPrice': 17.7,
#    'closePrice': 17.85,
#    'change': 0.05,
#    'changePercent': 0.28,
#    'tradeVolume': 22978,
#    'tradeValue': 411405550,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4967',
#    'name': '十銓',
#    'openPrice': 88.9,
#    'highPrice': 89.8,
#    'lowPrice': 85.8,
#    'closePrice': 85.9,
#    'change': -0.8,
#    'changePercent': -0.92,
#    'tradeVolume': 4700,
#    'tradeValue': 411294000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6515',
#    'name': '穎崴',
#    'openPrice': 777,
#    'highPrice': 782,
#    'lowPrice': 763,
#    'closePrice': 770,
#    'change': 6,
#    'changePercent': 0.79,
#    'tradeVolume': 529,
#    'tradeValue': 409910000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00893',
#    'name': '國泰智能電動車',
#    'openPrice': 19.53,
#    'highPrice': 19.69,
#    'lowPrice': 19.53,
#    'closePrice': 19.68,
#    'change': 0.69,
#    'changePercent': 3.63,
#    'tradeVolume': 20546,
# ...
#   {'type': 'EQUITY',
#    'symbol': '4930',
#    'name': '燦星網',
#    'openPrice': 33.95,
#    'highPrice': 33.95,
#    'lowPrice': 33.6,
#    'closePrice': 33.65,
#    'change': 0.05,
#    'changePercent': 0.15,
#    'tradeVolume': 120,
#    'tradeValue': 4044000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2243',
#    'name': '宏旭-KY',
#    'openPrice': 16.7,
#    'highPrice': 16.75,
#    'lowPrice': 16.45,
#    'closePrice': 16.45,
#    'change': -0.25,
#    'changePercent': -1.5,
#    'tradeVolume': 243,
#    'tradeValue': 4020200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4935',
#    'name': '茂林-KY',
#    'openPrice': 52,
#    'highPrice': 52,
#    'lowPrice': 51.5,
#    'closePrice': 51.8,
#    'change': -0.2,
#    'changePercent': -0.38,
#    'tradeVolume': 77,
#    'tradeValue': 3982000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6666',
#    'name': '羅麗芬-KY',
#    'openPrice': 67.3,
#    'highPrice': 67.3,
#    'lowPrice': 64.8,
#    'closePrice': 64.8,
#    'change': -1.6,
#    'changePercent': -2.41,
#    'tradeVolume': 60,
#    'tradeValue': 3969400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6916',
#    'name': '華凌',
#    'openPrice': 29.4,
#    'highPrice': 29.4,
#    'lowPrice': 28.9,
#    'closePrice': 29,
#    'change': -0.25,
#    'changePercent': -0.85,
#    'tradeVolume': 134,
#    'tradeValue': 3902200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2881A',
#    'name': '富邦特',
#    'openPrice': 61.8,
#    'highPrice': 61.9,
#    'lowPrice': 61.8,
#    'closePrice': 61.9,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 63,
#    'tradeValue': 3894500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2613',
#    'name': '中櫃',
#    'openPrice': 23.3,
#    'highPrice': 23.3,
#    'lowPrice': 22.75,
#    'closePrice': 22.8,
#    'change': -0.25,
#    'changePercent': -1.08,
#    'tradeVolume': 170,
#    'tradeValue': 3892450,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '01004T',
#    'name': '土銀富邦R2',
#    'openPrice': 13.24,
#    'highPrice': 13.3,
#    'lowPrice': 13.24,
#    'closePrice': 13.25,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 292,
#    'tradeValue': 3871660,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2109',
#    'name': '華豐',
#    'openPrice': 14.6,
#    'highPrice': 14.7,
#    'lowPrice': 14.55,
#    'closePrice': 14.55,
#    'change': -0.05,
#    'changePercent': -0.34,
#    'tradeVolume': 265,
#    'tradeValue': 3867300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00708L',
#    'name': '期元大S&P黃金正2',
#    'openPrice': 26.28,
#    'highPrice': 26.29,
#    'lowPrice': 26.22,
#    'closePrice': 26.25,
#    'change': -0.11,
#    'changePercent': -0.42,
#    'tradeVolume': 143,
#    'tradeValue': 3754830,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2107',
#    'name': '厚生',
#    'openPrice': 23.8,
#    'highPrice': 23.9,
#    'lowPrice': 23.75,
#    'closePrice': 23.75,
#    'change': -0.15,
#    'changePercent': -0.63,
#    'tradeVolume': 157,
#    'tradeValue': 3737800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1219',
#    'name': '福壽',
#    'openPrice': 19,
#    'highPrice': 19.1,
#    'lowPrice': 18.95,
#    'closePrice': 19,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 195,
#    'tradeValue': 3707350,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2115',
#    'name': '六暉-KY',
#    'openPrice': 30.85,
#    'highPrice': 30.85,
#    'lowPrice': 30.55,
#    'closePrice': 30.55,
#    'change': -0.1,
#    'changePercent': -0.33,
#    'tradeVolume': 121,
#    'tradeValue': 3706100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3528',
#    'name': '安馳',
#    'openPrice': 51.3,
#    'highPrice': 51.3,
#    'lowPrice': 50.2,
#    'closePrice': 50.6,
#    'change': -0.7,
#    'changePercent': -1.36,
#    'tradeVolume': 73,
#    'tradeValue': 3691300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1597',
#    'name': '直得',
#    'openPrice': 65.5,
#    'highPrice': 65.9,
#    'lowPrice': 65.3,
#    'closePrice': 65.4,
#    'change': -0.3,
#    'changePercent': -0.46,
#    'tradeVolume': 56,
#    'tradeValue': 3669400,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2430',
#    'name': '燦坤',
#    'openPrice': 38.7,
#    'highPrice': 38.8,
#    'lowPrice': 38.6,
#    'closePrice': 38.6,
#    'change': -0.1,
#    'changePercent': -0.26,
#    'tradeVolume': 94,
#    'tradeValue': 3636600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1437',
#    'name': '勤益控',
#    'openPrice': 31.2,
#    'highPrice': 31.2,
#    'lowPrice': 31,
#    'closePrice': 31.05,
#    'change': -0.15,
#    'changePercent': -0.48,
#    'tradeVolume': 117,
#    'tradeValue': 3635250,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '9905',
#    'name': '大華',
#    'openPrice': 24,
#    'highPrice': 24.05,
#    'lowPrice': 23.95,
#    'closePrice': 24.05,
#    'change': 0.05,
#    'changePercent': 0.21,
#    'tradeVolume': 150,
#    'tradeValue': 3597600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4426',
#    'name': '利勤',
#    'openPrice': 19.85,
#    'highPrice': 19.85,
#    'lowPrice': 19.5,
#    'closePrice': 19.55,
#    'change': -0.35,
#    'changePercent': -1.76,
#    'tradeVolume': 183,
#    'tradeValue': 3594000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4106',
#    'name': '雃博',
#    'openPrice': 28.7,
#    'highPrice': 28.85,
#    'lowPrice': 28.6,
#    'closePrice': 28.65,
#    'change': -0.15,
#    'changePercent': -0.52,
#    'tradeVolume': 125,
#    'tradeValue': 3587300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3130',
#    'name': '一零四',
#    'openPrice': 233,
#    'highPrice': 233,
#    'lowPrice': 228,
#    'closePrice': 230,
#    'change': -2,
#    'changePercent': -0.86,
#    'tradeVolume': 15,
#    'tradeValue': 3462500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2897A',
#    'name': '王道銀甲特',
#    'openPrice': 10.35,
#    'highPrice': 10.35,
#    'lowPrice': 10.3,
#    'closePrice': 10.3,
#    'change': -0.05,
#    'changePercent': -0.48,
#    'tradeVolume': 331,
#    'tradeValue': 3409650,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '020030',
#    'name': '統一智慧電動車N',
#    'openPrice': 5.38,
#    'highPrice': 5.4,
#    'lowPrice': 5.36,
#    'closePrice': 5.37,
#    'change': 0.02,
#    'changePercent': 0.37,
#    'tradeVolume': 630,
#    'tradeValue': 3396890,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2239',
#    'name': '英利-KY',
#    'openPrice': 57.1,
#    'highPrice': 58.4,
#    'lowPrice': 56.5,
#    'closePrice': 58.4,
#    'change': 1.3,
#    'changePercent': 2.28,
#    'tradeVolume': 59,
#    'tradeValue': 3395800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '01007T',
#    'name': '兆豐國泰R2',
#    'openPrice': 16.9,
#    'highPrice': 16.9,
#    'lowPrice': 16.85,
#    'closePrice': 16.88,
#    'change': 0.03,
#    'changePercent': 0.18,
#    'tradeVolume': 200,
#    'tradeValue': 3374340,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1324',
#    'name': '地球',
#    'openPrice': 17.15,
#    'highPrice': 17.15,
#    'lowPrice': 16.9,
#    'closePrice': 16.9,
#    'change': -0.2,
#    'changePercent': -1.17,
#    'tradeVolume': 198,
#    'tradeValue': 3373950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6658',
#    'name': '聯策',
#    'openPrice': 44,
#    'highPrice': 44,
#    'lowPrice': 42.75,
#    'closePrice': 42.85,
#    'change': -0.5,
#    'changePercent': -1.15,
#    'tradeVolume': 78,
#    'tradeValue': 3361550,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '5525',
#    'name': '順天',
#    'openPrice': 27.8,
#    'highPrice': 27.8,
#    'lowPrice': 27.6,
#    'closePrice': 27.75,
#    'change': -0.15,
#    'changePercent': -0.54,
#    'tradeVolume': 121,
#    'tradeValue': 3354800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2852',
#    'name': '第一保',
#    'openPrice': 18.45,
#    'highPrice': 18.6,
#    'lowPrice': 18.45,
#    'closePrice': 18.45,
#    'change': -0.05,
#    'changePercent': -0.27,
#    'tradeVolume': 181,
#    'tradeValue': 3349150,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1506',
#    'name': '正道',
#    'openPrice': 16.75,
#    'highPrice': 16.85,
#    'lowPrice': 16.6,
#    'closePrice': 16.75,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 199,
#    'tradeValue': 3321200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1338',
#    'name': '廣華-KY',
#    'openPrice': 39.9,
#    'highPrice': 39.9,
#    'lowPrice': 39.2,
#    'closePrice': 39.5,
#    'change': -0.35,
#    'changePercent': -0.88,
#    'tradeVolume': 83,
#    'tradeValue': 3286800,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6183',
#    'name': '關貿',
#    'openPrice': 69.8,
#    'highPrice': 70,
#    'lowPrice': 69.8,
#    'closePrice': 69.9,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 47,
#    'tradeValue': 3283200,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8072',
#    'name': '陞泰',
#    'openPrice': 27.9,
#    'highPrice': 27.9,
#    'lowPrice': 27.4,
#    'closePrice': 27.4,
#    'change': -0.25,
#    'changePercent': -0.9,
#    'tradeVolume': 118,
#    'tradeValue': 3261950,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2380',
#    'name': '虹光',
#    'openPrice': 7.29,
#    'highPrice': 7.29,
#    'lowPrice': 6.92,
#    'closePrice': 7.01,
#    'change': -0.26,
#    'changePercent': -3.58,
#    'tradeVolume': 464,
#    'tradeValue': 3260040,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1109',
#    'name': '信大',
#    'openPrice': 17.7,
#    'highPrice': 17.75,
#    'lowPrice': 17.65,
#    'closePrice': 17.7,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 183,
#    'tradeValue': 3237350,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4190',
#    'name': '佐登-KY',
#    'openPrice': 57.5,
#    'highPrice': 57.5,
#    'lowPrice': 56.1,
#    'closePrice': 56.2,
#    'change': -0.6,
#    'changePercent': -1.06,
#    'tradeVolume': 57,
#    'tradeValue': 3212600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '01001T',
#    'name': '土銀富邦R1',
#    'openPrice': 14.75,
#    'highPrice': 14.8,
#    'lowPrice': 14.75,
#    'closePrice': 14.8,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 216,
#    'tradeValue': 3193000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2032',
#    'name': '新鋼',
#    'openPrice': 17.25,
#    'highPrice': 17.25,
#    'lowPrice': 17,
#    'closePrice': 17.15,
#    'change': 0.15,
#    'changePercent': 0.88,
#    'tradeVolume': 184,
#    'tradeValue': 3145150,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '6606',
#    'name': '建德工業',
#    'openPrice': 24.3,
#    'highPrice': 24.35,
#    'lowPrice': 24.1,
#    'closePrice': 24.1,
#    'change': -0.1,
#    'changePercent': -0.41,
#    'tradeVolume': 129,
#    'tradeValue': 3124300,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2033',
#    'name': '佳大',
#    'openPrice': 17.25,
#    'highPrice': 17.25,
#    'lowPrice': 16.95,
#    'closePrice': 17,
#    'change': 0.05,
#    'changePercent': 0.29,
#    'tradeVolume': 179,
#    'tradeValue': 3052550,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00651R',
#    'name': '復華香港反1',
#    'openPrice': 9.6,
#    'highPrice': 9.6,
#    'lowPrice': 9.46,
#    'closePrice': 9.56,
#    'change': -0.06,
#    'changePercent': -0.62,
#    'tradeVolume': 318,
#    'tradeValue': 3036210,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00635U',
#    'name': '期元大S&P黃金',
#    'openPrice': 24.28,
#    'highPrice': 24.29,
#    'lowPrice': 24.25,
#    'closePrice': 24.25,
#    'change': -0.07,
#    'changePercent': -0.29,
#    'tradeVolume': 125,
#    'tradeValue': 3033330,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '9937',
#    'name': '全國',
#    'openPrice': 69.2,
#    'highPrice': 69.2,
#    'lowPrice': 68.5,
#    'closePrice': 68.5,
#    'change': -0.7,
#    'changePercent': -1.01,
#    'tradeVolume': 44,
#    'tradeValue': 3031900,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '9928',
#    'name': '中視',
#    'openPrice': 18.5,
#    'highPrice': 18.55,
#    'lowPrice': 18.3,
#    'closePrice': 18.4,
#    'change': -0.1,
#    'changePercent': -0.54,
#    'tradeVolume': 164,
#    'tradeValue': 3015600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '4439',
#    'name': '冠星-KY',
#    'openPrice': 125.5,
#    'highPrice': 126,
#    'lowPrice': 125,
#    'closePrice': 126,
#    'change': 0,
#    'changePercent': 0,
#    'tradeVolume': 24,
#    'tradeValue': 3013000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00736',
#    'name': '國泰新興市場',
#    'openPrice': 20.91,
#    'highPrice': 20.99,
#    'lowPrice': 20.91,
#    'closePrice': 20.97,
#    'change': 0.13,
#    'changePercent': 0.62,
#    'tradeVolume': 143,
#    'tradeValue': 2997430,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3164',
#    'name': '景岳',
#    'openPrice': 23.25,
#    'highPrice': 23.45,
#    'lowPrice': 23.2,
#    'closePrice': 23.35,
#    'change': 0.1,
#    'changePercent': 0.43,
#    'tradeVolume': 128,
#    'tradeValue': 2988350,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '8499',
#    'name': '鼎炫-KY',
#    'openPrice': 125,
#    'highPrice': 125,
#    'lowPrice': 124,
#    'closePrice': 124.5,
#    'change': -0.5,
#    'changePercent': -0.4,
#    'tradeVolume': 24,
#    'tradeValue': 2988000,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '00707R',
#    'name': '期元大S&P日圓反1',
#    'openPrice': 28.3,
#    'highPrice': 28.34,
#    'lowPrice': 28.27,
#    'closePrice': 28.34,
#    'change': 0.05,
#    'changePercent': 0.18,
#    'tradeVolume': 105,
#    'tradeValue': 2972820,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2069',
#    'name': '運錩',
#    'openPrice': 16.2,
#    'highPrice': 16.25,
#    'lowPrice': 16.05,
#    'closePrice': 16.1,
#    'change': -0.1,
#    'changePercent': -0.62,
#    'tradeVolume': 183,
#    'tradeValue': 2950750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2929',
#    'name': '淘帝-KY',
#    'openPrice': 11.3,
#    'highPrice': 11.35,
#    'lowPrice': 11.2,
#    'closePrice': 11.3,
#    'change': 0.05,
#    'changePercent': 0.44,
#    'tradeVolume': 257,
#    'tradeValue': 2894850,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2887F',
#    'name': '台新戊特二',
#    'openPrice': 46,
#    'highPrice': 46,
#    'lowPrice': 45.9,
#    'closePrice': 45.9,
#    'change': -0.1,
#    'changePercent': -0.22,
#    'tradeVolume': 62,
#    'tradeValue': 2849100,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1446',
#    'name': '宏和',
#    'openPrice': 35.25,
#    'highPrice': 35.55,
#    'lowPrice': 35.1,
#    'closePrice': 35.25,
#    'change': 0.05,
#    'changePercent': 0.14,
#    'tradeVolume': 79,
#    'tradeValue': 2784700,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '2704',
#    'name': '國賓',
#    'openPrice': 46.85,
#    'highPrice': 46.95,
#    'lowPrice': 46.7,
#    'closePrice': 46.75,
#    'change': -0.05,
#    'changePercent': -0.11,
#    'tradeVolume': 59,
#    'tradeValue': 2761500,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1457',
#    'name': '宜進',
#    'openPrice': 18.65,
#    'highPrice': 18.75,
#    'lowPrice': 18.5,
#    'closePrice': 18.6,
#    'change': -0.1,
#    'changePercent': -0.53,
#    'tradeVolume': 148,
#    'tradeValue': 2755750,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '1464',
#    'name': '得力',
#    'openPrice': 13.8,
#    'highPrice': 13.8,
#    'lowPrice': 13.55,
#    'closePrice': 13.55,
#    'change': -0.25,
#    'changePercent': -1.81,
#    'tradeVolume': 200,
#    'tradeValue': 2730600,
#    'lastUpdated': 1708666200000000},
#   {'type': 'EQUITY',
#    'symbol': '3593',
#    'name': '力銘',
#    'openPrice': 13.25,
#    'highPrice': 13.3,
#    'lowPrice': 12.65,
#    'closePrice': 12.65,
#    'change': -0.6,
#    'changePercent': -4.53,
#    'tradeVolume': 212,
#    'tradeValue': 2725150,
#    'lastUpdated': 1708666200000000},
#   ...]}
